# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

import sys
sys.path.append(r'C:\Users\justink\Code\dro')

import dro.utilities as dro
import dro.plotting_functions as dro_plots
# Out:
# failed to import CV2 in core.utilities
# c:\users\justink\code\imaging_behavior\imaging_behavior\core\tifffile.py:278: UserWarning: ImportError: No module named '_tifffile'. Loading of some compressed images will be very slow. Tifffile.c can be obtained at http://www.lfd.uci.edu/~gohlke/
#   "ImportError: No module named '_tifffile'. "
# failed to import mask in core.jcamdata.py
# failed to import get_mask_dict_gui in core.epoch.py
# FreeType import Failed: Freetype library not found
# failed to import mask relalated functions in __init__.py

# %% [markdown]
# ## Load data

# %%
from braintv_pilot.cohorts import cohort_assignment, mouse_info
mouse_df = cohort_assignment['mouse_id'].apply(lambda mouse: pd.Series(mouse_info(mouse)))
cohort_assignment = cohort_assignment.merge(
    mouse_df,
    how='left',
    on='mouse_id',
)

# %%
from braintv_pilot.latest import copy_latest, local_dir
# copy_latest()
df = dro.load_from_folder(local_dir)
# Out:
# error loading file 161107125855-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276600.pkl:
# Loading c:\users\justink\projects\braintv_behavior_piloting\braintv_pilot\..\data\raw\161108100145-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M258274.pkl
# Loading c:\users\justink\projects\braintv_behavior_piloting\braintv_pilot\..\data\raw\161108100932-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M258275.pkl
# Loading c:\users\justink\projects\braintv_behavior_piloting\braintv_pilot\..\data\raw\161108101222-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M261584.pkl
# Loading c:\users\justink\projects\braintv_behavior_piloting\braintv_pilot\..\data\raw\161108101439-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M258089.pkl
# Loading c:\users\justink\projects\braintv_behavior_piloting\braintv_pilot\..\data\raw\161108101709-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M258173.pkl
# Loading c:\users\justink\projects\braintv_behavior_piloting\braintv_pilot\..\data\raw\161108102140-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M258276.pkl

# %%
def get_training_day(df_in):
    '''adds a column to the dataframe with the number of unique training days up to that point
         '''

    training_day_lookup = {}
    for key, group in df_in.groupby(['mouse_id',]):
        dates = np.sort(group['date'].unique())
        training_day_lookup[key] = {date:training_day for training_day,date in enumerate(dates)}
        print key,dates
    return df_in.apply(lambda row: training_day_lookup[row['mouse_id']][row['date']],axis=1)

df['training_day'] = get_training_day(df)

#df['day_of_week'] = df.startdatetime.dt.weekday_name

## build arrays for change detection

# df['change'] = ~df['change_frame'].isnull()
df['change'] = df['trial_type']=='go'
df['detect'] = (df['response']==1.0) #| (df['trial_type']=='aborted')

## calculate reaction times

df['reaction_time'] = df['lick_times'].map(lambda x: x[0] if len(x)>0 else np.nan)
df['reaction_time'] = df.apply(lambda row: row['reaction_time'] - row['change_time'],axis=1)

## unwrap the response window
df['response_window_lower'] = df['response_window'].map(lambda x: x[0])
df['response_window_upper'] = df['response_window'].map(lambda x: x[1])
# Out:
# M246782 ['2016-08-22' '2016-08-23' '2016-08-24' '2016-08-25' '2016-08-26'
#  '2016-08-29' '2016-08-30' '2016-08-31' '2016-09-02' '2016-09-06'
#  '2016-09-07' '2016-09-08' '2016-09-09' '2016-09-12' '2016-09-13'
#  '2016-09-14' '2016-09-15' '2016-09-16' '2016-09-19' '2016-09-20']
# M249123 ['2016-08-22' '2016-08-23' '2016-08-24' '2016-08-25' '2016-08-26'
#  '2016-08-29' '2016-08-30' '2016-08-31' '2016-09-02' '2016-09-06'
#  '2016-09-07' '2016-09-08' '2016-09-09' '2016-09-12' '2016-09-13'
#  '2016-09-15' '2016-09-16' '2016-09-19' '2016-09-20']
# M250783 ['2016-08-22' '2016-08-23' '2016-08-24' '2016-08-25' '2016-08-26'
#  '2016-08-29' '2016-08-30' '2016-08-31' '2016-09-02' '2016-09-06'
#  '2016-09-07' '2016-09-08' '2016-09-09' '2016-09-12' '2016-09-13'
#  '2016-09-14' '2016-09-15' '2016-09-16' '2016-09-19' '2016-09-20'
#  '2016-09-21' '2016-09-22' '2016-09-23' '2016-09-26' '2016-09-27'
#  '2016-09-28' '2016-09-29' '2016-09-30' '2016-10-03' '2016-10-05'
#  '2016-10-06' '2016-10-07' '2016-10-10' '2016-10-11' '2016-10-12'
#  '2016-10-13' '2016-10-14' '2016-10-17' '2016-10-18' '2016-10-19'
#  '2016-10-20' '2016-10-21' '2016-10-24' '2016-10-25' '2016-10-26'
#  '2016-10-27' '2016-10-28' '2016-10-31' '2016-11-01' '2016-11-02'
#  '2016-11-03' '2016-11-04' '2016-11-07']
# M250786 ['2016-08-22' '2016-08-23' '2016-08-24' '2016-08-25' '2016-08-26'
#  '2016-08-29' '2016-08-30' '2016-08-31' '2016-09-02' '2016-09-06'
#  '2016-09-07' '2016-09-08' '2016-09-09' '2016-09-12' '2016-09-13'
#  '2016-09-14' '2016-09-15' '2016-09-16' '2016-09-19' '2016-09-20'
#  '2016-09-21' '2016-09-22' '2016-09-23' '2016-09-26' '2016-09-27'
#  '2016-09-28' '2016-09-29' '2016-09-30' '2016-10-03' '2016-10-05'
#  '2016-10-06' '2016-10-07' '2016-10-10' '2016-10-11' '2016-10-12'
#  '2016-10-13' '2016-10-14' '2016-10-17' '2016-10-18' '2016-10-19'
#  '2016-10-20' '2016-10-21' '2016-10-24' '2016-10-25' '2016-10-27'
#  '2016-10-28' '2016-10-31' '2016-11-01' '2016-11-02' '2016-11-03'
#  '2016-11-04' '2016-11-07']
# M258089 ['2016-09-19' '2016-09-20' '2016-09-22' '2016-09-23' '2016-09-26'
#  '2016-09-27' '2016-09-28' '2016-09-29' '2016-09-30' '2016-10-03'
#  '2016-10-04' '2016-10-05' '2016-10-06' '2016-10-07' '2016-10-10'
#  '2016-10-11' '2016-10-12' '2016-10-13' '2016-10-14' '2016-10-17'
#  '2016-10-18' '2016-10-19' '2016-10-20' '2016-10-21' '2016-10-25'
#  '2016-10-26' '2016-10-27' '2016-10-28' '2016-10-31' '2016-11-01'
#  '2016-11-02' '2016-11-03' '2016-11-04' '2016-11-07' '2016-11-08']
# M258173 ['2016-09-19' '2016-09-20' '2016-09-21' '2016-09-22' '2016-09-23'
#  '2016-09-26' '2016-09-27' '2016-09-28' '2016-09-29' '2016-09-30'
#  '2016-10-03' '2016-10-04' '2016-10-05' '2016-10-06' '2016-10-07'
#  '2016-10-10' '2016-10-11' '2016-10-12' '2016-10-13' '2016-10-14'
#  '2016-10-17' '2016-10-18' '2016-10-19' '2016-10-20' '2016-10-21'
#  '2016-10-25' '2016-10-26' '2016-10-27' '2016-10-28' '2016-10-31'
#  '2016-11-01' '2016-11-02' '2016-11-03' '2016-11-04' '2016-11-07'
#  '2016-11-08']
# M258174 ['2016-08-22' '2016-08-23' '2016-08-24' '2016-08-25' '2016-08-26'
#  '2016-08-29' '2016-08-30' '2016-08-31' '2016-09-02' '2016-09-06'
#  '2016-09-07' '2016-09-08' '2016-09-09' '2016-09-12' '2016-09-13'
#  '2016-09-14' '2016-09-15' '2016-09-16' '2016-09-19' '2016-09-20'
#  '2016-09-21' '2016-09-22' '2016-09-23' '2016-09-26' '2016-09-27'
#  '2016-09-28' '2016-09-29' '2016-09-30' '2016-10-03' '2016-10-05'
#  '2016-10-06' '2016-10-07' '2016-10-10' '2016-10-11' '2016-10-12'
#  '2016-10-13' '2016-10-14' '2016-10-17' '2016-10-18' '2016-10-19'
#  '2016-10-20' '2016-10-21' '2016-10-24' '2016-10-25' '2016-10-26'
#  '2016-10-27' '2016-10-28' '2016-10-31' '2016-11-01' '2016-11-02'
#  '2016-11-03' '2016-11-04' '2016-11-07']
# M258194 ['2016-10-10' '2016-10-11' '2016-10-12' '2016-10-13' '2016-10-14'
#  '2016-10-17' '2016-10-18' '2016-10-19' '2016-10-20' '2016-10-21'
#  '2016-10-25' '2016-10-26' '2016-10-27' '2016-10-28' '2016-10-31'
#  '2016-11-01' '2016-11-03' '2016-11-04' '2016-11-07']
# M258196 ['2016-08-29' '2016-08-30' '2016-08-31' '2016-09-02' '2016-09-06'
#  '2016-09-07' '2016-09-08' '2016-09-09' '2016-09-12' '2016-09-13'
#  '2016-09-15' '2016-09-16' '2016-09-19' '2016-09-20' '2016-09-21'
#  '2016-09-22' '2016-09-23' '2016-09-26' '2016-09-27' '2016-09-28'
#  '2016-09-29' '2016-09-30' '2016-10-03' '2016-10-05' '2016-10-06'
#  '2016-10-07' '2016-10-10' '2016-10-11' '2016-10-12' '2016-10-13'
#  '2016-10-14' '2016-10-17' '2016-10-18' '2016-10-19' '2016-10-20'
#  '2016-10-21' '2016-10-24' '2016-10-25' '2016-10-26' '2016-10-27'
#  '2016-10-28' '2016-10-31' '2016-11-01' '2016-11-02' '2016-11-03'
#  '2016-11-04' '2016-11-07']
# M258274 ['2016-09-19' '2016-09-20' '2016-09-22' '2016-09-23' '2016-09-26'
#  '2016-09-27' '2016-09-28' '2016-09-29' '2016-09-30' '2016-10-03'
#  '2016-10-04' '2016-10-05' '2016-10-06' '2016-10-07' '2016-10-10'
#  '2016-10-11' '2016-10-12' '2016-10-13' '2016-10-14' '2016-10-17'
#  '2016-10-18' '2016-10-19' '2016-10-20' '2016-10-21' '2016-10-25'
#  '2016-10-26' '2016-10-27' '2016-10-28' '2016-10-31' '2016-11-01'
#  '2016-11-02' '2016-11-03' '2016-11-04' '2016-11-07' '2016-11-08']
# M258275 ['2016-09-19' '2016-09-20' '2016-09-22' '2016-09-23' '2016-09-26'
#  '2016-09-27' '2016-09-28' '2016-09-29' '2016-09-30' '2016-10-03'
#  '2016-10-04' '2016-10-05' '2016-10-06' '2016-10-07' '2016-10-10'
#  '2016-10-11' '2016-10-12' '2016-10-13' '2016-10-14' '2016-10-17'
#  '2016-10-18' '2016-10-19' '2016-10-20' '2016-10-21' '2016-10-25'
#  '2016-10-26' '2016-10-27' '2016-10-28' '2016-11-01' '2016-11-02'
#  '2016-11-03' '2016-11-04' '2016-11-07' '2016-11-08']
# M258276 ['2016-09-19' '2016-09-20' '2016-09-22' '2016-09-23' '2016-09-26'
#  '2016-09-27' '2016-09-28' '2016-09-29' '2016-09-30' '2016-10-03'
#  '2016-10-04' '2016-10-05' '2016-10-06' '2016-10-07' '2016-10-10'
#  '2016-10-11' '2016-10-12' '2016-10-13' '2016-10-14' '2016-10-17'
#  '2016-10-18' '2016-10-19' '2016-10-20' '2016-10-21' '2016-10-25'
#  '2016-10-26' '2016-10-27' '2016-10-28' '2016-10-31' '2016-11-01'
#  '2016-11-02' '2016-11-03' '2016-11-04' '2016-11-07' '2016-11-08']
# M261584 ['2016-09-19' '2016-09-20' '2016-09-21' '2016-09-22' '2016-09-23'
#  '2016-09-26' '2016-09-27' '2016-09-28' '2016-09-29' '2016-09-30'
#  '2016-10-03' '2016-10-04' '2016-10-05' '2016-10-06' '2016-10-07'
#  '2016-10-10' '2016-10-11' '2016-10-12' '2016-10-13' '2016-10-14'
#  '2016-10-17' '2016-10-18' '2016-10-19' '2016-10-20' '2016-10-21'
#  '2016-10-25' '2016-10-26' '2016-10-27' '2016-10-28' '2016-10-31'
#  '2016-11-01' '2016-11-02' '2016-11-03' '2016-11-04' '2016-11-07'
#  '2016-11-08']
# M265154 ['2016-10-10' '2016-10-11' '2016-10-12' '2016-10-13' '2016-10-14'
#  '2016-10-17' '2016-10-18' '2016-10-19' '2016-10-20' '2016-10-21'
#  '2016-10-25' '2016-10-26' '2016-10-27' '2016-10-28' '2016-10-31'
#  '2016-11-01' '2016-11-03' '2016-11-04' '2016-11-07']
# M265158 ['2016-10-10' '2016-10-11' '2016-10-12' '2016-10-13' '2016-10-14'
#  '2016-10-17' '2016-10-18' '2016-10-19' '2016-10-20' '2016-10-21'
#  '2016-10-25' '2016-10-26' '2016-10-27' '2016-10-28' '2016-10-31'
#  '2016-11-01' '2016-11-03' '2016-11-04' '2016-11-07']
# M265166 ['2016-10-10' '2016-10-11' '2016-10-12' '2016-10-13' '2016-10-14'
#  '2016-10-17' '2016-10-18' '2016-10-19' '2016-10-20' '2016-10-21'
#  '2016-10-25' '2016-10-26' '2016-10-27' '2016-10-28' '2016-10-31'
#  '2016-11-01' '2016-11-03' '2016-11-04' '2016-11-07']
# M271723 ['2016-10-28']
# M271728 ['2016-10-28' '2016-10-31' '2016-11-01' '2016-11-02' '2016-11-03'
#  '2016-11-04' '2016-11-07']
# M271733 ['2016-10-31' '2016-11-01' '2016-11-02' '2016-11-03' '2016-11-04'
#  '2016-11-07']
# M271966 ['2016-10-10' '2016-10-11' '2016-10-12' '2016-10-13' '2016-10-14'
#  '2016-10-17' '2016-10-18' '2016-10-19' '2016-10-20' '2016-10-21'
#  '2016-10-25' '2016-10-26' '2016-10-27' '2016-10-28' '2016-10-31'
#  '2016-11-01' '2016-11-03' '2016-11-04' '2016-11-07']
# M272464 ['2016-10-28' '2016-10-31' '2016-11-01' '2016-11-03' '2016-11-04'
#  '2016-11-07']
# M272465 ['2016-10-10' '2016-10-11' '2016-10-12' '2016-10-13' '2016-10-14'
#  '2016-10-17' '2016-10-18' '2016-10-19' '2016-10-20' '2016-10-21'
#  '2016-10-25' '2016-10-26' '2016-10-27' '2016-10-28' '2016-10-31'
#  '2016-11-01' '2016-11-03' '2016-11-04' '2016-11-07']
# M276600 ['2016-10-28' '2016-10-31' '2016-11-01' '2016-11-02' '2016-11-03'
#  '2016-11-04']
# M276950 ['2016-10-28' '2016-10-31' '2016-11-01' '2016-11-02' '2016-11-03'
#  '2016-11-04' '2016-11-07']
# M276951 ['2016-10-28' '2016-10-31' '2016-11-01' '2016-11-02' '2016-11-03'
#  '2016-11-04' '2016-11-07']

# %%
cohort_assignmentgnment_assignment.head()
# Out:
#      cohort    day_zero mouse_id baselineweight   birthdate dayonescript  \
# 0  Cohort 4  2016-10-31  M272464           20.2  2016-08-24
# 1  Cohort 4  2016-10-31  M271733           20.4  2016-08-01
# 2  Cohort 4  2016-10-31  M271728           23.0  2016-08-01
# 3  Cohort 4  2016-10-31  M276951           20.8  2016-08-27
# 4  Cohort 4  2016-10-31  M276950           20.4  2016-08-27
#
#   driver1 driver2                  group iacuc_protocol minweight  \
# 0    None    None           EMX-Cre-Ai35           1406        85
# 1    None    None                  Nr5a1           1506        85
# 2    None    None                  Nr5a1           1506        85
# 3    None    None  Emx-IRES-Cre;Ai95(NC)           1506        85
# 4    None    None           EMX-Cre-Ai35           1506        85
#
#                   mousenotes   owner reporter     sex tasktype  \
# 0  Additional information...  sissyc     None    Male     None
# 1  Additional information...  sissyc     None  Female     None
# 2  Additional information...  sissyc     None    Male     None
# 3  Additional information...  sissyc     None  Female     None
# 4  Additional information...  sissyc     None  Female     None
#
#   training_location  userid waterrestrictionstartdate
# 0              None  sissyc                2016-10-21
# 1              None  sissyc                2016-10-21
# 2              None  sissyc                2016-10-21
# 3              None  sissyc                2016-10-21
# 4              None  sissyc                2016-10-21

# %%
df[['change_contrast','initial_contrast']].dropna().drop_duplicates()
# Out:
#        change_contrast  initial_contrast
# 2                 1.00              1.00
# 8650              0.16              0.16
# 10010             0.32              0.32
# 11597             0.64              0.64

# %%
df = df.merge(
    cohort_assignment,
    how='left',
    on='mouse_id',
)

# %%
def rectify_angle(angle):
    if np.isnan(angle):
        return 0.0
    else:
        angle = angle % 180
        return abs(min(
            angle,
            180 - angle
        ))

df['orientation_delta'] = df['change_ori'] - df['initial_ori']
df['orientation_delta'] = df['orientation_delta'].map(rectify_angle)
df['orientation_delta_log'] = df['orientation_delta'].map(np.log10).replace(-np.inf,0.001)

# %%
df[df.trial_type=='aborted']['orientation_delta'].unique()
# Out:
# array([ 0.])

# %%
from behaviorist import metrics

# %%
def compute_metrics(group):
    result = {
        'd-prime': metrics.discrim(group,'change','detect',metric=metrics.d_prime),
        'discrim_p': metrics.discrim(group,'change','detect',metric=metrics.discrim_p),
        'response_bias': metrics.response_bias(group,'detect'),
        'earned_water': metrics.earned_water(group), 
        'total_water': metrics.total_water(group), 
        'num_trials': metrics.num_trials(group),
        'num_contingent_trials': metrics.num_contingent_trials(group),
        'reaction_time_50th%ile': metrics.reaction_times(group,percentile=50),
        'reaction_time_05th%ile': metrics.reaction_times(group,percentile=5),
        'reaction_time_95th%ile': metrics.reaction_times(group,percentile=95),
        'num_orientations': len(group['orientation_delta'].dropna().unique()),
    }
    
    return pd.Series(result, name='metrics')

water = df.groupby(['mouse_id','training_day']).apply(compute_metrics).reset_index()
water['frac_earned_water'] = water['earned_water'] / water['total_water']
water['reaction_time_spread'] = water['reaction_time_95th%ile'] - water['reaction_time_05th%ile']

water = water.merge(
    cohort_assignment,
    how='left',
    on='mouse_id',
)
water['baselineweight'] = water['baselineweight'].astype(float)

water.head()
# Out:
# metrics mouse_id  training_day   d-prime  discrim_p  earned_water  \
# 0        M246782             0       NaN   1.000000         1.092
# 1        M246782             1 -0.057545   0.946458         0.354
# 2        M246782             2 -0.803594   0.076643         0.198
# 3        M246782             3 -0.025337   0.783441         0.276
# 4        M246782             4 -0.262469   0.681377         0.530
#
# metrics  num_contingent_trials  num_orientations  num_trials  \
# 0                        156.0               2.0       157.0
# 1                        356.0               2.0      1563.0
# 2                        117.0               2.0       394.0
# 3                        186.0               2.0       426.0
# 4                        179.0               2.0       423.0
#
# metrics  reaction_time_05th%ile  reaction_time_50th%ile  \
# 0                     -5.020008                0.334217
# 1                      0.161557                1.286406
# 2                      0.208261                1.360493
# 3                      0.087997                1.401724
# 4                      0.150696                1.343656
#
# metrics            ...             iacuc_protocol  minweight  \
# 0                  ...                       1406         85
# 1                  ...                       1406         85
# 2                  ...                       1406         85
# 3                  ...                       1406         85
# 4                  ...                       1406         85
#
# metrics                 mousenotes   owner  reporter     sex tasktype  \
# 0        Additional information...  sissyc   GCaMP6+  Female     None
# 1        Additional information...  sissyc   GCaMP6+  Female     None
# 2        Additional information...  sissyc   GCaMP6+  Female     None
# 3        Additional information...  sissyc   GCaMP6+  Female     None
# 4        Additional information...  sissyc   GCaMP6+  Female     None
#
# metrics  training_location  userid waterrestrictionstartdate
# 0                     None  sissyc                2016-08-12
# 1                     None  sissyc                2016-08-12
# 2                     None  sissyc                2016-08-12
# 3                     None  sissyc                2016-08-12
# 4                     None  sissyc                2016-08-12
#
# [5 rows x 33 columns]

# %%
import numpy as np

# %%
class LastWaterTime():
    """
    
    """
    def __init__(self):
        self.last_time = {}
    def check(self,row):
        key = (row['mouse_id'],row['training_day'])
        
        # first let's hang on to the last time to return later
        try:
            last_time = self.last_time[key]
        except KeyError:
            self.last_time[key] = np.nan
            last_time = self.last_time[key]
        
        # if they were rewarded this time, let's update the value
        if len(row['reward_times'])>0:
            self.last_time[key] = row['starttime']
            
        # now we return the old value
        return last_time

# %%
df.sort_values('starttime',inplace=True)
df['last_water_time'] = df.apply(LastWaterTime().check,axis=1)

# %%
df['change_time_tr'] = df['change_time'] - df['starttime']

df['wait_time'] = df['lick_times'].map(lambda x: x[0] if len(x)>0 else None) - df['starttime']
df['time_since_last_water'] = df['starttime'] - df['last_water_time']

df['time_since_last_water_log'] = df['time_since_last_water'].map(np.log10)

# %%
df['detect'].rolling()
# Out:
#        trial_type detect
# 0         aborted   True
# 1              go   True
# 2         aborted   True
# 3              go  False
# 4              go  False
# 5              go  False
# 6              go  False
# 7              go  False
# 8              go  False
# 9              go  False
# 10        aborted   True
# 11             go   True
# 12          catch  False
# 13        aborted   True
# 14        aborted   True
# 15        aborted   True
# 16        aborted   True
# 17             go  False
# 18          catch  False
# 19          catch  False
# 20             go   True
# 21             go  False
# 22             go  False
# 23             go  False
# 24             go   True
# 25             go   True
# 26        aborted   True
# 27             go  False
# 28        aborted   True
# 29        aborted   True
# ...           ...    ...
# 460835    aborted   True
# 460836    aborted   True
# 460837    aborted   True
# 460838    aborted   True
# 460839    aborted   True
# 460840    aborted   True
# 460841    aborted   True
# 460842    aborted   True
# 460843    aborted   True
# 460844    aborted   True
# 460845    aborted   True
# 460846    aborted   True
# 460847      other  False
# 460848    aborted   True
# 460849    aborted   True
# 460850    aborted   True
# 460851    aborted   True
# 460852    aborted   True
# 460853    aborted   True
# 460854    aborted   True
# 460855    aborted   True
# 460856    aborted   True
# 460857      other  False
# 460858    aborted   True
# 460859    aborted   True
# 460860    aborted   True
# 460861    aborted   True
# 460862    aborted   True
# 460863    aborted   True
# 460864    aborted   True
#
# [460865 rows x 2 columns]

# %%
# good_mouse = 'M258274'
good_mouse = 'M250786'

# %%
data = df[
#     (df.mouse_id==good_mouse)
    df.trial_type.isin(('go','catch'))
    & (df.training_day ==6)
]

sns.lmplot('cumulative_volume','detect',
           data=data,
#            logistic=True,
           hue='change',
           col='mouse_id',
           col_wrap=3,
           x_bins=np.arange(0,df.cumulative_volume.max(),0.05),
           fit_reg=False,
)
# plt.xlim(0,3)

# %%
df['success'] = (df['trial_type']=='go') & (df['detect'])
df['failure'] = (df['trial_type']!='go') & (df['detect'])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
from patsy import dmatrices
from sklearn import linear_model

# %%
from sklearn.model_selection import train_test_split

# %%
df['contrast'] = df['change_contrast'].fillna(1.0)

# %%
def compute_strategy(behav_df):
    
    df = behav_df.copy(deep=True)
    
    for factor in ('success','failure','detect'):
        df['prior_{}'.format(factor)] = (
            df[factor]
            .rolling(center=False,window=2)
            .apply(func=lambda x: x[0]==True)
            )
    df['prior_cumulative_volume'] = (
            df['cumulative_volume']
            .rolling(center=False,window=2)
            .apply(func=lambda x: x[0])
            )
    
    candidate_predictors = [
#         'prior_success',
#         'prior_failure',
        'prior_detect',
        'orientation_delta_log',
        'prior_cumulative_volume',
        'starttime',
        'time_since_last_water_log',
        'contrast',
#         'hour',
#         'dayofweek',
        
    ]
    
    predictors = [p for p in candidate_predictors if len(df[p].unique()>1)]
    print predictors,df['contrast'].unique(),len(df['contrast'].unique()>1)
    
    df = df[['detect',]+predictors].dropna().apply(pd.to_numeric)
    df['detect'] = df['detect'].astype(int)
    
    # z-score the predictors
    for col in predictors:
        df[col] = (df[col] - df[col].mean())/df[col].std(ddof=0)

    #train logistic regression
    formula = 'detect ~ ' + ' + '.join(predictors)
    y, X = dmatrices(formula,df)
    
    formula2 = 'detect ~ orientation_delta_log'
    yo, Xo = dmatrices(formula2,df)
        
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.5)
    
    Xo_train, Xo_test, yo_train, yo_test = train_test_split(
        Xo, yo, test_size=0.5)
    
    try:
        logreg = linear_model.LogisticRegression(
            C=0.35, #chosen based on median of LogisticRegressionCV on all sessions
            penalty = 'l1',
            class_weight = 'balanced',
        )
        logreg.fit(X_train,y_train)
        results = {k:v for k,v in zip(X.design_info.column_names,logreg.coef_[0])}

        y_pred = logreg.predict(X_test)
        results.update(dict(
            score=logreg.score(X_test,y_test),
            p=metrics.discrim_p(y_pred,y_test),
            )
        )
        
        # orientation-only
        logreg.fit(Xo_train,yo_train)
        results.update(
            {'{}_o'.format(k):v for k,v in zip(Xo.design_info.column_names,logreg.coef_[0])}
            )

        yo_pred = logreg.predict(Xo_test)
        results.update(dict(
            score_o=logreg.score(Xo_test,yo_test),
            p_o=metrics.discrim_p(yo_pred,yo_test),
            )
        )
        
        return pd.Series(results,name='results')
    
    
    except ValueError:
        return None

# %%
results = compute_strategy(df)
print results
# Out:
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.    0.16  0.32  0.64]
# Intercept                    0.000000
# Intercept_o                  0.121182
# contrast                     0.079021
# orientation_delta_log       -0.781925
# orientation_delta_log_o     -0.798001
# p                            0.000000
# p_o                          0.000000
# prior_cumulative_volume      0.019064
# prior_detect                 0.008577
# score                        0.754710
# score_o                      0.774840
# starttime                   -0.304249
# time_since_last_water_log   -0.171659
# Name: results, dtype: float64

# %%
strategy = (
    df[df.trial_type.isin(['go','catch'])]
    .groupby(['mouse_id','dayofweek','training_day'])
    .apply(compute_strategy)
    .reset_index()
    )

strategy = pd.merge(strategy,water,on=['mouse_id','training_day'])

p_thresh = 0.05
strategy['stimulus_control'] = (strategy['discrim_p'] < p_thresh) & (strategy['d-prime'] > 0.5)
strategy['model_significant'] = strategy['p'] < p_thresh
strategy['model_significant_o'] = strategy['p_o'] < p_thresh
strategy.head()
# Out:
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.    0.64  0.32  0.16]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.    0.32  0.64]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ['prior_detect', 'orientation_delta_log', 'prior_cumulative_volume', 'starttime', 'time_since_last_water_log', 'contrast'] [ 1.]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-338-40df489cd30c> in <module>()
#       2     df[df.trial_type.isin(['go','catch'])]
#       3     .groupby(['mouse_id','dayofweek','training_day'])
# ----> 4     .apply(compute_strategy)
#       5     .reset_index()
#       6     )
#
# C:\Users\justink\AppData\Local\Continuum\Anaconda2\envs\dro\lib\site-packages\pandas\core\groupby.pyc in apply(self, func, *args, **kwargs)
#     649         # ignore SettingWithCopy here in case the user mutates
#     650         with option_context('mode.chained_assignment', None):
# --> 651             return self._python_apply_general(f)
#     652
#     653     def _python_apply_general(self, f):
#
# C:\Users\justink\AppData\Local\Continuum\Anaconda2\envs\dro\lib\site-packages\pandas\core\groupby.pyc in _python_apply_general(self, f)
#     653     def _python_apply_general(self, f):
#     654         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 655                                                    self.axis)
#     656
#     657         return self._wrap_applied_output(
#
# C:\Users\justink\AppData\Local\Continuum\Anaconda2\envs\dro\lib\site-packages\pandas\core\groupby.pyc in apply(self, f, data, axis)
#    1509                 hasattr(splitter, 'fast_apply') and axis == 0):
#    1510             try:
# -> 1511                 values, mutated = splitter.fast_apply(f, group_keys)
#    1512                 return group_keys, values, mutated
#    1513             except (lib.InvalidApply):
#
# C:\Users\justink\AppData\Local\Continuum\Anaconda2\envs\dro\lib\site-packages\pandas\core\groupby.pyc in fast_apply(self, f, names)
#    3929
#    3930         sdata = self._get_sorted_data()
# -> 3931         results, mutated = lib.apply_frame_axis0(sdata, f, names, starts, ends)
#    3932
#    3933         return results, mutated
#
# pandas\src\reduce.pyx in pandas.lib.apply_frame_axis0 (pandas\lib.c:41631)()
#
# C:\Users\justink\AppData\Local\Continuum\Anaconda2\envs\dro\lib\site-packages\pandas\core\groupby.pyc in f(g)
#     645         @wraps(func)
#     646         def f(g):
# --> 647             return func(g, *args, **kwargs)
#     648
#     649         # ignore SettingWithCopy here in case the user mutates
#
# <ipython-input-337-21162371beaa> in compute_strategy(behav_df)
#       1 def compute_strategy(behav_df):
#       2
# ----> 3     df = behav_df.copy(deep=True)
#       4
#       5     for factor in ('success','failure','detect'):
#
# C:\Users\justink\AppData\Local\Continuum\Anaconda2\envs\dro\lib\site-packages\pandas\core\generic.pyc in copy(self, deep)
#    2970         copy : type of caller
#    2971         """
# -> 2972         data = self._data.copy(deep=deep)
#    2973         return self._constructor(data).__finalize__(self)
#    2974
#
# C:\Users\justink\AppData\Local\Continuum\Anaconda2\envs\dro\lib\site-packages\pandas\core\internals.pyc in copy(self, deep, mgr)
#    3134             new_axes = list(self.axes)
#    3135         return self.apply('copy', axes=new_axes, deep=deep,
# -> 3136                           do_integrity_check=False)
#    3137
#    3138     def as_matrix(self, items=None):
#
# C:\Users\justink\AppData\Local\Continuum\Anaconda2\envs\dro\lib\site-packages\pandas\core\internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, raw, **kwargs)
#    2898             return self.make_empty(axes or self.axes)
#    2899         bm = self.__class__(result_blocks, axes or self.axes,
# -> 2900                             do_integrity_check=do_integrity_check)
#    2901         bm._consolidate_inplace()
#    2902         return bm
#
# C:\Users\justink\AppData\Local\Continuum\Anaconda2\envs\dro\lib\site-packages\pandas\core\internals.pyc in __init__(self, blocks, axes, do_integrity_check, fastpath)
#    2596         self._consolidate_check()
#    2597
# -> 2598         self._rebuild_blknos_and_blklocs()
#    2599
#    2600     def make_empty(self, axes=None):
#
# C:\Users\justink\AppData\Local\Continuum\Anaconda2\envs\dro\lib\site-packages\pandas\core\internals.pyc in _rebuild_blknos_and_blklocs(self)
#    2684             rl = blk.mgr_locs
#    2685             new_blknos[rl.indexer] = blkno
# -> 2686             new_blklocs[rl.indexer] = np.arange(len(rl))
#    2687
#    2688         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %%
sns.lmplot('d-prime','orientation_delta_log',data=strategy,
           hue='model_significant',
           fit_reg=False,
              )

# %%
lm = sns.lmplot('d-prime','orientation_delta_log_o',data=strategy,
           hue='model_significant_o',
           fit_reg=False,
              )
# lm.ax.plot()

# %%
# good_mouse = 'M258274'
good_mouse = 'M250786'

# %%
fp = sns.factorplot('training_day','d-prime',data=strategy[strategy['mouse_id']==good_mouse],
#                     col='mouse_id',
#                     col_wrap=2,
                    size=2,
                    aspect=5,
#                     hue='cohort',
#                     col_order=col_order,
              )
fp = sns.factorplot('training_day','orientation_delta_log',data=strategy[strategy['mouse_id']==good_mouse],
#                     col='mouse_id',
#                     col_wrap=2,
                    size=2,
                    aspect=5,
#                     hue='cohort',
#                     col_order=col_order,
              )

# %%
min_tr = 50

# %%
df = df.merge(
    df[df.trial_type.isin(['go','catch'])].groupby(['mouse_id','training_day']).size().rename('num_tr').reset_index(),
    on=['mouse_id','training_day'],
    how='left',
)

# %%
df.head()
# Out:
#   LDT_mode auto_rewarded blank_duration_range blank_screen_timeout  \
# 0    block          None           (0.0, 0.0)                False
# 1    block          True           (0.0, 0.0)                False
# 2   single          None           (0.5, 0.5)                False
# 3     None          True           (0.0, 0.0)                 None
# 4     None          True           (0.0, 0.0)                 None
#
#    change_color  change_contrast  change_frame change_image  change_ori  \
# 0           NaN              NaN           NaN         None         NaN
# 1           1.0              NaN         132.0         None       180.0
# 2           NaN              1.0           NaN         None         NaN
# 3           1.0              NaN         168.0         None       180.0
# 4           1.0              NaN         156.0         None       180.0
#
#    change_size   ...    waterrestrictionstartdate orientation_delta  \
# 0          NaN   ...                   2016-08-12               NaN
# 1         50.0   ...                   2016-08-12              90.0
# 2          NaN   ...                   2016-08-12               NaN
# 3         50.0   ...                   2016-08-12              90.0
# 4         50.0   ...                   2016-08-12              90.0
#
#   orientation_delta_log  last_water_time wait_time  time_since_last_water  \
# 0                   NaN              NaN  0.321877                    NaN
# 1              1.954243              NaN  2.080386                    NaN
# 2                   NaN              NaN  0.504858                    NaN
# 3              1.954243              NaN  7.025571                    NaN
# 4              1.954243              NaN       NaN                    NaN
#
#    time_since_last_water_log  success  failure  num_tr
# 0                        NaN    False    False     168
# 1                        NaN     True    False     189
# 2                        NaN    False    False     380
# 3                        NaN    False    False     156
# 4                        NaN    False    False     157
#
# [5 rows x 94 columns]

# %%
min_tr = 50
data = df[
    (df.mouse_id==good_mouse)
    & df.trial_type.isin(('go','catch'))
#     & (df.training_day ==6)
    & (df.num_tr>min_tr)
]

sns.lmplot('orientation_delta_log','detect',
           data=data,
           logistic=True,
           ci=None,
#            hue='change',
           size=2,
           col='training_day',
           col_wrap=5,
           x_estimator=np.mean,
           x_ci=95,
#            x_bins=np.arange(0,data.cumulative_volume.max(),0.1),
#            y_jitter=0.1,
#            x_jitter=0.05,
#            fit_reg=False,
)
# plt.xlim(0,3)

# %%
data['orientation_delta'].unique()
# Out:
# array([ 90.,   0.,  30.,  45.,   5.,  10.,  20.])

# %%
mask = (
#     (strategy['prior_failure'].abs()<10)
#     & (strategy['prior_success'].abs()<10)
#     & (strategy['orientation_delta'].abs()<10)
    (strategy['stimulus_control'])
)

# %%
sns.lmplot('training_day','orientation_delta_log',data=strategy,
           col='stimulus_control',
           hue='model_significant',
           fit_reg=False,
           size=3,
              )

# %%
strategy.groupby('stimulus_control')['model_significant'].mean()
# Out:
# stimulus_control
# False    0.528369
# True     0.923313
# Name: model_significant, dtype: float64

# %%
sns.countplot('stimulus_control',data=strategy,hue='model_significant')

# %%
sns.factorplot('stimulus_control','score',data=strategy,
               hue='model_significant',
              )

# %%
learned = strategy.groupby('mouse_id')['stimulus_control'].sum()>3

# %%
strategy['learned'] = strategy['mouse_id'].map(learned)

# %%
cols = ['training_day','orientation_delta_log','starttime','prior_cumulative_volume','time_since_last_water_log']
g = sns.PairGrid(strategy[strategy.model_significant].dropna(),vars=cols)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter,alpha=0.5)
# g = g.map_lower(plt.hexbin,gridsize=(30,20),bins='log',linewidths=(0,),cmap='Blues')

# %%
sns.jointplot('orientation_delta_log','time_since_last_water_log',strategy[strategy.model_significant])
sns.jointplot('starttime','prior_cumulative_volume',strategy[strategy.model_significant],stat_func=None)

# %%
orientation_mask = (
    (strategy['model_significant']==True)
    & (strategy['num_orientations'] > 2)
    & (strategy['orientation_delta_log'] > 0.8)
#     & (strategy['orientation_delta_log'] > 1)
)
strategy[orientation_mask]
# Out:
#        cohort mouse_id  training_day  Intercept  orientation_delta_log  \
# 86   Cohort 1  M250783            47  -0.028978               0.903345
# 88   Cohort 1  M250783            49  -0.026627               0.893827
# 138  Cohort 1  M250786            46  -0.116534               1.042711
# 139  Cohort 1  M250786            47  -0.078455               1.334456
# 140  Cohort 1  M250786            48   0.000000               1.324859
# 194  Cohort 1  M258174            50  -0.204527               1.041162
# 238  Cohort 1  M258196            41  -0.471022               0.937824
#
#                 p  prior_cumulative_volume     score  starttime  \
# 86   2.659516e-06                -0.157537  0.679688   0.000000
# 88   1.378572e-05                -0.276219  0.695312   0.000000
# 138  9.141577e-07                 0.000000  0.733333   0.203479
# 139  1.589498e-07                 0.000000  0.751938   0.108672
# 140  3.652679e-03                 0.000000  0.645161   0.104739
# 194  5.468635e-05                 0.000000  0.716667  -0.166871
# 238  6.298130e-06                 0.000000  0.769231   0.313389
#
#      time_since_last_water_log   ...     reaction_time_05th%ile  \
# 86                    0.000000   ...                   0.316577
# 88                   -0.642691   ...                   0.283063
# 138                  -0.073695   ...                   0.283867
# 139                   0.000000   ...                   0.300272
# 140                   0.057627   ...                   0.299105
# 194                  -0.984576   ...                   0.283149
# 238                  -1.009595   ...                   0.248676
#
#      reaction_time_50th%ile  reaction_time_95th%ile  response_bias  \
# 86                 0.409099                3.495473       0.295720
# 88                 0.500131                3.302619       0.308594
# 138                0.416612                3.669626       0.325000
# 139                0.400783                3.933001       0.370656
# 140                0.417626                3.903842       0.475936
# 194                0.468049                2.529613       0.178423
# 238                0.550231                4.048075       0.153846
#
#      total_water  frac_earned_water  reaction_time_spread  stimulus_control  \
# 86         0.370                1.0              3.178896              True
# 88         0.395                1.0              3.019556              True
# 138        0.340                1.0              3.385759              True
# 139        0.425                1.0              3.632730              True
# 140        0.395                1.0              3.604737              True
# 194        0.240                1.0              2.246464              True
# 238        0.275                1.0              3.799399              True
#
#      model_significant  learned
# 86                True     True
# 88                True     True
# 138               True     True
# 139               True     True
# 140               True     True
# 194               True     True
# 238               True     True
#
# [7 rows x 26 columns]

# %%
last_water_mask = (
    (strategy['model_significant']==True)
    & (strategy['time_since_last_water_log'] < -1.0)
#     & (strategy['orientation_delta_log'] > 1)
)
strategy[last_water_mask][['cohort','mouse_id','training_day','orientation_delta_log','time_since_last_water_log']]
# Out:
#        cohort mouse_id  training_day  orientation_delta_log  \
# 1    Cohort 1  M246782             1              -0.116119
# 11   Cohort 1  M246782            11               0.000000
# 14   Cohort 1  M246782            14               0.640690
# 40   Cohort 1  M250783             1               0.337693
# 45   Cohort 1  M250783             6               0.216696
# 50   Cohort 1  M250783            11               0.520749
# 52   Cohort 1  M250783            13               0.518983
# 53   Cohort 1  M250783            14               0.137506
# 55   Cohort 1  M250783            16               0.000000
# 58   Cohort 1  M250783            19               1.354166
# 59   Cohort 1  M250783            20               1.392355
# 77   Cohort 1  M250783            38               0.620483
# 87   Cohort 1  M250783            48               0.697648
# 90   Cohort 1  M250783            51               0.570392
# 103  Cohort 1  M250786            11               1.149348
# 104  Cohort 1  M250786            12               1.305807
# 106  Cohort 1  M250786            14               1.508474
# 109  Cohort 1  M250786            17               1.599890
# 123  Cohort 1  M250786            31               2.546623
# 145  Cohort 1  M258174             1               0.016272
# 150  Cohort 1  M258174             6               0.775295
# 157  Cohort 1  M258174            13               1.246470
# 158  Cohort 1  M258174            14               1.858555
# 160  Cohort 1  M258174            16               1.398253
# 161  Cohort 1  M258174            17               0.911167
# 190  Cohort 1  M258174            46               0.040063
# 191  Cohort 1  M258174            47               0.680508
# 202  Cohort 1  M258196             5               0.000000
# 208  Cohort 1  M258196            11               2.011364
# 210  Cohort 1  M258196            13               0.730555
# 214  Cohort 1  M258196            17               2.065375
# 217  Cohort 1  M258196            20               1.500675
# 220  Cohort 1  M258196            23               1.362752
# 223  Cohort 1  M258196            26               1.652191
# 229  Cohort 1  M258196            32               0.958937
# 234  Cohort 1  M258196            37               0.395719
# 238  Cohort 1  M258196            41               0.937824
# 239  Cohort 1  M258196            42               0.441702
# 262  Cohort 2  M258089            18               2.143389
# 274  Cohort 2  M258089            30               3.373012
# 275  Cohort 2  M258089            31               2.768360
# 276  Cohort 2  M258089            32               2.576599
# 279  Cohort 2  M258173             0              -0.056010
# 331  Cohort 2  M258274            16               2.549007
# 347  Cohort 2  M258274            32               1.939137
# 373  Cohort 2  M258275            23               1.839054
# 374  Cohort 2  M258275            24               1.745410
# 377  Cohort 2  M258275            27               1.438548
# 381  Cohort 2  M258275            31               2.329953
# 450  Cohort 2  M261584            31               1.545037
# 463  Cohort 3  M258194             8               2.175456
# 465  Cohort 3  M258194            10               1.222456
# 468  Cohort 3  M258194            13               2.202770
#
#      time_since_last_water_log
# 1                    -1.278447
# 11                   -1.053959
# 14                   -1.678572
# 40                   -1.329336
# 45                   -1.024135
# 50                   -1.532691
# 52                   -2.053800
# 53                   -1.413550
# 55                   -1.384231
# 58                   -1.125882
# 59                   -1.159930
# 77                   -1.307988
# 87                   -1.767740
# 90                   -1.440223
# 103                  -1.212338
# 104                  -1.066844
# 106                  -1.442269
# 109                  -1.788521
# 123                  -1.890016
# 145                  -1.306382
# 150                  -1.030235
# 157                  -1.059756
# 158                  -1.125571
# 160                  -1.457140
# 161                  -1.998415
# 190                  -1.115720
# 191                  -1.907916
# 202                  -1.168225
# 208                  -1.265310
# 210                  -1.331178
# 214                  -1.443223
# 217                  -1.662671
# 220                  -1.148232
# 223                  -1.342165
# 229                  -1.228548
# 234                  -1.512002
# 238                  -1.009595
# 239                  -1.155896
# 262                  -1.298518
# 274                  -1.006688
# 275                  -1.315019
# 276                  -1.199985
# 279                  -1.182027
# 331                  -1.292220
# 347                  -1.057900
# 373                  -1.354592
# 374                  -1.098158
# 377                  -1.320334
# 381                  -1.114768
# 450                  -1.016771
# 463                  -1.091694
# 465                  -1.534465
# 468                  -1.310688

# %%
def bins(x,steps=20):
    return np.linspace(x.min(),x.max(),steps)

# %%
def lookup_factors(mouse,day):
    factors = strategy[(strategy.mouse_id==mouse)&(strategy.training_day==day)]
    assert len(factors)==1
    return factors.iloc[0]

# %%
mouse_exemplars = (
    ('M250783',13),
    ('M250783',47),
)


fig,ax = plt.subplots(3,len(mouse_exemplars),sharey=True,figsize=(6,9))
fig.subplots_adjust(hspace=.5)

for ii,(mouse,day) in enumerate(mouse_exemplars):
    factors = lookup_factors(mouse,day)
#     print factors

    mask = (
        (df['mouse_id']==mouse)
        & (df['training_day']==day)
        & df['trial_type'].isin(['go','catch'])
    )

    sns.regplot('orientation_delta_log','detect',df[mask],
                logistic=True,
                x_ci=95,
                x_estimator=np.mean,
                ax=ax[0,ii],
                color='0.3',
              )
    ax[0,ii].set_ylim(0,1)
    ax[0,ii].set_title('{}, day {}'.format(mouse,day))
    
    xlabel = 'log(orientation_delta), beta: {:0.2f}'.format(factors['orientation_delta_log'])
    ax[0,ii].set_xlabel(xlabel)
    
    sns.regplot('starttime','detect',df[mask],
                logistic=True,
                x_ci=95,
                x_estimator=np.mean,
                x_bins=bins(df[mask]['starttime'],steps=10),
                ax=ax[1,ii],
                color='0.3',
               )
    xlabel = 'trial start time, beta: {:0.2f}'.format(factors['starttime'])
    ax[1,ii].set_xlabel(xlabel)
    
    sns.regplot('time_since_last_water_log','detect',df[mask],
                logistic=True,
                x_ci=95,
                x_estimator=np.mean,
                x_bins=bins(df[mask]['time_since_last_water_log'],steps=10),
                ax=ax[2,ii],
                color='0.3',
               )
    xlabel = 'log(time_since_last_water), beta: {:0.2f}'.format(factors['time_since_last_water_log'])
    ax[2,ii].set_xlabel(xlabel)
    
    if ii>0:
        [a.set_ylabel('') for a in ax[:,ii]]

# %%
strategy = pd.merge(strategy,cohort_assignment,on='mouse_id',how='left')

# %%
fp = sns.factorplot('orientation_delta_log','group',data=strategy[strategy.model_significant],size=6)
fp.ax.axvline(0.0,color='0.5',zorder=-1)
fp = sns.factorplot('time_since_last_water_log','group',data=strategy[strategy.model_significant],size=6)
fp.ax.axvline(0.0,color='0.5',zorder=-1)

# %%
strategy[strategy.model_significant]['orientation_delta_log'].min()
# Out:
# -0.4393583261719356

# %%
reload(sns)
# Out:
# <module 'seaborn' from 'C:\Users\justink\AppData\Local\Continuum\Anaconda2\envs\dro\lib\site-packages\seaborn\__init__.pyc'>

# %%
data = strategy[strategy.model_significant]

# %%
strategy['baselineweight'].astype(float)
# Out:
# 1      23.3
# 2      23.3
# 3      23.3
# 7      23.3
# 8      23.3
# 9      23.3
# 10     23.3
# 11     23.3
# 12     23.3
# 13     23.3
# 16     23.3
# 21     24.8
# 34     24.8
# 37     24.8
# 38     24.8
# 40     22.2
# 42     22.2
# 44     22.2
# 45     22.2
# 46     22.2
# 47     22.2
# 48     22.2
# 49     22.2
# 50     22.2
# 51     22.2
# 52     22.2
# 53     22.2
# 54     22.2
# 55     22.2
# 56     22.2
#        ...
# 560    15.7
# 561    15.7
# 562    15.7
# 566    15.7
# 567    15.7
# 568    15.7
# 570    23.0
# 571    23.0
# 572    23.0
# 573    23.0
# 574    23.0
# 575    23.0
# 576    20.4
# 577    20.4
# 579    20.4
# 580    20.4
# 586    20.2
# 590    16.6
# 591    16.6
# 592    16.6
# 593    16.6
# 595    20.4
# 596    20.4
# 597    20.4
# 598    20.4
# 600    20.4
# 602    20.8
# 605    20.8
# 606    20.8
# 607    20.8
# Name: baselineweight, dtype: float64

# %%
strategy['baselineweight'] = strategy['baselineweight'].astype(float)

# %%
wdata = (
    strategy[strategy.model_significant]
    .groupby(['group','mouse_id'])[['baselineweight','orientation_delta_log']]
    .max()
    .reset_index()
)
sns.lmplot('baselineweight','orientation_delta_log',
           data=wdata,
#            hue='group',
#            fit_reg=False,
#            x_estimator=np.mean,
          )
sns.lmplot('baselineweight','orientation_delta_log',
           data=wdata,
           hue='group',
           fit_reg=False,
#            x_estimator=np.mean,
          )

# %%
sns.lmplot('baselineweight','time_since_last_water_log',
           data=strategy[strategy.model_significant])

# %%
sns.regplot('dayofweek','orientation_delta_log',
            data=strategy[strategy.model_significant],
#            x_estimator=np.mean,
#            x_partial='training_day',
           x_jitter=0.2,
            label='raw'
          )
sns.regplot('dayofweek','orientation_delta_log',
            data=strategy[strategy.model_significant],
#            x_estimator=np.mean,
            x_partial='training_day',
#            x_jitter=None,
            label='regressing out training day'
          )
plt.legend()
