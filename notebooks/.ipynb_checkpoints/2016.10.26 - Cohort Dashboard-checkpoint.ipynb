# %% [markdown]
# Justin Kiggins
#
# Oct 24, 2016
#
# [justink@alleninstitute.org](mailto:justink@alleninstitute.org)
#
# Summary of learning on cohorts 1-3 on the Detection of Change task.

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# import sys
# sys.path.append(r'C:\Users\justink\Code\dro')

from dro import utilities as dro
from dro import plotting_functions as dro_plots
# Out:
# /home/justink/.conda/envs/braintv_behav/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# failed to import CV2 in core.utilities
# failed to import mask in core.jcamdata.py
# failed to import get_mask_dict_gui in core.epoch.py
# failed to import aibs.Analysis.Core.smooth
# failed to import mask relalated functions in __init__.py

# %%
from braintv_pilot.cohorts import cohort_assignment
cohort_assignment
# Out:
#       mouse                   experiment  cohort   day_zero
# 0   M272464  visual_behavior_development       4 2016-10-31
# 1   M271733  visual_behavior_development       4 2016-10-31
# 2   M271728  visual_behavior_development       4 2016-10-31
# 3   M276951  visual_behavior_development       4 2016-10-31
# 4   M276950  visual_behavior_development       4 2016-10-31
# 5   M276600  visual_behavior_development       4 2016-10-31
# 6   M272465  visual_behavior_development       3 2016-10-10
# 7   M265158  visual_behavior_development       3 2016-10-10
# 8   M271966  visual_behavior_development       3 2016-10-10
# 9   M265154  visual_behavior_development       3 2016-10-10
# 10  M258194  visual_behavior_development       3 2016-10-10
# 11  M265166  visual_behavior_development       3 2016-10-10
# 12  M258173  visual_behavior_development       2 2016-09-19
# 13  M258089  visual_behavior_development       2 2016-09-19
# 14  M258276  visual_behavior_development       2 2016-09-19
# 15  M261584  visual_behavior_development       2 2016-09-19
# 16  M258274  visual_behavior_development       2 2016-09-19
# 17  M258275  visual_behavior_development       2 2016-09-19
# 18  M246782  visual_behavior_development       1 2016-08-22
# 19  M249123  visual_behavior_development       1 2016-08-22
# 20  M258174  visual_behavior_development       1 2016-08-22
# 21  M250783  visual_behavior_development       1 2016-08-22
# 22  M250786  visual_behavior_development       1 2016-08-22
# 23  M258196  visual_behavior_development       1 2016-08-22
# 24  M273577  visual_behavior_development       5 2016-11-28
# 25  M273578  visual_behavior_development       5 2016-11-28
# 26  M278229  visual_behavior_development       5 2016-11-28
# 27  M276444  visual_behavior_development       5 2016-11-28
# 28  M275962  visual_behavior_development       5 2016-11-28
# 29  M276445  visual_behavior_development       5 2016-11-28
# 30  M275965  visual_behavior_development       6 2017-01-16
# 31  M275963  visual_behavior_development       6 2017-01-16
# 32  M277931  visual_behavior_development       6 2017-01-16
# 33  M278329  visual_behavior_development       6 2017-01-16
# 34  M278463  visual_behavior_development       6 2017-01-16
# 35  M278332  visual_behavior_development       6 2017-01-16

# %%
from braintv_pilot import latest

# %%
latest.local_dir
# Out:
# '/local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw'

# %%
from braintv_pilot.cohorts import mouse_info
mouse_df = cohort_assignment['mouse'].apply(lambda mouse: pd.Series(mouse_info(mouse)))
cohort_assignment = cohort_assignment.merge(
    mouse_df,
    how='left',
    left_on='mouse',
    right_on='mouse_id'
)

# %%
cohort_assignment
# Out:
#       mouse                   experiment  cohort   day_zero baselineweight  \
# 0   M272464  visual_behavior_development       4 2016-10-31           20.2
# 1   M271733  visual_behavior_development       4 2016-10-31           20.4
# 32  2016-09-02                 None    None
# 33  2016-09-05                 None    None
# 34  2016-09-06                 None    None
# 35  2016-09-05                 None    None
#
#                                     group            ...            minweight  \
# 0                            EMX-Cre-Ai35            ...                   85
# 1                                   Nr5a1            ...                   85
# 2                                   Nr5a1            ...                   85
# 3                   Emx-IRES-Cre;Ai95(NC)            ...                   81
# 4                            EMX-Cre-Ai35            ...                   85
# 5                            EMX-Cre-Ai35            ...                   85
# 6                            EMX-Cre-Ai35            ...                   80
# 7   Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)            ...                   80
# 8                            EMX-Cre-Ai35            ...                   80
# 9   Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)            ...                   80
# 10  Scnn1a-Tg3-Cre; Camk2a-tTa; Ai93 (NC)            ...                   80
# 11  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)            ...                   80
# 12                               Sim1-Cre            ...                   85
# 13                                   Gnb4            ...                   80
# 14                                 Rasgrf            ...                   80
# 15                                   Ai93            ...                   80
# 16                                Rasgrf2            ...                   85
# 17                                 Rasgrf            ...                   80
# 18  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)            ...                   85
# 19  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)            ...                   85
# 20                               Sim1-Cre            ...                   85
# 21  Scnn1a-Tg3-Cre; Camk2a-tTa; Ai93 (NC)            ...                   82
# 22  Scnn1a-Tg3-Cre; Camk2a-tTa; Ai93 (NC)            ...                   85
# 23  Scnn1a-Tg3-Cre; Camk2a-tTa; Ai93 (NC)            ...                   85
# 24          Cux2-CreERT2; Camk2a-tTA;Ai93            ...                   85
# 25                           Cux2-CreERT2            ...                   85
# 26                           EmX-IRES-Cre            ...                   80
# 27                                  Nr5a1            ...                   85
# 28                              Ntsr1-Cre            ...                   85
# 29                              Nr5a1-Cre            ...                   85
# 30       Ntsr1-Cre; Camk2a-tTa; Ai93 (NC)            ...                   80
# 31       Ntsr1-Cre; Camk2a-tTa; Ai93 (NC)            ...                   80
# 32                                  nr5a1            ...                   80
# 33  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)            ...                   80
# 34  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)            ...                   80
# 35  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)            ...                   80
#
#    mouse_id                 mousenotes   owner reporter     sex tasktype  \
# 0   M272464  Additional information...  sissyc     None    Male     None
# 1   M271733  Additional information...  sissyc     None  Female     None
# 2   M271728  Additional information...  sissyc     None    Male     None
# 3   M276951  Additional information...  sissyc     None  Female     None
# 4   M276950  Additional information...  sissyc     None  Female     None
# 5   M276600  Additional information...  sissyc     None  Female     None
# 6   M272465  Additional information...  sissyc     None  Female     None
# 7   M265158  Additional information...  sissyc     None  Female     None
# 8   M271966  Additional information...  sissyc     None  Female     None
# 9   M265154  Additional information...  sissyc     None    Male     None
# 10  M258194  Additional information...  sissyc     None  Female     None
# 11  M265166  Additional information...  sissyc     None    Male     None
# 12  M258173  Additional information...  sissyc     None  Female     None
# 13  M258089  Additional information...  sissyc     None  Female     None
# 14  M258276  Additional information...  sissyc     None  Female     None
# 15  M261584  Additional information...  sissyc  GCaMP6+    Male     None
# 16  M258274  Additional information...  sissyc     None  Female     None
# 17  M258275  Additional information...  sissyc     None  Female     None
# 18  M246782  Additional information...  sissyc  GCaMP6+  Female     None
# 19  M249123  Additional information...  sissyc  GCaMP6+  Female     None
# 20  M258174  Additional information...  sissyc     None  Female     None
# 21  M250783  Additional information...  sissyc  GCaMP6-  Female     None
# 22  M250786  Additional information...  sissyc  GCaMP6+  Female     None
# 23  M258196  Additional information...  sissyc     None  Female     None
# 24  M273577  Additional information...  sissyc     None    Male     None
# 25  M273578  Additional information...  sissyc     None    Male     None
# 26  M278229  Additional information...  sissyc     None    Male     None
# 27  M276444  Additional information...  sissyc     None  Female     None
# 28  M275962  Additional information...  sissyc     None  Female     None
# 29  M276445  Additional information...  sissyc     None  Female     None
# 30  M275965  Additional information...  sissyc     None  Female     None
# 31  M275963  Additional information...  sissyc     None  Female     None
# 32  M277931  Additional information...  sissyc     None    Male     None
# 33  M278329  Additional information...  sissyc     None    Male     None
# 34  M278463  Additional information...  sissyc     None    Male     None
# 35  M278332  Additional information...  sissyc     None  Female     None
#
#    training_location  userid waterrestrictionstartdate
# 0               None  sissyc                2016-10-21
# 1               None  sissyc                2016-10-21
# 2               None  sissyc                2016-10-21
# 3               None  sissyc                2016-10-21
# 4               None  sissyc                2016-10-21
# 5               None  sissyc                2016-10-21
# 6               None  sissyc                2016-10-05
# 7               None  sissyc                2016-09-30
# 8               None  sissyc                2016-10-05
# 9               None  sissyc                2016-09-30
# 10              None  sissyc                2016-09-30
# 11              None  sissyc                2016-09-30
# 12              None  sissyc                2016-09-09
# 13              None  sissyc                2016-09-09
# 14              None  sissyc                2016-09-09
# 15              None  sissyc                2016-09-09
# 16              None  sissyc                2016-09-09
# 17              None  sissyc                2016-09-09
# 18              None  sissyc                2016-08-12
# 19              None  sissyc                2016-08-12
# 20              None  sissyc                2016-08-12
# 21              None  sissyc                2016-08-12
# 22              None  sissyc                2016-08-12
# 23              None  sissyc                2016-08-19
# 24              None  sissyc                2016-11-18
# 25              None  sissyc                2016-11-18
# 26              None  sissyc                2016-11-18
# 27              None  sissyc                2016-11-18
# 28              None  sissyc                2016-11-18
# 29              None  sissyc                2016-11-18
# 30              None  sissyc                2017-01-03
# 31              None  sissyc                2017-01-03
# 32              None  sissyc                2017-01-03
# 33              None  sissyc                2017-01-03
# 34              None  sissyc                2017-01-03
# 35              None  sissyc                2017-01-03
#
# [36 rows x 21 columns]

# %% [markdown]
# ## Load data

# %%
cohort_assignment.groupby('cohort')['group'].value_counts()
# Out:
# cohort  group
# 1       Scnn1a-Tg3-Cre; Camk2a-tTa; Ai93 (NC)    3
#         Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)    2
#         Sim1-Cre                                 1
# 2       Rasgrf                                   2
#         Ai93                                     1
#         Gnb4                                     1
#         Rasgrf2                                  1
#         Sim1-Cre                                 1
# 3       Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)    3
#         EMX-Cre-Ai35                             2
#         Scnn1a-Tg3-Cre; Camk2a-tTa; Ai93 (NC)    1
# 4       EMX-Cre-Ai35                             3
#         Nr5a1                                    2
#         Emx-IRES-Cre;Ai95(NC)                    1
# 5       Cux2-CreERT2                             1
#         Cux2-CreERT2; Camk2a-tTA;Ai93            1
#         EmX-IRES-Cre                             1
#         Nr5a1                                    1
#         Nr5a1-Cre                                1
#         Ntsr1-Cre                                1
# 6       Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)    3
#         Ntsr1-Cre; Camk2a-tTa; Ai93 (NC)         2
#         nr5a1                                    1
# Name: group, dtype: int64

# %%
from braintv_pilot import latest
latest.copy_latest()
# Out:
# copying 161219124658-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 161220141256-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 161221151523-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 161222142449-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 161223140829-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 170103144314-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 170104142719-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 170105132604-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 170106110606-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 170109133536-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 170110131936-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 170111140526-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 170112133529-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 170113121226-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M272464.pkl
# copying 170116135806-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M272464.pkl
# copying 161219125501-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 161220142041-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 161221154200-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 161222141250-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 161223134915-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 170103150843-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 170104143330-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 170105133755-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 170106112529-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 170109103519-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 170110100708-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 170111102241-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 170112101812-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 170113095415-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# copying 170116103724-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M271733.pkl
# copying 170117102052-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M271733.pkl
# copying 170118102157-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M271733.pkl
# copying 161219123857-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 161220141020-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 161221154412-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 161222140650-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 161223134841-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 170103145043-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 170104142252-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 170105131649-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 170106105742-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 170109133650-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 170110134920-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 170111135334-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 170112132109-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 170113113106-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# copying 170116134310-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M271728.pkl
# copying 161219130734-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 161220143137-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 161221153600-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 161222143846-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 161223141807-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 170103150931-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 170104144045-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 170105132607-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 170106112651-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 170109133824-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 170110135032-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 170111135329-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 170112132820-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 170113121541-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# copying 170116140257-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M276951.pkl
# copying 161219124345-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276950.pkl
# copying 161220140313-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276950.pkl
# copying 161221151104-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276950.pkl
# copying 161222140656-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276950.pkl
# copying 161223134835-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276950.pkl
# copying 170103145104-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276950.pkl
# copying 170104142258-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276950.pkl
# copying 170105131706-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M
task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258274.pkl
# copying 161219151642-task=DoC_MNIST_stage=0v1_n=3_mouse=M258275.pkl
# copying 161220145231-task=DoC_MNIST_stage=0v1v2_n=3_mouse=M258275.pkl
# copying 161221114554-task=DoC_MNIST_stage=0v1v2_n=3_mouse=M258275.pkl
# copying 161221122503-task=DoC_MNIST_stage=0v1v2_n=3_mouse=M258275.pkl
# copying 161222150524-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 161223111109-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 170103145026-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 170104152219-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 170105150052-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 170106150955-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 170109145006-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 170110150242-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 170111145902-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 170112145511-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 170113120117-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 170116152342-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 170117150631-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258275.pkl
# copying 161219131155-task=DoC_Gratings_multi_ori_multi_contrast_stage=2_LickDetectTraining_mouse=M258174.pkl
# copying 161220121843-task=DoC_Gratings_multi_ori_multi_contrast_stage=2_LickDetectTraining_mouse=M258174.pkl
# copying 161219131200-task=DoC_Gratings_multi_ori_multi_contrast_stage=2_LickDetectTraining_mouse=M250783.pkl
# copying 161220121846-task=DoC_Gratings_multi_ori_multi_contrast_stage=2_LickDetectTraining_mouse=M250783.pkl
# copying 161219131924-task=DoC_Gratings_multi_ori_multi_contrast_stage=2_LickDetectTraining_mouse=M250786.pkl
# copying 161220122315-task=DoC_Gratings_multi_ori_multi_contrast_stage=2_LickDetectTraining_mouse=M250786.pkl
# copying 161219131151-task=DoC_Gratings_multi_ori_multi_contrast_stage=2_LickDetectTraining_mouse=M258196.pkl
# copying 161220121841-task=DoC_Gratings_multi_ori_multi_contrast_stage=2_LickDetectTraining_mouse=M258196.pkl
# copying 161220103218-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 161221142810-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 161222102937-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 161223105516-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 170103141332-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 170104103559-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 170105105352-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 170106104428-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 170109120719-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 170110105801-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 170111105155-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 170112103915-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 170113102014-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# copying 170116103243-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M273577.pkl
# copying 170117130012-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M273577.pkl
# copying 161220104925-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 161221142714-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 161222105536-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 161223113311-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 170103141250-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 170104104239-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 170105105249-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 170106104316-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 170109113821-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 170110105427-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 170111105000-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 170112101853-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 170113094850-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273578.pkl
# copying 170116103136-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M273578.pkl
# copying 170117125938-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M273578.pkl
# copying 161220104646-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 161221140931-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 161222101759-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 161223110045-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 170103140101-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 170104102323-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 170105101859-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 170106103207-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 170109120000-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 170110110015-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 170111105357-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 170112104204-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 170113102247-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# copying 170116103419-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M278229.pkl
# copying 170117130122-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M278229.pkl
# copying 161220105201-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 161221142641-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 161222104456-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 161223105520-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 170103141153-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 170104101211-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 170105101623-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 170106100717-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 170109113709-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 170110103906-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 170111104754-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 170112104629-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 170113100257-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# copying 170116103050-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M276444.pkl
# copying 170117125821-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M276444.pkl
# copying 161220102050-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 161221142938-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 161222103623-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 161223110042-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 170103141033-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 170104095954-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 170105102215-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 170106101410-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 170109114136-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 170110104212-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 170111103139-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 170112103933-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 170113102458-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M275962.pkl
# copying 170116102609-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M275962.pkl
# copying 170117130239-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M275962.pkl
# copying 161220103214-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 161221143018-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 161222103205-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 161223112630-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 170103140536-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 170104100454-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 170105102217-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 170106102857-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 170109114138-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 170110103525-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 170111105804-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 170112104514-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 170113095721-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# copying 170116102606-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M276445.pkl
# copying 170117130337-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M276445.pkl
# copying 170116112904-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# copying 170116121443-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# copying 170117140749-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# copying 170116112722-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275963.pkl
# copying 170116121258-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275963.pkl
# copying 170117141938-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275963.pkl
# copying 170116111600-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M277931.pkl
# copying 170116120709-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M277931.pkl
# copying 170117141409-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M277931.pkl
# copying 170116112506-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278329.pkl
# copying 170116121048-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278329.pkl
# copying 170117142051-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278329.pkl
# copying 170116112236-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278463.pkl
# copying 170116120821-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278463.pkl
# copying 170117141414-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278463.pkl
# copying 170116111935-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# copying 170116120723-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# copying 170117141411-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl

# %%
from braintv_pilot.latest import local_dir
trials = dro.load_from_folder(local_dir)
# Out:
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170113100257-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170109102611-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M272465.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170111135329-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170111135334-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/161220142041-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170111150421-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M261584.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170117130239-task=DoC_NaturalImages_n=8_stage=Testing_mouse=M275962.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170110103525-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276445.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/161219131155-task=DoC_Gratings_multi_ori_multi_contrast_stage=2_LickDetectTraining_mouse=M258174.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170109102346-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M271966.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/161220105201-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276444.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170110101016-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276600.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170110101810-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258194.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/161220103805-task=DoC_MNIST_stage=0v1v2_n=3_mouse=M272465.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170104103559-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170113102247-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M278229.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170104142252-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271728.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170116152342-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M261584.pkl
# error loading file 161107125855-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276600.pkl:
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/161222140656-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276950.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170112132820-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276951.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/161221114554-task=DoC_MNIST_stage=0v1v2_n=3_mouse=M258275.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/161223112701-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258089.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170116121048-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278329.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170109102805-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258194.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/161223111043-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258173.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170112103915-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M273577.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/161223134915-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M271733.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170117141938-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275963.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/161222150842-task=DoC_MNIST_stage=0v1_probes_n=3_mouse=M258173.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170103150843-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M
#  u'M271966': '2016-10-10',
#  u'M272464': '2016-10-31',
#  u'M272465': '2016-10-10',
#  u'M273577': '2016-11-28',
#  u'M273578': '2016-11-28',
#  u'M275962': '2016-11-28',
#  u'M275963': '2017-01-16',
#  u'M275965': '2017-01-16',
#  u'M276444': '2016-11-28',
#  u'M276445': '2016-11-28',
#  u'M276600': '2016-10-31',
#  u'M276950': '2016-10-31',
#  u'M276951': '2016-10-31',
#  u'M277931': '2017-01-16',
#  u'M278229': '2016-11-28',
#  u'M278329': '2017-01-16',
#  u'M278332': '2017-01-16',
#  u'M278463': '2017-01-16'}

# %%
def get_training_day(df_in):
    '''adds a column to the dataframe with the number of unique training days up to that point
         '''
    coh = cohort_assignment.set_index('mouse')['cohort']
#     print coh

    training_day_lookup = {}
    for mouse, group in df_in.groupby('mouse_id'):
        dates = np.sort(group['date'].unique())
        try:
            dz = day_zero[mouse]
            offset = np.argwhere(dates==dz)[0][0]
        except KeyError:
            print 'day zero not found for {}'.format(mouse)
            offset = 0
        except IndexError:
            print 'day zero ({}) not found in dates'.format(dz)
            offset = 0
        print offset
        training_day_lookup[mouse] = {date:training_day-offset for training_day,date in enumerate(dates)}
        print mouse,dates
    return df_in.apply(lambda row: training_day_lookup[row['mouse_id']][row['date']],axis=1)

trials['training_day'] = get_training_day(trials)

#df['day_of_week'] = df.startdatetime.dt.weekday_name

## build arrays for change detection

# df['change'] = ~df['change_frame'].isnull()
trials['change'] = trials['trial_type']=='go'
trials['detect'] = trials['response']==1.0

## calculate reaction times

trials['reaction_time'] = trials['lick_times'].map(lambda x: x[0] if len(x)>0 else np.nan)
trials['reaction_time'] = trials.apply(lambda row: row['reaction_time'] - row['change_time'],axis=1)

## unwrap the response window
trials['response_window_lower'] = trials['response_window'].map(lambda x: x[0])
trials['response_window_upper'] = trials['response_window'].map(lambda x: x[1])
# Out:
# 0
# M246782 ['2016-08-22' '2016-08-23' '2016-08-24' '2016-08-25' '2016-08-26'
#  '2016-08-29' '2016-08-30' '2016-08-31' '2016-09-02' '2016-09-06'
#  '2016-09-07' '2016-09-08' '2016-09-09' '2016-09-12' '2016-09-13'
#  '2016-09-14' '2016-09-15' '2016-09-16' '2016-09-19' '2016-09-20']
# 0
# M249123 ['2016-08-22' '2016-08-23' '2016-08-24' '2016-08-25' '2016-08-26'
#  '2016-08-29' '2016-08-30' '2016-08-31' '2016-09-02' '2016-09-06'
#  '2016-09-07' '2016-09-08' '2016-09-09' '2016-09-12' '2016-09-13'
#  '2016-09-15' '2016-09-16' '2016-09-19' '2016-09-20']
# 0
# M250783 ['2016-08-22' '2016-08-23' '2016-08-24' '2016-08-25' '2016-08-26'
#  '2016-08-29' '2016-08-30' '2016-08-31' '2016-09-02' '2016-09-06'
#  '2016-09-07' '2016-09-08' '2016-09-09' '2016-09-12' '2016-09-13'
#  '2016-09-14' '2016-09-15' '2016-09-16' '2016-09-19' '2016-09-20'
#  '2016-09-21' '2016-09-22' '2016-09-23' '2016-09-26' '2016-09-27'
#  '2016-09-28' '2016-09-29' '2016-09-30' '2016-10-03' '2016-10-05'
    return np.nanmax(dp[int(len(dp)/3):])

# %%
def compute_metrics(group):
    result = {
        'accuracy': metrics.discrim(group,'change','detect',metric=accuracy_score),
        'd-prime': metrics.discrim(group,'change','detect',metric=metrics.d_prime),
        'd-prime_peak': peak_dprime(group),
        'discrim_p': metrics.discrim(group,'change','detect',metric=metrics.discrim_p),
        'response_bias': metrics.response_bias(group,'detect'),
        'earned_water': metrics.earned_water(group), 
        'total_water': metrics.total_water(group), 
        'num_trials': metrics.num_trials(group),
        'num_contingent_trials': metrics.num_contingent_trials(group),
        'reaction_time_50th%ile': metrics.reaction_times(group,percentile=50),
        'reaction_time_05th%ile': metrics.reaction_times(group,percentile=5),
        'reaction_time_95th%ile': metrics.reaction_times(group,percentile=95),
    }
    
    return pd.Series(result, name='metrics')

water = trials.groupby(['cohort','mouse_id','training_day']).apply(compute_metrics).reset_index()
water['frac_earned_water'] = water['earned_water'] / water['total_water']
water['reaction_time_spread'] = water['reaction_time_95th%ile'] - water['reaction_time_05th%ile']
water.head()
# Out:
# /home/justink/Code/behaviorist/behaviorist/metrics.py:15: RuntimeWarning: invalid value encountered in double_scalars
#   FAR = fp / (tn + fp)
# /home/justink/Code/dro/dro/utilities.py:516: RuntimeWarning: invalid value encountered in greater
#   v[v>ceiling]=ceiling
# /home/justink/Code/dro/dro/utilities.py:517: RuntimeWarning: invalid value encountered in less
#   v[v<floor]=floor
# /home/justink/.conda/envs/braintv_behav/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1897: RuntimeWarning: invalid value encountered in greater
#   cond1 = (0 < q) & (q < 1)
# /home/justink/.conda/envs/braintv_behav/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1897: RuntimeWarning: invalid value encountered in less
#   cond1 = (0 < q) & (q < 1)
# /home/justink/.conda/envs/braintv_behav/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:343: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)
# /home/justink/Code/behaviorist/behaviorist/metrics.py:90: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   return behav_df[mask][(behav_df['reward_times'].map(len)>0)]['reward_volume'].sum()
# metrics  cohort mouse_id  training_day  accuracy   d-prime  d-prime_peak  \
# 0           1.0  M246782             0  0.544872       NaN           NaN
# 1           1.0  M246782             1  0.219101 -0.057545      0.256948
# 2           1.0  M246782             2  0.264957 -0.803594     -0.346402
# 3           1.0  M246782             3  0.241935 -0.025337      0.589474
# 4           1.0  M246782             4  0.312849 -0.262469     -0.032233
#
# metrics  discrim_p  earned_water  num_contingent_trials  num_trials  \
# 0         1.000000         1.092                  156.0       157.0
# 1         0.946458         0.354                  356.0      1563.0
# 2         0.076643         0.198                  117.0       394.0
# 3         0.783441         0.276                  186.0       426.0
# 4         0.681377         0.530                  179.0       423.0
#
# metrics  reaction_time_05th%ile  reaction_time_50th%ile  \
# 0                     -5.020008                0.334217
# 1                      0.161557                1.286406
# 2                      0.208261                1.360493
# 3                      0.087997                1.401724
# 4                      0.150696                1.343656
#
# metrics  reaction_time_95th%ile  response_bias  total_water  \
# 0                      3.778943       0.544872        1.092
# 1                      4.141207       0.171348        0.354
# 2                      5.292036       0.273504        0.198
# 3                      4.474582       0.193548        0.276
# 4                      4.549200       0.296089        0.530
#
# metrics  frac_earned_water  reaction_time_spread
# 0                      1.0              8.798951
# 1                      1.0              3.979650
# 2                      1.0              5.083775
# 3                      1.0              4.386585
# 4                      1.0              4.398504

# %%
sns.jointplot('d-prime','d-prime_peak',data=water)

# %%
jp = sns.jointplot('reaction_time_50th%ile','d-prime',data=water,
                   stat_func=None,
             )
jp.ax_joint.axhspan(-0.5,0.5,color='0.5',alpha=0.5,zorder=-2)
jp.ax_joint.axhline(0.0,color='0.5',zorder=-1)

plt.savefig('../figures/d_prime_by_reaction_time.pdf')

jp = sns.jointplot('response_bias','d-prime',data=water,
             )
jp.ax_joint.axhspan(-1,1,color='0.5',alpha=0.5,zorder=-2)
jp.ax_joint.axhline(0.0,color='0.5',zorder=-1)


jp = sns.jointplot('accuracy','d-prime',data=water,
             )
jp.ax_joint.axhspan(-1,1,color='0.5',alpha=0.5,zorder=-2)
jp.ax_joint.axhline(0.0,color='0.5',zorder=-1)

# %%
def stars(p,ns='n.s.',thresh=(0.1,0.05,0.01,0.001)):
    '''Converts p-values into R-styled stars.
    Signif. codes:
        '***' :  < 0.001
        '**' : < 0.01
        '*' : < 0.05
        '.' : < 0.1
        'n.s.' : < 1.0
    '''
    lookup = (
        (0.001, '***'),
        (0.01, '**'),
        (0.05, '*'),
        (0.1, '.'),
    )
    for t,s in lookup:
        if (t in thresh) and (p < t):
            return s
    return ns

def plot_stars(p,x,y,ax,ns='n.s.',thresh=(0.1,0.05,0.01,0.001),size='large',horizontalalignment='center',**kwargs):
    ''' Plots significance stars '''
    ax.text(x,y,stars(p,ns,thresh),size=size,horizontalalignment=horizontalalignment,**kwargs)

def plot_linestar(p,x1,x2,y,ax):
    ax.hlines(y, x1, x2)
    plot_stars(0.5*(x1+x2),y+0.02,stars(p),ax=ax,size='large',horizontalalignment='center')

# %%
class RisingEdge():
    """
    This object implements a "rising edge" detector on a boolean array.
    
    It takes advantage of how pandas applies functions in order.
    
    For example, if the "criteria" column in the `df` dataframe consists of booleans indicating
    whether the row meets a criterion, we can detect the first run of three rows above criterion
    with the following
    
        first_run_of_three = (
            df['criteria']
            .rolling(center=False,window=3)
            .apply(func=RisingEdge().check)
            )
    
    ```
    
    """
    def __init__(self):
        self.firstall = False
    def check(self,arr):
        if arr.all():
            self.firstall = True
        return self.firstall

# %%
pdf = water
pdf['d_prime'] = pdf['d-prime']
pdf['d_prime_peak'] = pdf['d-prime_peak']
pdf['stimulus_control'] = pdf['discrim_p'] < 0.01

# %%
num_tr_thresh = 20
dprime_thresh = 0.5

consecutive_sessions = 2

pdf['criteria'] = (
    pdf['stimulus_control']
    & (pdf['num_contingent_trials'] > num_tr_thresh)
    & (pdf['d_prime'] > dprime_thresh)
)

mask = pdf.num_trials > num_tr_thresh # ignore sessions with very few trials

first = {}

for key, group in pdf[mask].set_index('training_day').sort_index().groupby(['cohort','mouse_id']):
#     print group.head()
    learned = (
        group['criteria']
        .rolling(center=False,window=consecutive_sessions)
        .apply(func=RisingEdge().check)
        )
    summary = pd.DataFrame(
        [learned.rename('learned'),
         group['stimulus_control'],
         group['d_prime'],
         group['num_trials'],
        ]).transpose()
    
    try:
        first_session = summary['learned'][summary['learned']==1.0].index[0] +(1-consecutive_sessions)
    except IndexError:
        first_session = np.nan
    
    print key, first_session
#     print summary.tail()
    
    first[key[1]]=first_session
    
def learned(row):
    first_day = first[row['mouse_id']]
    
    if pd.isnull(first_day):
        return False
    else: 
        return (first_day <= row['training_day'])
    
pdf['learned'] = pdf.apply(learned,axis=1)
# Out:
# (1.0, 'M246782') 18
# (1.0, 'M249123') nan
# (1.0, 'M250783') 8
# (1.0, 'M250786') 8
# (1.0, 'M258174') 3
# (1.0, 'M258196') 7
# (2.0, 'M258089') 10
# (2.0, 'M258173') 21
# (2.0, 'M258274') 4
# (2.0, 'M258275') 7
# (2.0, 'M258276') 36
# (2.0, 'M261584') 9
# (3.0, 'M258194') 5
# (3.0, 'M265154') nan
# (3.0, 'M265158') 24
# (3.0, 'M265166') nan
# (3.0, 'M271966') 10
# (3.0, 'M272465') 11
# (4.0, 'M271728') 4
# (4.0, 'M271733') 9
# (4.0, 'M272464') 5
# (4.0, 'M276600') 3
# (4.0, 'M276950') 5
# (4.0, 'M276951') 3
# (5.0, 'M273577') 3
# (5.0, 'M273578') 10
# (5.0, 'M275962') 8
# (5.0, 'M276444') 19
# (5.0, 'M276445') 6
# (5.0, 'M278229') 2
# (6.0, u'M275963') nan
# (6.0, u'M275965') nan
# (6.0, u'M277931') nan
# (6.0, u'M278329') nan
# (6.0, u'M278332') nan
# (6.0, u'M278463') nan

# %%
# trials[trials.cohort=='Cohort 3'].groupby(['mouse_id'])['date'].min()

# %%
col_order = cohort_assignment.sort_values('cohort')['mouse_id']

mask = (
    (pdf.training_day >= 0)
    & (pdf.training_day < 15)
    )

fp = sns.factorplot('training_day','d_prime_peak',data=pdf[mask],
                    col='mouse_id',
                    col_wrap=3,
                    size=2,
                    aspect=1.5,
                    hue='cohort',
                    col_order=col_order,
              )

yloc = -1.5

for ax,mouse_id in zip(fp.axes.ravel(),col_order):
    ax.axhline(0.0,color='0.5',zorder=-1)
    ax.axhspan(-dprime_thresh,dprime_thresh,color='0.5',alpha=0.5,zorder=-1)
#     print mouse_id
    for r,row in pdf[mask & (pdf['mouse_id']==mouse_id)].iterrows():
        p, x = row['discrim_p'], row['training_day']
        plot_stars(p,x,yloc,ax,ns='',thresh=(0.05,))
    ax.axvline(first[mouse_id],color='r',zorder=-1)
    
sns.despine(bottom=True)
# plt.xlim(0,8)


plt.savefig('../figures/d_prime_by_training_day_individ.pdf')

# %%
pdf['cohort'] = pdf['cohort'].map(int)

# %%
mask = (
#     (pdf.num_trials > num_tr_thresh) # ignore sessions with very few trials
#     & (pdf.training_day <= pdf.groupby('mouse_id')['training_day'].max().min())
    (pdf.training_day >= 0)
    & (pdf.training_day <= 15)
    )

fp = sns.factorplot('training_day','d_prime',data=pdf[mask],
                    hue='mouse_id',
                    col_wrap=3,
                    size=3,
#                     aspect=2,
                    col='cohort',
#                     col_order=col_order,
              )

for ax in fp.axes.flatten():
    ax.axhline(0.0,color='0.7')
    ax.axhspan(-0.5,0.5,color='0.5',alpha=0.5,zorder=-10)
plt.ylim(-1,4)

plt.savefig('../figures/d_prime_by_training_day.pdf')

# fp = sns.factorplot('training_day','learned',data=pdf[mask],
#                     hue='mouse_id',
#                     col_wrap=3,
#                     size=3,
# #                     aspect=2,
#                     col='cohort',
# #                     col_order=col_order,
#                     legend=False,
#               )

# fp = sns.factorplot('training_day','learned',data=pdf[mask],
# #                     hue='mouse_id',
#                     col_wrap=3,
#                     size=3,
# #                     aspect=2,
#                     col='cohort',
# #                     col_order=col_order,
#                     legend=False,
#               )

# %%
mask = (
#     (pdf.num_trials > num_tr_thresh) # ignore sessions with very few trials
#     & (pdf.training_day <= pdf.groupby('mouse_id')['training_day'].max().min())
    (pdf.training_day >= 0)
    & (pdf.training_day <= 19)
)

g = sns.factorplot('training_day','d_prime',data=pdf[mask],
                    size=4,
                    aspect=1.2,
                    hue='cohort',
                    kind='strip',  
                    legend=True,
                    alpha=0.5,
                    palette='Dark2'
              )

g.map_dataframe(sns.pointplot,'training_day','d_prime',
                hue='cohort',
                palette='Dark2',
                zorder=1000,
                ci=None,
                )
g.set_axis_labels('Training Day', 'd\'')
g.fig.get_children()[-1].set_bbox_to_anchor((1.15, 0.5, 0, 0))
# g.fig.get_children()[-1].set_title('')


for ax in g.axes.ravel():
    ax.axhline(0.0,color='0.5',zorder=-10)
    ax.axhspan(-0.5,0.5,color='0.5',alpha=0.2,zorder=-10)

plt.savefig('../figures/d_prime_by_training_day_cohort_means.pdf')

# %%
mask = (
#     (pdf.num_trials > num_tr_thresh) # ignore sessions with very few trials
#     & (pdf.training_day <= pdf.groupby('mouse_id')['training_day'].max().min())
    (pdf.training_day >= 0)
    & (pdf.training_day <= 15)
    & pdf.cohort.isin((3,4))
    )

fp = sns.factorplot('training_day','d_prime',data=pdf[mask],
                    hue='mouse_id',
#                     col_wrap=3,
                    size=3,
#                     aspect=2,
                    col='cohort',
                    palette='coolwarm',
#                     col_order=col_order,
              )

for ax in fp.axes.flatten():
    ax.axhline(0.0,color='0.2',zorder=-1)
    ax.axhspan(-0.5,0.5,color='0.5',alpha=0.2,zorder=-10)
plt.ylim(-1,4)
fp.set_axis_labels('Training Day','d\'')

plt.savefig('../figures/d_prime_by_training_day_cohorts3and4.pdf')

# %%
mask = (
#     (pdf.num_trials > num_tr_thresh) # ignore sessions with very few trials
#     & (pdf.training_day <= pdf.groupby('mouse_id')['training_day'].max().min())
    (pdf.training_day >= 0)
    & (pdf.training_day <= 15)
)

g = sns.factorplot('training_day','learned',data=pdf[mask],
                   size=3,
                   aspect=2,
                   hue='cohort',
                   ci=False,  
                   legend=True,
                   palette='Dark2'
              )

g.set_axis_labels('Training Day','Fraction Learned')
plt.ylim(-0.1,1.1)
sns.despine(trim=True)

# g.map_dataframe(sns.pointplot,'training_day','d_prime',
#                 hue='cohort',
#                 palette='Dark2',
#                 zorder=1000,
#                 ci=None,
#                 )
# g.set_axis_labels('Training Day', 'd\'')
# g.fig.get_children()[-1].set_bbox_to_anchor((1.15, 0.5, 0, 0))
# # g.fig.get_children()[-1].set_title('')


# for ax in g.axes.ravel():
#     ax.axhline(0.0,color='0.5',zorder=-10)
#     ax.axhspan(-0.5,0.5,color='0.5',alpha=0.2,zorder=-10)

plt.savefig('../figures/cohort_survival.pdf')

# %%
trials[trials.trial_type=='catch'][['trial_type','reward_volume']].head(30)
# Out:
#      trial_type  reward_volume
# 785       catch          0.006
# 814       catch          0.006
# 815       catch          0.006
# 817       catch          0.006
# 820       catch          0.006
# 826       catch          0.006
# 833       catch          0.006
# 839       catch          0.006
# 887       catch          0.006
# 890       catch          0.006
# 900       catch          0.006
# 916       catch          0.006
# 928       catch          0.006
# 933       catch          0.006
# 971       catch          0.006
# 994       catch          0.006
# 1014      catch          0.006
# 1046      catch          0.006
# 1066      catch          0.006
# 1088      catch          0.006
# 1115      catch          0.006
# 1144      catch          0.006
# 1166      catch          0.006
# 1171      catch          0.006
# 1173      catch          0.006
# 1192      catch          0.006
# 1215      catch          0.006
# 1233      catch          0.006
# 1246      catch          0.006
# 1272      catch          0.006

# %%
trials.columns
# Out:
# Index([                 u'LDT_mode',             u'auto_rewarded',
#             u'blank_duration_range',      u'blank_screen_timeout',
#                     u'change_color',           u'change_contrast',
#                     u'change_frame',              u'change_image',
#            u'change_image_category',         u'change_image_name',
#                       u'change_ori',               u'change_size',
#                      u'change_time',                     u'color',
#                    u'computer_name',         u'cumulative_volume',
#                             u'date',                       u'day',
#                        u'dayofweek',                 u'delta_ori',
#                u'distribution_mean',                  u'endframe',
#                         u'filename',                  u'filepath',
#                             u'hour',                     u'index',
#                     u'inital_color',           u'inital_contrast',
#            u'inital_image_category',         u'inital_image_name',
#                 u'initial_contrast',             u'initial_image',
#           u'initial_image_category',        u'initial_image_name',
#                      u'initial_ori',              u'initial_size',
#                      u'lick_frames',                u'lick_times',
#                u'mnist_probe_trial',                     u'month',
#                         u'mouse_id',         u'number_of_rewards',
#                     u'optogenetics',         u'prechange_minimum',
#                         u'response',          u'response_latency',
#                    u'response_time',             u'response_type',
#                  u'response_window',             u'reward_frames',
#                      u'reward_rate',              u'reward_times',
#                    u'reward_volume',                  u'rewarded',
#                           u'rig_id',     u'scheduled_change_time',
#                 u'session_duration',                     u'stage',
#                    u'startdatetime',                u'startframe',
#                        u'starttime',             u'stim_duration',
#                   u'stim_on_frames',     u'stimulus_distribution',
#                             u'task',              u'training_day',
#                   u'trial_duration',              u'trial_length',
#                       u'trial_type',                   u'user_id',
#                             u'year',                     u'mouse',
#                       u'experiment',                    u'cohort',
#                         u'day_zero',            u'baselineweight',
#                        u'birthdate',              u'dayonescript',
#                          u'driver1',                   u'driver2',
#                            u'group',            u'iacuc_protocol',
#                        u'minweight',                u'mousenotes',
#                            u'owner',                  u'reporter',
#                              u'sex',                  u'tasktype',
#                u'training_location',                    u'userid',
#        u'waterrestrictionstartdate',                    u'change',
#                           u'detect',             u'reaction_time',
#            u'response_window_lower',     u'response_window_upper'],
#       dtype='object')
