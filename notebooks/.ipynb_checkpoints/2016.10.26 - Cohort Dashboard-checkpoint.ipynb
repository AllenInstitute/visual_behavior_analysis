# %% [markdown]
# Justin Kiggins
#
# Oct 24, 2016
#
# [justink@alleninstitute.org](mailto:justink@alleninstitute.org)
#
# Summary of learning on cohorts 1-3 on the Detection of Change task.

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# import sys
# sys.path.append(r'C:\Users\justink\Code\dro')

from braintv_behav import utilities as dro
from braintv_behav import plotting as dro_plots
# Out:
# /home/justink/.conda/envs/braintv_behav/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/justink/.conda/envs/braintv_behav/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# failed to import CV2 in core.utilities
# failed to import mask in core.jcamdata.py
# failed to import get_mask_dict_gui in core.epoch.py
# failed to import aibs.Analysis.Core.smooth
# failed to import mask relalated functions in __init__.py

# %%
from braintv_behav.cohorts import cohort_assignment
cohort_assignment
# Out:
#       mouse                   experiment  cohort   day_zero mtrain_regimen
# 0   M272464  visual_behavior_development       4 2016-10-31            NaN
# 1   M271733  visual_behavior_development       4 2016-10-31            NaN
# 2   M271728  visual_behavior_development       4 2016-10-31            NaN
# 3   M276951  visual_behavior_development       4 2016-10-31            NaN
# 4   M276950  visual_behavior_development       4 2016-10-31            NaN
# 5   M276600  visual_behavior_development       4 2016-10-31            NaN
# 6   M272465  visual_behavior_development       3 2016-10-10            NaN
# 7   M265158  visual_behavior_development       3 2016-10-10            NaN
# 8   M271966  visual_behavior_development       3 2016-10-10            NaN
# 9   M265154  visual_behavior_development       3 2016-10-10            NaN
# 10  M258194  visual_behavior_development       3 2016-10-10            NaN
# 11  M265166  visual_behavior_development       3 2016-10-10            NaN
# 12  M258173  visual_behavior_development       2 2016-09-19            NaN
# 13  M258089  visual_behavior_development       2 2016-09-19            NaN
# 14  M258276  visual_behavior_development       2 2016-09-19            NaN
# 15  M261584  visual_behavior_development       2 2016-09-19            NaN
# 16  M258274  visual_behavior_development       2 2016-09-19            NaN
# 17  M258275  visual_behavior_development       2 2016-09-19            NaN
# 18  M246782  visual_behavior_development       1 2016-08-22            NaN
# 19  M249123  visual_behavior_development       1 2016-08-22            NaN
# 20  M258174  visual_behavior_development       1 2016-08-22            NaN
# 21  M250783  visual_behavior_development       1 2016-08-22            NaN
# 22  M250786  visual_behavior_development       1 2016-08-22            NaN
# 23  M258196  visual_behavior_development       1 2016-08-22            NaN
# 24  M273577  visual_behavior_development       5 2016-11-28            NaN
# 25  M273578  visual_behavior_development       5 2016-11-28            NaN
# 26  M278229  visual_behavior_development       5 2016-11-28            NaN
# 27  M276444  visual_behavior_development       5 2016-11-28            NaN
# 28  M275962  visual_behavior_development       5 2016-11-28            NaN
# 29  M276445  visual_behavior_development       5 2016-11-28            NaN
# 30  M275965  visual_behavior_development       6 2017-01-16            NaN
# 31  M275963  visual_behavior_development       6 2017-01-16            NaN
# 32  M277931  visual_behavior_development       6 2017-01-16            NaN
# 33  M278329  visual_behavior_development       6 2017-01-16            NaN
# 34  M278463  visual_behavior_development       6 2017-01-16            NaN
# 35  M278332  visual_behavior_development       6 2017-01-16            NaN
# 36  M278460  visual_behavior_development       7 2017-02-13        cohort7
# 37  M276953  visual_behavior_development       7 2017-02-13        cohort7
# 38  M274438  visual_behavior_development       7 2017-02-13        cohort7
# 39  M274439  visual_behavior_development       7 2017-02-13        cohort7
# 40  M294753  visual_behavior_development       7 2017-02-13        cohort7
# 41  M294759  visual_behavior_development       7 2017-02-13        cohort7
# 42  M289734                        rylan       7 2017-02-27   cohort7habit
# 43  M289737                        rylan       7 2017-02-27   cohort7habit
# 44  M289738                        rylan       7 2017-02-27   cohort7habit
# 45  M278461  visual_behavior_development       7 2017-03-06   cohort7habit
# 46  M278465  visual_behavior_development       7 2017-03-06   cohort7habit
# 47  M278710  visual_behavior_development       7 2017-03-06   cohort7habit
# 48  M279219  visual_behavior_development       7 2017-03-06   cohort7habit
# 49  M279220  visual_behavior_development       7 2017-03-06   cohort7habit
# 50  M279222  visual_behavior_development       7 2017-03-06   cohort7habit
# 51  M282821  visual_behavior_development       8 2017-03-20        cohort8
# 52  M282822  visual_behavior_development       8 2017-03-20        cohort8
# 53  M284728  visual_behavior_development       8 2017-03-20        cohort8
# 54  M297953  visual_behavior_development       8 2017-03-20        cohort8
# 55  M293817  visual_behavior_development       8 2017-03-20        cohort8
# 56  M293818  visual_behavior_development       8 2017-03-20        cohort8

# %%
from braintv_behav import latest

# %%
latest.local_dir
# Out:
# '/local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw'

# %%
from braintv_behav.cohorts import mouse_info
mouse_df = cohort_assignment['mouse'].apply(lambda mouse: pd.Series(mouse_info(mouse)))
cohort_assignment = cohort_assignment.merge(
    mouse_df,
    how='left',
    left_on='mouse',
    right_on='mouse_id'
)

# %%
cohort_assignment.head()
# Out:
#      mouse                   experiment  cohort   day_zero mtrain_regimen  \
# 0  M272464  visual_behavior_development       4 2016-10-31            NaN
# 1  M271733  visual_behavior_development       4 2016-10-31            NaN
# 2  M271728  visual_behavior_development       4 2016-10-31            NaN
# 3  M276951  visual_behavior_development       4 2016-10-31            NaN
# 4  M276950  visual_behavior_development       4 2016-10-31            NaN
#
#   baselineweight   birthdate dayonescript driver1 driver2  \
# 0           20.2  2016-08-24                 None    None
# 1           20.4  2016-08-01                 None    None
# 2           23.0  2016-08-01                 None    None
# 3           20.8  2016-08-27                 None    None
# 4           20.4  2016-08-27                 None    None
#
#              ...            minweight mouse_id                 mousenotes  \
# 0            ...                   85  M272464  Additional information...
# 1            ...                   85  M271733  Additional information...
# 2            ...                   85  M271728  Additional information...
# 3            ...                   81  M276951  Additional information...
# 4            ...                   85  M276950  Additional information...
#
#     owner reporter     sex tasktype training_location  userid  \
# 0  sissyc     None    Male     None              None  sissyc
# 1  sissyc     None  Female     None              None  sissyc
# 2  sissyc     None    Male     None              None  sissyc
# 3  sissyc     None  Female     None              None  sissyc
# 4  sissyc     None  Female     None              None  sissyc
#
#   waterrestrictionstartdate
# 0                2016-10-21
# 1                2016-10-21
# 2                2016-10-21
# 3                2016-10-21
# 4                2016-10-21
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Load data

# %%
cohort_assignment.groupby('cohort')['group'].value_counts()
# Out:
# cohort  group
# 1       Scnn1a-Tg3-Cre; Camk2a-tTa; Ai93 (NC)    3
#         Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)    2
#         Sim1-Cre                                 1
# 2       Rasgrf                                   2
#         Ai93                                     1
#         Gnb4                                     1
#         Rasgrf2                                  1
#         Sim1-Cre                                 1
# 3       Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)    3
#         EMX-Cre-Ai35                             2
#         Scnn1a-Tg3-Cre; Camk2a-tTa; Ai93 (NC)    1
# 4       EMX-Cre-Ai35                             3
#         Nr5a1                                    2
#         Emx-IRES-Cre;Ai95(NC)                    1
# 5       Cux2-CreERT2                             1
#         Cux2-CreERT2; Camk2a-tTA;Ai93            1
#         EmX-IRES-Cre                             1
#         Nr5a1                                    1
#         Nr5a1-Cre                                1
#         Ntsr1-Cre                                1
# 6       Ntsr1-Cre; Camk2a-tTa; Ai93 (NC)         2
#         Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)    2
#         Emx1-IRES-Cre; Camk2a-tTA; Ai93          1
#         nr5a1                                    1
# 7       None                                     4
#         Chat-IRES-Cre-neo,Ai148                  3
#         EMX-Cre-Ai35                             3
#         VGAT ChR2                                3
#         Emx1-IRES-Cre; Camk2a-tTA; Ai93          1
#         TetO                                     1
# 8       Cux2-CreERT2; Camk2a-tTA;Ai93            2
#         Emx1-IRES-Cre; Camk2a-tTA; Ai93          2
#         VGAT ChR2                                2
# Name: group, dtype: int64

# %%
from braintv_behav import latest
latest.copy_latest()
# Out:
# copying 170321101215-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M271733.pkl
# copying 170322101659-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M271733.pkl
# copying 170321095624-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M276950.pkl
# copying 170322101516-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M276950.pkl
# copying 170321101530-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M276600.pkl
# copying 170322102045-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M276600.pkl
# copying 170321100900-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M271966.pkl
# copying 170322101318-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M271966.pkl
# copying 170321101357-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M258194.pkl
# copying 170322101841-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M258194.pkl
# copying 170320144550-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M273577.pkl
# copying 170321143255-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M273577.pkl
# copying 170320144429-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M273578.pkl
# copying 170321143112-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M273578.pkl
# copying 170320144334-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M276444.pkl
# copying 170321143041-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M276444.pkl
# copying 170320153216-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M278460.pkl
# copying 170321153537-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M278460.pkl
# copying 170320153057-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M276953.pkl
# copying 170321153430-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M276953.pkl
# copying 170320152912-task=DetectionOfChange_General_stage=static_windowed_gratings_flash_500ms_mouse=M274438.pkl
# copying 170321153312-task=DetectionOfChange_General_stage=static_windowed_gratings_flash_500ms_mouse=M274438.pkl
# copying 170320153502-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M274439.pkl
# copying 170321153717-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M274439.pkl
# copying 170320153354-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M294753.pkl
# copying 170321153631-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M294753.pkl
# copying 170320153015-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M294759.pkl
# copying 170321153346-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M294759.pkl
# copying 170321112225-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M289734.pkl
# copying 170321112522-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M289737.pkl
# copying 170321112829-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M289738.pkl
# copying 170320135107-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M278461.pkl
# copying 170321141248-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M278461.pkl
# copying 170320135113-task=DetectionOfChange_General_stage=static_windowed_gratings_mouse=M278465.pkl
# copying 170321141410-task=DetectionOfChange_General_stage=static_windowed_gratings_flash_500ms_mouse=M278465.pkl
# copying 170320140943-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M278710.pkl
# copying 170321141129-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M278710.pkl
# copying 170320140653-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M279219.pkl
# copying 170321141006-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M279219.pkl
# copying 170320140534-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M279220.pkl
# copying 170321140804-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M279220.pkl
# copying 170320140434-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M279222.pkl
# copying 170321140633-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M279222.pkl
# copying 170321100027-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M282821.pkl
# copying 170322101732-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M282821.pkl
# copying 170321100130-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M284728.pkl
# copying 170322101908-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M284728.pkl
# copying 170321095922-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M297953.pkl
# copying 170322101615-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M297953.pkl
# copying 170321095804-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M293817.pkl
# copying 170322101513-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M293817.pkl
# copying 170321095709-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M293818.pkl
# copying 170322101424-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M293818.pkl

# %%
from braintv_behav.latest import local_dir
trials = dro.load_from_folder(local_dir)
# Out:
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320144334-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M276444.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 5 but corresponding boolean dimension is 4
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# error loading file 161107125855-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M276600.pkl:
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321100130-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M284728.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 3 but corresponding boolean dimension is 2
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 2 but corresponding boolean dimension is 1
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 9 but corresponding boolean dimension is 8
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 16 but corresponding boolean dimension is 15
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321140804-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M279220.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 6 but corresponding boolean dimension is 5
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320135107-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M278461.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 8 but corresponding boolean dimension is 7
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 7 but corresponding boolean dimension is 6
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 4 but corresponding boolean dimension is 3
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170322101424-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M293818.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 23 but corresponding boolean dimension is 22
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321141129-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M278710.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 71 but corresponding boolean dimension is 70
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 21 but corresponding boolean dimension is 20
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320152912-task=DetectionOfChange_General_stage=static_windowed_gratings_flash_500ms_mouse=M274438.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321153430-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M276953.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 11 but corresponding boolean dimension is 10
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320140434-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M279222.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321095709-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M293818.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 12 but corresponding boolean dimension is 11
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 10 but corresponding boolean dimension is 9
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170322101615-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M297953.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 17 but corresponding boolean dimension is 16
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 15 but corresponding boolean dimension is 14
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321153717-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M274439.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320153502-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M274439.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321141248-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M278461.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 30 but corresponding boolean dimension is 29
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# error loading file .161107103018-task=DetectionOfChange_Gratings_stage=2_LickDetectTraining_mouse=M261584.pkl.CtyC9d:
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321095624-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M276950.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 74 but corresponding boolean dimension is 73
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320140943-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M278710.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320153015-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M294759.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 72 but corresponding boolean dimension is 71
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 42 but corresponding boolean dimension is 41
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 18 but corresponding boolean dimension is 17
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321112225-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M289734.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320140653-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M279219.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321095922-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M297953.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320153057-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M276953.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 19 but corresponding boolean dimension is 18
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 22 but corresponding boolean dimension is 21
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170322101659-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M271733.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321143112-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M273578.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170322101513-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M293817.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321153346-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M294759.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 63 but corresponding boolean dimension is 62
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 20 but corresponding boolean dimension is 19
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 50 but corresponding boolean dimension is 49
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 51 but corresponding boolean dimension is 50
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 26 but corresponding boolean dimension is 25
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321101530-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M276600.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 79 but corresponding boolean dimension is 78
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 38 but corresponding boolean dimension is 37
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 40 but corresponding boolean dimension is 39
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 67 but corresponding boolean dimension is 66
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170322101732-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M282821.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321095804-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M293817.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320144550-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M273577.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321140633-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M279222.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320144429-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M273578.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170322101841-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M258194.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321153537-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M278460.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321100900-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M271966.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321143041-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M276444.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170322101318-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M271966.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320153354-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M294753.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 153 but corresponding boolean dimension is 152
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321143255-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M273577.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 14 but corresponding boolean dimension is 13
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320153216-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M278460.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320135113-task=DetectionOfChange_General_stage=static_windowed_gratings_mouse=M278465.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321153312-task=DetectionOfChange_General_stage=static_windowed_gratings_flash_500ms_mouse=M274438.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321101215-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M271733.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 13 but corresponding boolean dimension is 12
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321101357-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M258194.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321112522-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M289737.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321141006-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M279219.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321141410-task=DetectionOfChange_General_stage=static_windowed_gratings_flash_500ms_mouse=M278465.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170322101908-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M284728.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170322102045-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M276600.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 86 but corresponding boolean dimension is 85
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 90 but corresponding boolean dimension is 89
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321153631-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M294753.pkl
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 33 but corresponding boolean dimension is 32
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 62 but corresponding boolean dimension is 61
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 45 but corresponding boolean dimension is 44
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 80 but corresponding boolean dimension is 79
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# /home/justink/Code/dro/dro/utilities.py:157: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 84 but corresponding boolean dimension is 83
#   lt.append(list(np.array(lick_times_on_this_trial)[lick_intervals[:len(lick_times_on_this_trial)]>1]))
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170322101516-task=DoC_NaturalImages_LuminanceMatched_TestImages_n=8_stage=Testing_mouse=M276950.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321112829-task=DoC_NaturalImages_CAMMatched_n=8_stage=natural_images_mouse=M289738.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170320140534-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M279220.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_behav/../data/raw/170321100027-task=DetectionOfChange_General_stage=static_full_field_gratings_mouse=M282821.pkl

# %%
trials = trials.merge(
    cohort_assignment,
    how='left',
    on='mouse_id',
)
trials = trials[trials.cohort>0]

# %%
day_zero = {r['mouse']:"{:%Y-%m-%d}".format(r['day_zero']) for _,r in cohort_assignment.iterrows()}

# %%
day_zero
# Out:
# {u'M246782': '2016-08-22',
#  u'M249123': '2016-08-22',
#  u'M250783': '2016-08-22',
#  u'M250786': '2016-08-22',
#  u'M258089': '2016-09-19',
#  u'M258173': '2016-09-19',
#  u'M258174': '2016-08-22',
#  u'M258194': '2016-10-10',
#  u'M258196': '2016-08-22',
#  u'M258274': '2016-09-19',
#  u'M258275': '2016-09-19',
#  u'M258276': '2016-09-19',
#  u'M261584': '2016-09-19',
#  u'M265154': '2016-10-10',
#  u'M265158': '2016-10-10',
#  u'M265166': '2016-10-10',
#  u'M271728': '2016-10-31',
#  u'M271733': '2016-10-31',
#  u'M271966': '2016-10-10',
#  u'M272464': '2016-10-31',
#  u'M272465': '2016-10-10',
#  u'M273577': '2016-11-28',
#  u'M273578': '2016-11-28',
#  u'M274438': '2017-02-13',
#  u'M274439': '2017-02-13',
#  u'M275962': '2016-11-28',
#  u'M275963': '2017-01-16',
#  u'M275965': '2017-01-16',
#  u'M276444': '2016-11-28',
#  u'M276445': '2016-11-28',
#  u'M276600': '2016-10-31',
#  u'M276950': '2016-10-31',
#  u'M276951': '2016-10-31',
#  u'M276953': '2017-02-13',
#  u'M277931': '2017-01-16',
#  u'M278229': '2016-11-28',
#  u'M278329': '2017-01-16',
#  u'M278332': '2017-01-16',
#  u'M278460': '2017-02-13',
#  u'M278461': '2017-03-06',
#  u'M278463': '2017-01-16',
#  u'M278465': '2017-03-06',
#  u'M278710': '2017-03-06',
#  u'M279219': '2017-03-06',
#  u'M279220': '2017-03-06',
#  u'M279222': '2017-03-06',
#  u'M282821': '2017-03-20',
#  u'M282822': '2017-03-20',
#  u'M284728': '2017-03-20',
#  u'M289734': '2017-02-27',
#  u'M289737': '2017-02-27',
#  u'M289738': '2017-02-27',
#  u'M293817': '2017-03-20',
#  u'M293818': '2017-03-20',
#  u'M294753': '2017-02-13',
#  u'M294759': '2017-02-13',
#  u'M297953': '2017-03-20'}

# %%
def get_training_day(df_in):
    '''adds a column to the dataframe with the number of unique training days up to that point
         '''
    coh = cohort_assignment.set_index('mouse')['cohort']
#     print coh

    training_day_lookup = {}
    for mouse, group in df_in.groupby('mouse_id'):
        dates = np.sort(group['date'].unique())
        try:
            dz = day_zero[mouse]
            offset = np.argwhere(dates==dz)[0][0]
        except KeyError:
            print 'day zero not found for {}'.format(mouse)
            offset = 0
        except IndexError:
            print 'day zero ({}) not found in dates'.format(dz)
            offset = 0
        print offset
        training_day_lookup[mouse] = {date:training_day-offset for training_day,date in enumerate(dates)}
        print mouse,dates
    return df_in.apply(lambda row: training_day_lookup[row['mouse_id']][row['date']],axis=1)

trials['training_day'] = get_training_day(trials)

#df['day_of_week'] = df.startdatetime.dt.weekday_name

## build arrays for change detection

# df['change'] = ~df['change_frame'].isnull()
trials['change'] = trials['trial_type']=='go'
trials['detect'] = trials['response']==1.0
# Out:
# 0
# M246782 ['2016-08-22' '2016-08-23' '2016-08-24' '2016-08-25' '2016-08-26'
#  '2016-08-29' '2016-08-30' '2016-08-31' '2016-09-02' '2016-09-06'
#  '2016-09-07' '2016-09-08' '2016-09-09' '2016-09-12' '2016-09-13'
#  '2016-09-14' '2016-09-15' '2016-09-16' '2016-09-19' '2016-09-20']
# 0
# M249123 ['2016-08-22' '2016-08-23' '2016-08-24' '2016-08-25' '2016-08-26'
#  '2016-08-29' '2016-08-30' '2016-08-31' '2016-09-02' '2016-09-06'
#  '2016-09-07' '2016-09-08' '2016-09-09' '2016-09-12' '2016-09-13'
#  '2016-09-15' '2016-09-16' '2016-09-19' '2016-09-20']
# 0
# M250783 ['2016-08-22' '2016-08-23' '2016-08-24' '2016-08-25' '2016-08-26'
#  '2016-08-29' '2016-08-30' '2016-08-31' '2016-09-02' '2016-09-06'
#  '2016-09-07' '2016-09-08' '2016-09-09' '2016-09-12' '2016-09-13'
#  '2016-09-14' '2016-09-15' '2016-09-16' '2016-09-19' '2016-09-20'
#  '2016-09-21' '2016-09-22' '2016-09-23' '2016-09-26' '2016-09-27'
# 1
# M293818 ['2017-03-17' '2017-03-20' '2017-03-21' '2017-03-22']
# 1
# M294753 ['2017-02-10' '2017-02-13' '2017-02-14' '2017-02-15' '2017-02-16'
#  '2017-02-17' '2017-02-20' '2017-02-21' '2017-02-22' '2017-02-23'
#  '2017-02-24' '2017-02-27' '2017-02-28' '2017-03-01' '2017-03-02'
#  '2017-03-03' '2017-03-06' '2017-03-07' '2017-03-08' '2017-03-09'
#  '2017-03-10' '2017-03-13' '2017-03-14' '2017-03-15' '2017-03-16'
#  '2017-03-17' '2017-03-20' '2017-03-21']
# 1
# M294759 ['2017-02-10' '2017-02-13' '2017-02-14' '2017-02-15' '2017-02-16'
#  '2017-02-17' '2017-02-20' '2017-02-21' '2017-02-22' '2017-02-23'
#  '2017-02-24' '2017-02-27' '2017-02-28' '2017-03-01' '2017-03-02'
#  '2017-03-03' '2017-03-06' '2017-03-07' '2017-03-08' '2017-03-09'
#  '2017-03-10' '2017-03-13' '2017-03-14' '2017-03-15' '2017-03-16'
#  '2017-03-17' '2017-03-20' '2017-03-21']
# 1
# M297953 ['2017-03-17' '2017-03-20' '2017-03-21' '2017-03-22']

# %%
## calculate reaction times

trials['change_time'] = trials['change_time'].map(lambda x: np.nan if x is None else x)

trials['reaction_time'] = trials['lick_times'].map(lambda x: x[0] if len(x)>0 else np.nan)
trials['reaction_time'] = trials.apply(lambda row: row['reaction_time'] - row['change_time'],axis=1)

## unwrap the response window
trials['response_window_lower'] = trials['response_window'].map(lambda x: x[0])
trials['response_window_upper'] = trials['response_window'].map(lambda x: x[1])

# %%
trials['task'].unique()
# Out:
# array(['DetectionOfChange_Gratings',
#        'DoC_Gratings_multi_ori_multi_contrast',
#        'DetectionOfChange_General', 'DoC_MNIST', 'DoC_NaturalImages_n=8',
#        'DoC_NaturalImages_CAMMatched_n=8',
#        'DoC_NaturalImages_CAMMatched_TestImages_n=8',
#        'DoC_NaturalImages_LuminanceMatched_TestImages_n=8',
#        'DetectionOfChange'], dtype=object)

# %%
trials.groupby('task').get_group('DoC_NaturalImages_LuminanceMatched_TestImages_n=8')['cohort'].unique()
# Out:
# array([ 2.,  4.,  3.,  5.])

# %%
from braintv_behav import metrics
from sklearn.metrics import accuracy_score

# %%
reload(metrics)
def compute_metrics(group):
    result = {
        'accuracy': metrics.discrim(group,'change','detect',metric=accuracy_score),
        'd-prime': metrics.discrim(group,'change','detect',metric=metrics.d_prime),
        'd-prime_peak': metrics.peak_dprime(group),
        'discrim_p': metrics.discrim(group,'change','detect',metric=metrics.discrim_p),
        'response_bias': metrics.response_bias(group,'detect'),
        'earned_water': metrics.earned_water(group), 
        'total_water': metrics.total_water(group), 
        'num_trials': metrics.num_trials(group),
        'num_contingent_trials': metrics.num_contingent_trials(group),
        'reaction_time_50th%ile': metrics.reaction_times(group,percentile=50),
        'reaction_time_05th%ile': metrics.reaction_times(group,percentile=5),
        'reaction_time_95th%ile': metrics.reaction_times(group,percentile=95),
        'fraction_time_aborted': metrics.fraction_time_aborted(group),
    }
    
    return pd.Series(result, name='metrics')

water = trials.groupby(['cohort','mouse_id','training_day']).apply(compute_metrics).reset_index()
water['frac_earned_water'] = water['earned_water'] / water['total_water']
water['reaction_time_spread'] = water['reaction_time_95th%ile'] - water['reaction_time_05th%ile']
water.head()
# Out:
# metrics  cohort mouse_id  training_day  accuracy   d-prime  d-prime_peak  \
# 0           1.0  M246782             0  0.544872       NaN           NaN
# 1           1.0  M246782             1  0.219101 -0.057545      1.469094
# 2           1.0  M246782             2  0.264957 -0.803594     -0.346402
# 3           1.0  M246782             3  0.241935 -0.025337      0.589474
# 4           1.0  M246782             4  0.312849 -0.262469     -0.032233
#
# metrics  discrim_p  earned_water  fraction_time_aborted  \
# 0         1.000000         1.092               0.006408
# 1         0.946458         0.354               0.227186
# 2         0.076643         0.198               0.704902
# 3         0.783441         0.276               0.566037
# 4         0.681377         0.530               0.577811
#
# metrics  num_contingent_trials  num_trials  reaction_time_05th%ile  \
# 0                        156.0       157.0               -5.020008
# 1                        356.0      1563.0                0.161557
# 2                        117.0       394.0                0.208261
# 3                        186.0       426.0                0.087997
# 4                        179.0       423.0                0.150696
#
# metrics  reaction_time_50th%ile  reaction_time_95th%ile  response_bias  \
# 0                      0.334217                3.778943       0.544872
# 1                      1.286406                4.141207       0.171348
# 2                      1.360493                5.292036       0.273504
# 3                      1.401724                4.474582       0.193548
# 4                      1.343656                4.549200       0.296089
#
# metrics  total_water  frac_earned_water  reaction_time_spread
# 0              1.092                1.0              8.798951
# 1              0.354                1.0              3.979650
# 2              0.198                1.0              5.083775
# 3              0.276                1.0              4.386585
# 4              0.530                1.0              4.398504

# %%
sns.jointplot('d-prime','d-prime_peak',data=water)

# %%
sns.jointplot('d-prime_peak','fraction_time_aborted',data=water)

# %%
with sns.color_palette('coolwarm',20):
    sns.lmplot('fraction_time_aborted','d-prime_peak',data=water.dropna()[water.training_day<20],
               hue='training_day',
               col='cohort',col_wrap=3,
               fit_reg=False,
               size=2.5,
              )
# Out:
# /local1/.conda/envs/braintv_behav/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app

# %%
mask = water['reaction_time_05th%ile']>0

# %%
jp = sns.jointplot('reaction_time_05th%ile','d-prime',data=water[mask],
                   stat_func=None,
             )
jp.ax_joint.axhspan(-0.5,0.5,color='0.5',alpha=0.5,zorder=-2)
jp.ax_joint.axhline(0.0,color='0.5',zorder=-1)

plt.savefig('../figures/d_prime_by_reaction_time.pdf')

jp = sns.jointplot('response_bias','d-prime',data=water[mask],
             )
jp.ax_joint.axhspan(-1,1,color='0.5',alpha=0.5,zorder=-2)
jp.ax_joint.axhline(0.0,color='0.5',zorder=-1)


jp = sns.jointplot('accuracy','d-prime',data=water[mask],
             )
jp.ax_joint.axhspan(-1,1,color='0.5',alpha=0.5,zorder=-2)
jp.ax_joint.axhline(0.0,color='0.5',zorder=-1)

# %%
def stars(p,ns='n.s.',thresh=(0.1,0.05,0.01,0.001)):
    '''Converts p-values into R-styled stars.
    Signif. codes:
        '***' :  < 0.001
        '**' : < 0.01
        '*' : < 0.05
        '.' : < 0.1
        'n.s.' : < 1.0
    '''
    lookup = (
        (0.001, '***'),
        (0.01, '**'),
        (0.05, '*'),
        (0.1, '.'),
    )
    for t,s in lookup:
        if (t in thresh) and (p < t):
            return s
    return ns

def plot_stars(p,x,y,ax,ns='n.s.',thresh=(0.1,0.05,0.01,0.001),size='large',horizontalalignment='center',**kwargs):
    ''' Plots significance stars '''
    ax.text(x,y,stars(p,ns,thresh),size=size,horizontalalignment=horizontalalignment,**kwargs)

def plot_linestar(p,x1,x2,y,ax):
    ax.hlines(y, x1, x2)
    plot_stars(0.5*(x1+x2),y+0.02,stars(p),ax=ax,size='large',horizontalalignment='center')

# %%
class RisingEdge():
    """
    This object implements a "rising edge" detector on a boolean array.
    
    It takes advantage of how pandas applies functions in order.
    
    For example, if the "criteria" column in the `df` dataframe consists of booleans indicating
    whether the row meets a criterion, we can detect the first run of three rows above criterion
    with the following
    
        first_run_of_three = (
            df['criteria']
            .rolling(center=False,window=3)
            .apply(func=RisingEdge().check)
            )
    
    ```
    
    """
    def __init__(self):
        self.firstall = False
    def check(self,arr):
        if arr.all():
            self.firstall = True
        return self.firstall

# %%
class RisingEdgeTwo():
    """
    This object implements a "rising edge" detector on a boolean array.
    
    It takes advantage of how pandas applies functions in order.
    
    For example, if the "criteria" column in the `df` dataframe consists of booleans indicating
    whether the row meets a criterion, we can detect the first run of three rows above criterion
    with the following
    
        first_run_of_three = (
            df['criteria']
            .rolling(center=False,window=3)
            .apply(func=RisingEdge().check)
            )
    
    ```
    
    """
    def __init__(self):
        self.firstall = False
    def check(self,arr):
        if arr.sum()>1:
            self.firstall = True
        return self.firstall

# %%
pdf = water
pdf['d_prime'] = pdf['d-prime']
pdf['d_prime_peak'] = pdf['d-prime_peak']
pdf['stimulus_control'] = pdf['discrim_p'] < 0.01

# %%
num_tr_thresh = 20
# dprime_thresh = 0.5


# pdf['criteria'] = (
#     pdf['stimulus_control']
#     & (pdf['num_contingent_trials'] > num_tr_thresh)
#     & (pdf['d_prime'] > dprime_thresh)
# )

pdf['criteria'] = (
#     pdf['stimulus_control']
    (pdf['d_prime_peak'] > 2)
#     & (pdf['num_contingent_trials'] > num_tr_thresh)
)

# mask = pdf.num_trials > num_tr_thresh # ignore sessions with very few trials

first = {}

consecutive_sessions = 3

for key, group in pdf.set_index('training_day').sort_index().groupby(['cohort','mouse_id']):
#     print group.head()
    learned = (
        group['criteria']
        .rolling(center=False,window=consecutive_sessions)
        .apply(func=RisingEdgeTwo().check)
        )
    summary = pd.DataFrame(
        [learned.rename('learned'),
         group['stimulus_control'],
         group['d_prime'],
         group['num_trials'],
        ]).transpose()
    
    try:
        first_session = summary['learned'][summary['learned']==1.0].index[0] #+(1-2)
    except IndexError:
        first_session = np.nan
    
    print key, first_session
#     print summary.tail()
    
    first[key[1]]=first_session
    
def learned(row):
    first_day = first[row['mouse_id']]
    
    if pd.isnull(first_day):
        return False
    else: 
        return (first_day <= row['training_day'])
    
pdf['learned'] = pdf.apply(learned,axis=1)
# Out:
# (1.0, 'M246782') nan
# (1.0, 'M249123') nan
# (1.0, 'M250783') 12
# (1.0, 'M250786') 9
# (1.0, 'M258174') 6
# (1.0, 'M258196') 9
# (2.0, 'M258089') 12
# (2.0, 'M258173') 33
# (2.0, 'M258274') 9
# (2.0, 'M258275') 13
# (2.0, 'M258276') 37
# (2.0, 'M261584') 13
# (3.0, 'M258194') 7
# (3.0, 'M265154') nan
# (3.0, 'M265158') nan
# (3.0, 'M265166') nan
# (3.0, 'M271966') 12
# (3.0, 'M272465') 19
# (4.0, 'M271728') 5
# (4.0, 'M271733') 12
# (4.0, 'M272464') 8
# (4.0, 'M276600') 6
# (4.0, 'M276950') 17
# (4.0, 'M276951') 6
# (5.0, 'M273577') 5
# (5.0, 'M273578') 12
# (5.0, 'M275962') 12
# (5.0, 'M276444') 61
# (5.0, 'M276445') 8
# (5.0, 'M278229') 4
# (6.0, u'M275963') nan
# (6.0, u'M275965') nan
# (6.0, u'M277931') nan
# (6.0, u'M278329') nan
# (6.0, u'M278332') nan
# (6.0, u'M278463') nan
# (7.0, u'M274438') 7
# (7.0, u'M274439') 7
# (7.0, u'M276953') 13
# (7.0, u'M278460') 2
# (7.0, u'M278461') 5
# (7.0, u'M278465') 9
# (7.0, u'M278710') 3
# (7.0, u'M279219') nan
# (7.0, u'M279220') nan
# (7.0, u'M279222') nan
# (7.0, u'M289734') 2
# (7.0, u'M289737') 7
# (7.0, u'M289738') 8
# (7.0, u'M294753') 2
# (7.0, u'M294759') 9
# (8.0, u'M282821') nan
# (8.0, u'M284728') nan
# (8.0, u'M293817') nan
# (8.0, u'M293818') nan
# (8.0, u'M297953') nan

# %%
def learning_day(row):
    first_day = first[row['mouse_id']]
    
    if pd.isnull(first_day):
        return False
    else: 
        return (first_day == row['training_day'])
pdf['learning_day'] = pdf.apply(learning_day,axis=1)

# %%
# trials[trials.cohort=='Cohort 3'].groupby(['mouse_id'])['date'].min()

# %%
# col_order = cohort_assignment.sort_values('cohort')['mouse_id']

# mask = (
#     (pdf.training_day >= 0)
#     & (pdf.training_day < 15)
#     )

# fp = sns.factorplot('training_day','d_prime_peak',data=pdf[mask],
#                     col='mouse_id',
#                     col_wrap=3,
#                     size=2,
#                     aspect=1.5,
#                     hue='cohort',
#                     col_order=col_order,
#               )

# yloc = -1.5

# for ax,mouse_id in zip(fp.axes.ravel(),col_order):
#     ax.axhline(0.0,color='0.5',zorder=-1)
# #     ax.axhspan(-dprime_thresh,dprime_thresh,color='0.5',alpha=0.5,zorder=-1)
# #     print mouse_id
#     for r,row in pdf[mask & (pdf['mouse_id']==mouse_id)].iterrows():
#         p, x = row['discrim_p'], row['training_day']
#         plot_stars(p,x,yloc,ax,ns='',thresh=(0.05,))
#     ax.axvline(first[mouse_id],color='r',zorder=-1)
    
# sns.despine(bottom=True)
# # plt.xlim(0,8)


# plt.savefig('../figures/d_prime_by_training_day_individ.pdf')

# %%
pdf['cohort'] = pdf['cohort'].map(int)

# %%
pdf
# Out:
# 2560  8.497225e-03         0.690                  194.0       836.0    ...
# 2561  8.992169e-09         0.810                  252.0       845.0    ...
# 2562  1.000000e+00         0.504                   72.0        72.0    ...
# 2563  9.165969e-01         0.440                  280.0       881.0    ...
# 2564  9.753283e-01         0.450                  176.0       907.0    ...
# 2565  8.596323e-01         0.360                  156.0       894.0    ...
# 2566  1.000000e+00         0.518                   74.0        74.0    ...
# 2567  7.889715e-01         0.590                  285.0       966.0    ...
# 2568  1.383412e-04         0.740                  205.0       945.0    ...
# 2569  2.360132e-03         0.420                   79.0      1041.0    ...
# 2570  1.000000e+00         0.497                   71.0        71.0    ...
# 2571  3.654094e-01         0.520                  386.0       766.0    ...
# 2572  9.954147e-01         0.170                   82.0      1020.0    ...
# 2573  3.626429e-01         0.400                  251.0       908.0    ...
#
#       minweight                 mousenotes    owner  reporter     sex  \
# 0            85  Additional information...   sissyc   GCaMP6+  Female
# 1            85  Additional information...   sissyc   GCaMP6+  Female
# 2            85  Additional information...   sissyc   GCaMP6+  Female
# 3            85  Additional information...   sissyc   GCaMP6+  Female
# 4            85  Additional information...   sissyc   GCaMP6+  Female
# 5            85  Additional information...   sissyc   GCaMP6+  Female
# 6            85  Additional information...   sissyc   GCaMP6+  Female
# 7            85  Additional information...   sissyc   GCaMP6+  Female
# 8            85  Additional information...   sissyc   GCaMP6+  Female
# 9            85  Additional information...   sissyc   GCaMP6+  Female
# 10           85  Additional information...   sissyc   GCaMP6+  Female
# 11           85  Additional information...   sissyc   GCaMP6+  Female
# 12           85  Additional information...   sissyc   GCaMP6+  Female
# 13           85  Additional information...   sissyc   GCaMP6+  Female
# 14           85  Additional information...   sissyc   GCaMP6+  Female
# 15           85  Additional information...   sissyc   GCaMP6+  Female
# 16           85  Additional information...   sissyc   GCaMP6+  Female
# 17           85  Additional information...   sissyc   GCaMP6+  Female
# 18           85  Additional information...   sissyc   GCaMP6+  Female
# 19           85  Additional information...   sissyc   GCaMP6+  Female
# 20           85  Additional information...   sissyc   GCaMP6+  Female
# 21           85  Additional information...   sissyc   GCaMP6+  Female
# 22           85  Additional information...   sissyc   GCaMP6+  Female
# 23           85  Additional information...   sissyc   GCaMP6+  Female
# 24           85  Additional information...   sissyc   GCaMP6+  Female
# 25           85  Additional information...   sissyc   GCaMP6+  Female
# 26           85  Additional information...   sissyc   GCaMP6+  Female
# 27           85  Additional information...   sissyc   GCaMP6+  Female
# 28           85  Additional information...   sissyc   GCaMP6+  Female
# 29           85  Additional information...   sissyc   GCaMP6+  Female
# ...         ...                        ...      ...       ...     ...
# 2544         80  Additional information...   sissyc   GCaMP6+  Female
# 2545         80  Additional information...   sissyc   GCaMP6+  Female
# 2546         80  Additional information...   sissyc   GCaMP6+  Female
# 2547         80  Additional information...   sissyc   GCaMP6+  Female
# 2548         80  Additional information...   sissyc   GCaMP6+  Female
# 2549         80  Additional information...   sissyc   GCaMP6+  Female
# 2550         80  Additional information...   sissyc   GCaMP6+  Female
# 2551         80  Additional information...   sissyc   GCaMP6+  Female
# 2557              None                440  sissyc                 2017-03-10
# 2558              None                340  sissyc                 2017-03-10
# 2559              None                340  sissyc                 2017-03-10
# 2560              None                340  sissyc                 2017-03-10
# 2561              None                340  sissyc                 2017-03-10
# 2562              None                340  sissyc                 2017-03-10
# 2563              None                340  sissyc                 2017-03-10
# 2564              None                340  sissyc                 2017-03-10
# 2565              None                340  sissyc                 2017-03-10
# 2566              None                340  sissyc                 2017-03-10
# 2567              None                340  sissyc                 2017-03-10
# 2568              None                340  sissyc                 2017-03-10
# 2569              None                340  sissyc                 2017-03-10
# 2570              None                340  sissyc                 2017-03-10
# 2571              None                340  sissyc                 2017-03-10
# 2572              None                340  sissyc                 2017-03-10
# 2573              None                340  sissyc                 2017-03-10
#
#           Rorb
# 0         Rorb
# 1         Rorb
# 2         Rorb
# 3         Rorb
# 4         Rorb
# 5         Rorb
# 6         Rorb
# 7         Rorb
# 8         Rorb
# 9         Rorb
# 10        Rorb
# 11        Rorb
# 12        Rorb
# 13        Rorb
# 14        Rorb
# 15        Rorb
# 16        Rorb
# 17        Rorb
# 18        Rorb
# 19        Rorb
# 20        Rorb
# 21        Rorb
# 22        Rorb
# 23        Rorb
# 24        Rorb
# 25        Rorb
# 26        Rorb
# 27        Rorb
# 28        Rorb
# 29        Rorb
# ...        ...
# 2544  not Rorb
# 2545  not Rorb
# 2546  not Rorb
# 2547  not Rorb
# 2548  not Rorb
# 2549  not Rorb
# 2550  not Rorb
# 2551  not Rorb
# 2552  not Rorb
# 2553  not Rorb
# 2554  not Rorb
# 2555  not Rorb
# 2556  not Rorb
# 2557  not Rorb
# 2558  not Rorb
# 2559  not Rorb
# 2560  not Rorb
# 2561  not Rorb
# 2562  not Rorb
# 2563  not Rorb
# 2564  not Rorb
# 2565  not Rorb
# 2566  not Rorb
# 2567  not Rorb
# 2568  not Rorb
# 2569  not Rorb
# 2570  not Rorb
# 2571  not Rorb
# 2572  not Rorb
# 2573  not Rorb
#
# [2574 rows x 44 columns]

# %%
mask = (
#     (pdf.num_trials > num_tr_thresh) # ignore sessions with very few trials
#     & (pdf.training_day <= pdf.groupby('mouse_id')['training_day'].max().min())
    (pdf.training_day >= 0)
    & (pdf.training_day <= 15)
    )

fp = sns.factorplot('training_day','d_prime_peak',data=pdf[mask],
                    hue='mouse_id',
                    col_wrap=3,
                    size=3,
#                     aspect=2,
                    col='cohort',
#                     col_order=col_order,
              )

for ax in fp.axes.flatten():
    ax.axhline(0.0,color='0.7')
    ax.axhspan(-0.5,0.5,color='0.5',alpha=0.5,zorder=-10)
plt.ylim(-1,4)

plt.savefig('../figures/d_prime_by_training_day.pdf')

# fp = sns.factorplot('training_day','learned',data=pdf[mask],
#                     hue='mouse_id',
#                     col_wrap=3,
#                     size=3,
# #                     aspect=2,
#                     col='cohort',
# #                     col_order=col_order,
#                     legend=False,
#               )

# fp = sns.factorplot('training_day','learned',data=pdf[mask],
# #                     hue='mouse_id',
#                     col_wrap=3,
#                     size=3,
# #                     aspect=2,
#                     col='cohort',
# #                     col_order=col_order,
#                     legend=False,
#               )

# %%
mask = (
#     (pdf.num_trials > num_tr_thresh) # ignore sessions with very few trials
#     & (pdf.training_day <= pdf.groupby('mouse_id')['training_day'].max().min())
    (pdf.training_day >= 0)
    & (pdf.training_day <= 19)
)

g = sns.factorplot('training_day','d_prime',data=pdf[mask],
                    size=4,
                    aspect=1.2,
                    hue='cohort',
                    kind='strip',  
                    legend=True,
                    alpha=0.5,
                    palette='Dark2'
              )

g.map_dataframe(sns.pointplot,'training_day','d_prime',
                hue='cohort',
                palette='Dark2',
                zorder=1000,
                ci=None,
                )
g.set_axis_labels('Training Day', 'd\'')
g.fig.get_children()[-1].set_bbox_to_anchor((1.15, 0.5, 0, 0))
# g.fig.get_children()[-1].set_title('')


for ax in g.axes.ravel():
    ax.axhline(0.0,color='0.5',zorder=-10)
    ax.axhspan(-0.5,0.5,color='0.5',alpha=0.2,zorder=-10)

plt.savefig('../figures/d_prime_by_training_day_cohort_means.pdf')

# %%
mask = (
#     (pdf.num_trials > num_tr_thresh) # ignore sessions with very few trials
#     & (pdf.training_day <= pdf.groupby('mouse_id')['training_day'].max().min())
    (pdf.training_day >= 0)
    & (pdf.training_day <= 15)
    & pdf.cohort.isin((3,4))
    )

fp = sns.factorplot('training_day','d_prime',data=pdf[mask],
                    hue='mouse_id',
#                     col_wrap=3,
                    size=3,
#                     aspect=2,
                    col='cohort',
                    palette='coolwarm',
#                     col_order=col_order,
              )

for ax in fp.axes.flatten():
    ax.axhline(0.0,color='0.2',zorder=-1)
    ax.axhspan(-0.5,0.5,color='0.5',alpha=0.2,zorder=-10)
plt.ylim(-1,4)
fp.set_axis_labels('Training Day','d\'')

plt.savefig('../figures/d_prime_by_training_day_cohorts3and4.pdf')

# %%
pdf = pdf.merge(cohort_assignment,on=['cohort','mouse_id'])

# %%
mask = (
#     (pdf.num_trials > num_tr_thresh) # ignore sessions with very few trials
#     & (pdf.training_day <= pdf.groupby('mouse_id')['training_day'].max().min())
    (pdf.training_day >= 0)
    & (pdf.training_day < 20)
    & (pdf.cohort != 6)
)

g = sns.factorplot('training_day','learned',data=pdf[mask],
                   size=3,
                   aspect=2,
                   hue='cohort',
                   ci=False,  
                   legend=True,
                   palette='Dark2'
              )

g.set_axis_labels('Training Day','Fraction Learned')
plt.ylim(-0.1,1.1)
sns.despine(trim=True)

# g.map_dataframe(sns.pointplot,'training_day','d_prime',
#                 hue='cohort',
#                 palette='Dark2',
#                 zorder=1000,
#                 ci=None,
#                 )
# g.set_axis_labels('Training Day', 'd\'')
# g.fig.get_children()[-1].set_bbox_to_anchor((1.15, 0.5, 0, 0))
# # g.fig.get_children()[-1].set_title('')


for ax in g.axes.ravel():
#     ax.axhline(0.0,color='0.5',zorder=-10)
    ax.axvspan(4.5,9.5,color='0.5',alpha=0.1,zorder=-10)
    ax.axvspan(14.5,19.5,color='0.5',alpha=0.1,zorder=-10)

plt.savefig('../figures/cohort_survival.pdf')

# %%
df = pdf[mask][['mouse_id','training_day','learned']].copy()

# %%
learned_by_week_four = df[df.training_day==19][['mouse_id','learned']]
learned_by_week_four.head()
# Out:
#     mouse_id learned
# 19   M246782   False
# 58   M250783    True
# 136  M250786    True
# 213  M258174    True
# 291  M258196    True

# %%
pd.merge?

# %%
df = df.merge(learned_by_week_four,on=['mouse_id'],suffixes=('', '_by_week_four'))

# %%
df['predictor'] = df['learned']==df['learned_by_week_four']

# %%
sns.factorplot('training_day','predictor',data=df,aspect=1.5)

# %%
mask = (
    (pdf.training_day >= 0)
    & (pdf.training_day < 20)
    & (pdf.cohort != 6)
    & (pdf.group.map(lambda x: 'Rorb' not in x))
)

g = sns.factorplot('training_day','learned',data=pdf[mask],
                   size=3,
                   aspect=2,
                   hue='cohort',
                   ci=False,  
                   legend=True,
                   palette='Dark2'
              )

g.set_axis_labels('Training Day','Fraction Learned')
plt.ylim(-0.1,1.1)
sns.despine(trim=True)


for ax in g.axes.ravel():
#     ax.axhline(0.0,color='0.5',zorder=-10)
    ax.axvspan(4.5,9.5,color='0.5',alpha=0.1,zorder=-10)
    ax.axvspan(14.5,19.5,color='0.5',alpha=0.1,zorder=-10)


    
    plt.savefig('../figures/cohort_survival_no_Rorb.pdf')

# %%
mask = (
#     (pdf.num_trials > num_tr_thresh) # ignore sessions with very few trials
#     & (pdf.training_day <= pdf.groupby('mouse_id')['training_day'].max().min())
    (pdf.training_day >= 0)
    & (pdf.training_day < 20)
    & (pdf.cohort != 6)
    & (pdf.group.map(lambda x: 'Rorb' not in x))
)

g = sns.factorplot('training_day','learning_day',data=pdf[mask],
                   size=3,
                   aspect=2,
#                    hue='cohort',
                   ci=False,  
                   legend=True,
                   palette='Dark2'
              )

g.set_axis_labels('Training Day','Fraction Learned Today')
plt.ylim(-0.1,0.3)
sns.despine(trim=True)

# g.map_dataframe(sns.pointplot,'training_day','d_prime',
#                 hue='cohort',
#                 palette='Dark2',
#                 zorder=1000,
#                 ci=None,
#                 )
# g.set_axis_labels('Training Day', 'd\'')
# g.fig.get_children()[-1].set_bbox_to_anchor((1.15, 0.5, 0, 0))
# # g.fig.get_children()[-1].set_title('')


for ax in g.axes.ravel():
#     ax.axhline(0.0,color='0.5',zorder=-10)
    ax.axvspan(4.5,9.5,color='0.5',alpha=0.1,zorder=-10)
    ax.axvspan(14.5,19.5,color='0.5',alpha=0.1,zorder=-10)

# plt.savefig('../figures/cohort_survival.pdf')

# %%
pdf['Rorb'] = pdf['group'].map(lambda x: 'Rorb' if 'Rorb' in x else 'not Rorb')

mask = (
    (pdf.training_day >= 0)
    & (pdf.training_day < 20)
    & (pdf.cohort != 6)
#     & (pdf.group.map(lambda x: 'Rorb' not in x))
)


g = sns.factorplot('training_day','learned',data=pdf[mask],
                   size=3,
                   aspect=2,
                   hue='Rorb',
              )

g.set_axis_labels('Training Day','Fraction Learned')
plt.ylim(-0.1,1.1)
sns.despine(trim=True)

for ax in g.axes.ravel():
#     ax.axhline(0.0,color='0.5',zorder=-10)
    ax.axvspan(4.5,9.5,color='0.5',alpha=0.1,zorder=-10)
    ax.axvspan(14.5,19.5,color='0.5',alpha=0.1,zorder=-10)

# %%
pdf['Rorb'].unique()
# Out:
# array(['Rorb', 'not Rorb'], dtype=object)

# %%
cohort_assignment['Rorb'] = cohort_assignment['group'].map(lambda x: 'Rorb' if 'Rorb' in x else 'not Rorb')

# %%
cohort_assignment[cohort_assignment.cohort!=6].groupby('Rorb').size()
# Out:
# Rorb
# Rorb         5
# not Rorb    46
# dtype: int64

# %%
cohort_assignment[cohort_assignment['Rorb']=='Rorb'][['mouse','cohort','reporter','group']]
# Out:
#       mouse  cohort reporter                                  group
# 7   M265158       3     None  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)
# 9   M265154       3     None  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)
# 11  M265166       3     None  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)
# 18  M246782       1  GCaMP6+  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)
# 19  M249123       1  GCaMP6+  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)
# 33  M278329       6     None  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)
# 35  M278332       6     None  Rorb-IRES2-Cre; Camk2a-tTA; Ai93 (NC)

# %%
cre_negative = 'M278332'
cohort_assignment['cre_status'] = pdf['mouse'].map(lambda m: 'Cre-' if m==cre_negative else 'Cre+')

# %%
pdf.columns
# Out:
# Index([                   u'cohort',                  u'mouse_id',
#                     u'training_day',                  u'accuracy',
#                          u'd-prime',              u'd-prime_peak',
#                        u'discrim_p',              u'earned_water',
#            u'num_contingent_trials',                u'num_trials',
#           u'reaction_time_05th%ile',    u'reaction_time_50th%ile',
#           u'reaction_time_95th%ile',             u'response_bias',
#                      u'total_water',         u'frac_earned_water',
#             u'reaction_time_spread',                   u'd_prime',
#                     u'd_prime_peak',          u'stimulus_control',
#                         u'criteria',                   u'learned',
#                     u'learning_day',                     u'mouse',
#                       u'experiment',                  u'day_zero',
#                   u'mtrain_regimen',            u'baselineweight',
#                        u'birthdate',              u'dayonescript',
#                          u'driver1',                   u'driver2',
#                            u'group',            u'iacuc_protocol',
#                        u'minweight',                u'mousenotes',
#                            u'owner',                  u'reporter',
#                              u'sex',                  u'tasktype',
#                u'training_location',                    u'userid',
#        u'waterrestrictionstartdate',                      u'Rorb'],
#       dtype='object')

# %%
g = sns.factorplot('training_day','learned',data=pdf[mask],
                   size=3,
                   aspect=2,
                   hue='Rorb',
              )

# %%
mask = (
#     (pdf.num_trials > num_tr_thresh) # ignore sessions with very few trials
#     & (pdf.training_day <= pdf.groupby('mouse_id')['training_day'].max().min())
    (pdf.training_day >= 0)
    & (pdf.training_day < 10)
    & (pdf.cohort.isin([1,3,6]))
#     & (pdf.Rorb=='Rorb')
    & (pdf.mouse!='M278463')
)

g = sns.factorplot('training_day','response_bias',data=pdf[mask],
                    size=4,
                    aspect=1.2,
                    hue='mouse',
                    col='cohort',
                    row='Rorb',
                    legend=True,
                    alpha=0.5,
                    palette='Dark2'
              )
