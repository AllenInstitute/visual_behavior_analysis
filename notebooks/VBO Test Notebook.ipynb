# %%
import numpy as np
import pandas as pd
from pathlib import Path
from glob import glob

from allensdk.brain_observatory.behavior.behavior_session import BehaviorSession
from allensdk.brain_observatory.behavior.behavior_ophys_experiment import BehaviorOphysExperiment

# %% [markdown]
# Below are some example data access code for BehaviorSession and OphysExperiment data. For the session/experiment objects themselves, I'm looking for any feedback regarding missing data or incorrectly formated data. For the pandas tables the question regards any incorrect typing or formating of the data. If you find issues beyond some that are already know (for instance `age_in_days` being float and not int, mouseid being typed `object`, or the ophys_experiment NWB I produced below missing a project code.) please create an issue on the AllenSDK. Thanks!
#
# The code below requires the rc/2.15.0 branch of the AllenSDK. To install from the command line (assuming you have `git` installed) use:
#
# `git clone https://github.com/AllenInstitute/AllenSDK`
#
# `cd your_newly_cloned_AllenSDK_directory`
#
# `git checkout rc/2.15.0`
#
# `pip install -e .`

# %%
base_path = Path('/allen/aibs/informatics/chris.morrison/vbo_nbw_test')

# %% [markdown]
# Behavior only
# ----------------

# %%
behavior_sessions = pd.read_csv(base_path / 'behavior_session_table.csv')
behavior_sessions
# Out:
#       behavior_session_id equipment_name  \
# 0               870987812     BEH.D-Box1
# 1               872953842     BEH.D-Box1
# 2               873774125     BEH.D-Box1
# 3               874790261     BEH.D-Box1
# 4               875207834     BEH.D-Box1
# ...                   ...            ...
# 4782            993537991        CAM2P.4
# 4783            993691759        CAM2P.4
# 4784            993959724        CAM2P.4
# 4785            994710581        CAM2P.4
# 4786            994882261        CAM2P.4
#
#                                       full_genotype  mouse_id  \
# 0     Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 1     Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 2     Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 3     Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 4     Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# ...                                             ...       ...
# 4782  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
# 4783  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
# 4784  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
# 4785  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
# 4786  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
#
#                    reporter_line       driver_line sex  age_in_days  \
# 0     Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F         80.0
# 1     Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F         84.0
# 2     Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F         85.0
# 3     Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F         86.0
# 4     Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F         87.0
# ...                          ...               ...  ..          ...
# 4782  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        128.0
# 4783  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        129.0
# 4784  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        130.0
# 4785  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        134.0
# 4786  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        135.0
#
#                                session_type      cre_line  ...  \
# 0     TRAINING_0_gratings_autorewards_15min  Sst-IRES-Cre  ...
# 1                       TRAINING_1_gratings  Sst-IRES-Cre  ...
# 2                       TRAINING_1_gratings  Sst-IRES-Cre  ...
# 3                       TRAINING_1_gratings  Sst-IRES-Cre  ...
# 4                       TRAINING_1_gratings  Sst-IRES-Cre  ...
# ...                                     ...           ...  ...
# 4782               OPHYS_2_images_B_passive  Vip-IRES-Cre  ...
# 4783                       OPHYS_4_images_A  Vip-IRES-Cre  ...
# 4784               OPHYS_5_images_A_passive  Vip-IRES-Cre  ...
# 4785                       OPHYS_6_images_A  Vip-IRES-Cre  ...
# 4786               OPHYS_5_images_A_passive  Vip-IRES-Cre  ...
#
#      miss_trial_count  false_alarm_trial_count  correct_reject_trial_count  \
# 0                   0                        0                           0
# 1                 275                        4                          45
# 2                 300                        3                          38
# 3                 312                        0                          42
# 4                 300                        3                          41
# ...               ...                      ...                         ...
# 4782              357                        0                          52
# 4783              114                        6                          20
# 4784              353                        0                          49
# 4785               35                        5                          10
# 4786              354                        0                          50
#
#       engaged_trial_count  ophys_session_id  imaging_plane_group_count  \
# 0                      70               NaN                        NaN
# 1                      27               NaN                        NaN
# 2                       0               NaN                        NaN
# 3                       0               NaN                        NaN
# 4                       5               NaN                        NaN
# ...                   ...               ...                        ...
# 4782                    0       993512923.0                        NaN
# 4783                  314       993668836.0                        NaN
# 4784                    0       993948045.0                        NaN
# 4785                   87       994689422.0                        NaN
# 4786                    0       994868382.0                        NaN
#
#       ophys_experiment_id  ophys_container_id      date_of_acquisition  \
# 0                     NaN                 NaN  2019-05-17 14:46:33.550
# 1                     NaN                 NaN  2019-05-21 13:22:20.613
# 2                     NaN                 NaN  2019-05-22 13:19:52.005
# 3                     NaN                 NaN  2019-05-23 13:40:31.405
# 4                     NaN                 NaN  2019-05-24 11:06:39.332
# ...                   ...                 ...                      ...
# 4782          [993590480]         [991913246]  2019-12-10 12:25:49.549
# 4783          [993862120]         [991913246]  2019-12-11 08:57:44.877
# 4784          [994053909]         [991913246]  2019-12-12 09:29:20.785
# 4785          [994791582]         [991913246]  2019-12-16 09:27:10.443
# 4786          [994956406]         [991913246]  2019-12-17 09:39:25.881
#
#                   project_code
# 0     VisualBehaviorMultiscope
# 1     VisualBehaviorMultiscope
# 2     VisualBehaviorMultiscope
# 3     VisualBehaviorMultiscope
# 4     VisualBehaviorMultiscope
# ...                        ...
# 4782      VisualBehaviorTask1B
# 4783      VisualBehaviorTask1B
# 4784      VisualBehaviorTask1B
# 4785      VisualBehaviorTask1B
# 4786      VisualBehaviorTask1B
#
# [4787 rows x 29 columns]

# %%
# Example behavior session NWB. There are several others to test in the same directory.
behavior_session = BehaviorSession.from_nwb_path(base_path / 'behavior_sessions/893560763.nwb')

# %%
behavior_session.stimulus_presentations
# Out:
#                            duration  end_frame  flashes_since_change  \
# stimulus_presentations_id
# 0                          0.250219      18000                   0.0
# 1                          0.250237      18045                   1.0
# 2                          0.250198      18090                   2.0
# 3                          0.250206      18135                   3.0
# 4                          0.250191      18180                   4.0
# ...                             ...        ...                   ...
# 13782                      0.033366     269823                9094.0
# 13783                      0.033352     269825                9095.0
# 13784                      0.033365     269827                9096.0
# 13785                      0.033369     269829                9097.0
# 13786                      0.016674     269831                9098.0
#
#                            image_index image_name  is_change  is_image_novel  \
# stimulus_presentations_id
# 0                                  0.0      im065      False           False
# 1                                  0.0      im065      False           False
# 2                                  0.0      im065      False           False
# 3                                  0.0      im065      False           False
# 4                                  0.0      im065      False           False
# ...                                ...        ...        ...             ...
# 13782                              NaN        NaN      False            <NA>
# 13783                              NaN        NaN      False            <NA>
# 13784                              NaN        NaN      False            <NA>
# 13785                              NaN        NaN      False            <NA>
# 13786                              NaN        NaN      False            <NA>
#
#                            movie_frame_index  omitted  repeat  start_frame  \
# stimulus_presentations_id
# 0                                        NaN    False     NaN        17985
# 1                                        NaN    False     NaN        18030
# 2                                        NaN    False     NaN        18075
# 3                                        NaN    False     NaN        18120
# 4                                        NaN    False     NaN        18165
# ...                                      ...      ...     ...          ...
# 13782                                  895.0     <NA>     9.0       269822
# 13783                                  896.0     <NA>     9.0       269824
# 13784                                  897.0     <NA>     9.0       269826
# 13785                                  898.0     <NA>     9.0       269828
# 13786                                  899.0     <NA>     9.0       269830
#
#                             start_time  stimulus_block  \
# stimulus_presentations_id
# 0                           300.021065               0
# 1                           300.771696               0
# 2                           301.522332               0
# 3                           302.272965               0
# 4                           303.023618               0
# ...                                ...             ...
# 13782                      4500.894073               2
# 13783                      4500.927438               2
# 13784                      4500.960790               2
# 13785                      4500.994155               2
# 13786                      4501.027524               2
#
#                                                           stimulus_name  \
# stimulus_presentations_id
# 0                          Natural_Images_Lum_Matched_set_training_2017
# 1                          Natural_Images_Lum_Matched_set_training_2017
# 2                          Natural_Images_Lum_Matched_set_training_2017
# 3                          Natural_Images_Lum_Matched_set_training_2017
# 4                          Natural_Images_Lum_Matched_set_training_2017
# ...                                                                 ...
# 13782                                                 natural_movie_one
# 13783                                                 natural_movie_one
# 13784                                                 natural_movie_one
# 13785                                                 natural_movie_one
# 13786                                                 natural_movie_one
#
#                               end_time
# stimulus_presentations_id
# 0                           300.271285
# 1                           301.021932
# 2                           301.772530
# 3                           302.523171
# 4                           303.273809
# ...                                ...
# 13782                      4500.927438
# 13783                      4500.960790
# 13784                      4500.994155
# 13785                      4501.027524
# 13786                      4501.044198
#
# [13787 rows x 15 columns]

# %%
behavior_session.metadata
# Out:
# {'equipment_name': 'BEH.D-Box3',
#  'sex': 'F',
#  'age_in_days': 233,
#  'stimulus_frame_rate': 60.0,
#  'session_type': 'TRAINING_5_images_A_handoff_ready',
#  'date_of_acquisition': datetime.datetime(2019, 6, 24, 13, 10, 41, 640000, tzinfo=tzutc()),
#  'reporter_line': 'Ai148(TIT2L-GC6f-ICL-tTA2)',
#  'cre_line': 'Sst-IRES-Cre',
#  'behavior_session_uuid': UUID('54e58e01-0dc4-44fb-81f5-7cda93591eca'),
#  'driver_line': ['Sst-IRES-Cre'],
#  'mouse_id': 457841,
#  'project_code': 'VisualBehaviorMultiscope',
#  'full_genotype': 'Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt',
#  'behavior_session_id': 893560763}

# %% [markdown]
# Ophys Experiment
# -----------

# %%
ophys_experiments = pd.read_csv(base_path / 'ophys_experiment_table.csv')
ophys_experiments
# Out:
#       ophys_experiment_id equipment_name  \
# 0               951980471         MESO.1
# 1               951980473         MESO.1
# 2               951980475         MESO.1
# 3               951980479         MESO.1
# 4               951980481         MESO.1
# ...                   ...            ...
# 1936            993590480        CAM2P.4
# 1937            993862120        CAM2P.4
# 1938            994053909        CAM2P.4
# 1939            994791582        CAM2P.4
# 1940            994956406        CAM2P.4
#
#                                       full_genotype  mouse_id  \
# 0     Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 1     Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 2     Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 3     Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 4     Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# ...                                             ...       ...
# 1936  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
# 1937  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
# 1938  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
# 1939  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
# 1940  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
#
#                    reporter_line       driver_line sex  age_in_days  \
# 0     Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F        206.0
# 1     Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F        206.0
# 2     Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F        206.0
# 3     Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F        206.0
# 4     Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F        206.0
# ...                          ...               ...  ..          ...
# 1936  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        128.0
# 1937  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        129.0
# 1938  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        130.0
# 1939  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        134.0
# 1940  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        135.0
#
#                   session_type      cre_line  ... experiment_workflow_state  \
# 0             OPHYS_1_images_A  Sst-IRES-Cre  ...                    passed
# 1             OPHYS_1_images_A  Sst-IRES-Cre  ...                    passed
# 2             OPHYS_1_images_A  Sst-IRES-Cre  ...                    passed
# 3             OPHYS_1_images_A  Sst-IRES-Cre  ...                    passed
# 4             OPHYS_1_images_A  Sst-IRES-Cre  ...                    passed
# ...                        ...           ...  ...                       ...
# 1936  OPHYS_2_images_B_passive  Vip-IRES-Cre  ...                    passed
# 1937          OPHYS_4_images_A  Vip-IRES-Cre  ...                    passed
# 1938  OPHYS_5_images_A_passive  Vip-IRES-Cre  ...                    passed
# 1939          OPHYS_6_images_A  Vip-IRES-Cre  ...                    passed
# 1940  OPHYS_5_images_A_passive  Vip-IRES-Cre  ...                    passed
#
#       isi_experiment_id  imaging_depth  targeted_structure  published_at  \
# 0             848974280            150                VISp    2021-03-25
# 1             848974280            225                VISp    2021-03-25
# 2             848974280             75                VISp    2021-03-25
# 3             848974280            150                VISl    2021-03-25
# 4             848974280            225                VISl    2021-03-25
# ...                 ...            ...                 ...           ...
# 1936          967103425            175                VISp    2021-03-25
# 1937          967103425            175                VISp    2021-03-25
# 1938          967103425            175                VISp    2021-03-25
# 1939          967103425            175                VISp    2021-03-25
# 1940          967103425            175                VISp    2021-03-25
#
#           date_of_acquisition              project_code  experience_level  \
# 0     2019-09-20 09:59:38.837  VisualBehaviorMultiscope          Familiar
# 1     2019-09-20 09:59:38.837  VisualBehaviorMultiscope          Familiar
# 2     2019-09-20 09:59:38.837  VisualBehaviorMultiscope          Familiar
# 3     2019-09-20 09:59:38.837  VisualBehaviorMultiscope          Familiar
# 4     2019-09-20 09:59:38.837  VisualBehaviorMultiscope          Familiar
# ...                       ...                       ...               ...
# 1936  2019-12-10 12:25:49.549      VisualBehaviorTask1B          Familiar
# 1937  2019-12-11 08:57:44.877      VisualBehaviorTask1B           Novel 1
# 1938  2019-12-12 09:29:20.785      VisualBehaviorTask1B          Novel >1
# 1939  2019-12-16 09:27:10.443      VisualBehaviorTask1B          Novel >1
# 1940  2019-12-17 09:39:25.881      VisualBehaviorTask1B          Novel >1
#
#       passive image_set
# 0       False         A
# 1       False         A
# 2       False         A
# 3       False         A
# 4       False         A
# ...       ...       ...
# 1936     True         B
# 1937    False         A
# 1938     True         A
# 1939    False         A
# 1940     True         A
#
# [1941 rows x 30 columns]

# %%
# Example ophys experiment NWB. There are several others to test in the same directory.
ophys_experiment = BehaviorOphysExperiment.from_nwb_path(base_path / 'ophys_experiments/795952471.nwb')
# Out:
# /allen/aibs/informatics/chris.morrison/miniconda/envs/allensdk_jupyter/lib/python3.8/site-packages/pynwb/base.py:193: UserWarning: RoiResponseSeries 'RMSE': Length of data does not match length of timestamps. Your data may be transposed. Time should be on the 0th dimension
#   warn("%s '%s': Length of data does not match length of timestamps. Your data may be transposed. "
# /allen/aibs/informatics/chris.morrison/miniconda/envs/allensdk_jupyter/lib/python3.8/site-packages/pynwb/base.py:193: UserWarning: RoiResponseSeries 'r': Length of data does not match length of timestamps. Your data may be transposed. Time should be on the 0th dimension
#   warn("%s '%s': Length of data does not match length of timestamps. Your data may be transposed. "

# %%
ophys_experiment.stimulus_presentations
# Out:
#                            duration  end_frame  flashes_since_change  \
# stimulus_presentations_id
# 0                           0.25010      17999                   0.0
# 1                           0.25027      18044                   1.0
# 2                           0.25030      18089                   2.0
# 3                           0.25014      18134                   3.0
# 4                           0.25018      18179                   4.0
# ...                             ...        ...                   ...
# 13808                       0.03337     270497                9002.0
# 13809                       0.03335     270499                9003.0
# 13810                       0.03337     270501                9004.0
# 13811                       0.03336     270503                9005.0
# 13812                       0.03332     270505                9006.0
#
#                            image_index image_name  is_change  is_image_novel  \
# stimulus_presentations_id
# 0                                  0.0      im000      False           False
# 1                                  0.0      im000      False           False
# 2                                  0.0      im000      False           False
# 3                                  0.0      im000      False           False
# 4                                  0.0      im000      False           False
# ...                                ...        ...        ...             ...
# 13808                              NaN        NaN      False            <NA>
# 13809                              NaN        NaN      False            <NA>
# 13810                              NaN        NaN      False            <NA>
# 13811                              NaN        NaN      False            <NA>
# 13812                              NaN        NaN      False            <NA>
#
#                            movie_frame_index  omitted  repeat  start_frame  \
# stimulus_presentations_id
# 0                                        NaN    False     NaN        17984
# 1                                        NaN    False     NaN        18029
# 2                                        NaN    False     NaN        18074
# 3                                        NaN    False     NaN        18119
# 4                                        NaN    False     NaN        18164
# ...                                      ...      ...     ...          ...
# 13808                                  895.0     <NA>     9.0       270496
# 13809                                  896.0     <NA>     9.0       270498
# 13810                                  897.0     <NA>     9.0       270500
# 13811                                  898.0     <NA>     9.0       270502
# 13812                                  899.0     <NA>     9.0       270504
#
#                             start_time  stimulus_block  \
# stimulus_presentations_id
# 0                           308.475208               0
# 1                           309.225748               0
# 2                           309.976348               0
# 3                           310.727038               0
# 4                           311.477668               0
# ...                                ...             ...
# 13808                      4520.611958               2
# 13809                      4520.645328               2
# 13810                      4520.678678               2
# 13811                      4520.712048               2
# 13812                      4520.745408               2
#
#                                                          stimulus_name  \
# stimulus_presentations_id
# 0                          Natural_Images_Lum_Matched_set_ophys_6_2017
# 1                          Natural_Images_Lum_Matched_set_ophys_6_2017
# 2                          Natural_Images_Lum_Matched_set_ophys_6_2017
# 3                          Natural_Images_Lum_Matched_set_ophys_6_2017
# 4                          Natural_Images_Lum_Matched_set_ophys_6_2017
# ...                                                                ...
# 13808                                                natural_movie_one
# 13809                                                natural_movie_one
# 13810                                                natural_movie_one
# 13811                                                natural_movie_one
# 13812                                                natural_movie_one
#
#                               end_time
# stimulus_presentations_id
# 0                           308.725308
# 1                           309.476018
# 2                           310.226648
# 3                           310.977178
# 4                           311.727848
# ...                                ...
# 13808                      4520.645328
# 13809                      4520.678678
# 13810                      4520.712048
# 13811                      4520.745408
# 13812                      4520.778728
#
# [13813 rows x 15 columns]

# %%
ophys_experiment.metadata
# Out:
# {'equipment_name': 'CAM2P.4',
#  'sex': 'F',
#  'age_in_days': 161,
#  'stimulus_frame_rate': 60.0,
#  'session_type': 'OPHYS_5_images_B_passive',
#  'date_of_acquisition': datetime.datetime(2018, 12, 14, 8, 35, 41, 725000, tzinfo=tzutc()),
#  'reporter_line': 'Ai93(TITL-GCaMP6f)',
#  'cre_line': 'Slc17a7-IRES2-Cre',
#  'behavior_session_uuid': UUID('053e0bb4-cd11-4757-af90-43b6ce821894'),
#  'driver_line': ['Camk2a-tTA', 'Slc17a7-IRES2-Cre'],
#  'mouse_id': 412366,
#  'project_code': 'Not Available',
#  'full_genotype': 'Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP6f)/wt',
#  'behavior_session_id': 795431009,
#  'indicator': 'GCaMP6f',
#  'emission_lambda': 520.0,
#  'excitation_lambda': 910.0,
#  'ophys_container_id': 814796612,
#  'field_of_view_height': 512,
#  'field_of_view_width': 451,
#  'imaging_depth': 375,
#  'targeted_imaging_depth': 375,
#  'imaging_plane_group': None,
#  'imaging_plane_group_count': 0,
#  'ophys_experiment_id': 795952471,
#  'ophys_frame_rate': 31.0,
#  'ophys_session_id': 795217244,
#  'targeted_structure': 'VISp'}

# %% [markdown]
# Other Tables
# ============

# %%
ophys_sessions = pd.read_csv(base_path / 'ophys_session_table.csv')
ophys_sessions
# Out:
#      ophys_session_id equipment_name  \
# 0           951410079         MESO.1
# 1           952430817         MESO.1
# 2           954954402         MESO.1
# 3           955775716         MESO.1
# 4           957020350         MESO.1
# ..                ...            ...
# 699         993512923        CAM2P.4
# 700         993668836        CAM2P.4
# 701         993948045        CAM2P.4
# 702         994689422        CAM2P.4
# 703         994868382        CAM2P.4
#
#                                      full_genotype  mouse_id  \
# 0    Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 1    Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 2    Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 3    Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 4    Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# ..                                             ...       ...
# 699  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
# 700  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
# 701  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
# 702  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
# 703  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    489066
#
#                   reporter_line       driver_line sex  age_in_days  \
# 0    Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F        206.0
# 1    Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F        209.0
# 2    Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F        210.0
# 3    Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F        212.0
# 4    Ai148(TIT2L-GC6f-ICL-tTA2)  ['Sst-IRES-Cre']   F        213.0
# ..                          ...               ...  ..          ...
# 699  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        128.0
# 700  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        129.0
# 701  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        130.0
# 702  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        134.0
# 703  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F        135.0
#
#                  session_type      cre_line  ... session_number  \
# 0            OPHYS_1_images_A  Sst-IRES-Cre  ...            1.0
# 1    OPHYS_2_images_A_passive  Sst-IRES-Cre  ...            2.0
# 2            OPHYS_3_images_A  Sst-IRES-Cre  ...            3.0
# 3            OPHYS_3_images_A  Sst-IRES-Cre  ...            3.0
# 4            OPHYS_4_images_B  Sst-IRES-Cre  ...            4.0
# ..                        ...           ...  ...            ...
# 699  OPHYS_2_images_B_passive  Vip-IRES-Cre  ...            2.0
# 700          OPHYS_4_images_A  Vip-IRES-Cre  ...            4.0
# 701  OPHYS_5_images_A_passive  Vip-IRES-Cre  ...            5.0
# 702          OPHYS_6_images_A  Vip-IRES-Cre  ...            6.0
# 703  OPHYS_5_images_A_passive  Vip-IRES-Cre  ...            5.0
#
#      prior_exposures_to_session_type  prior_exposures_to_image_set  \
# 0                                  0                          65.0
# 1                                  0                          66.0
# 2                                  0                          67.0
# 3                                  1                          68.0
# 4                                  0                           0.0
# ..                               ...                           ...
# 699                                0                          12.0
# 700                                0                           0.0
# 701                                0                           1.0
# 702                                0                           2.0
# 703                                1                           3.0
#
#      prior_exposures_to_omissions  behavior_session_id  \
# 0                               0            951520319
# 1                               1            952554548
# 2                               2            953982960
# 3                               3            956010809
# 4                               4            957032492
# ..                            ...                  ...
# 699                             2            993537991
# 700                             3            993691759
# 701                             4            993959724
# 702                             5            994710581
# 703                             6            994882261
#
#      imaging_plane_group_count  \
# 0                          4.0
# 1                          3.0
# 2                          4.0
# 3                          2.0
# 4                          4.0
# ..                         ...
# 699                        NaN
# 700                        NaN
# 701                        NaN
# 702                        NaN
# 703                        NaN
#
#                                    ophys_experiment_id  \
# 0    [951980471, 951980473, 951980475, 951980479, 9...
# 1         [953659743, 953659745, 953659749, 953659752]
# 2    [958527464, 958527471, 958527474, 958527479, 9...
# 3                    [956941841, 956941844, 956941846]
# 4    [957759562, 957759564, 957759566, 957759570, 9...
# ..                                                 ...
# 699                                        [993590480]
# 700                                        [993862120]
# 701                                        [994053909]
# 702                                        [994791582]
# 703                                        [994956406]
#
#                                     ophys_container_id  \
# 0    [1018028339, 1018028342, 1018028345, 101802835...
# 1     [1018028339, 1018028345, 1018028354, 1018028357]
# 2    [1018028339, 1018028342, 1018028345, 101802835...
# 3                 [1018028339, 1018028342, 1018028345]
# 4    [1018028339, 1018028342, 1018028345, 101802835...
# ..                                                 ...
# 699                                        [991913246]
# 700                                        [991913246]
# 701                                        [991913246]
# 702                                        [991913246]
# 703                                        [991913246]
#
#          date_of_acquisition              project_code
# 0    2019-09-20 09:59:38.837  VisualBehaviorMultiscope
# 1    2019-09-23 08:45:38.490  VisualBehaviorMultiscope
# 2    2019-09-24 09:01:31.582  VisualBehaviorMultiscope
# 3    2019-09-26 09:22:21.772  VisualBehaviorMultiscope
# 4    2019-09-27 08:58:37.005  VisualBehaviorMultiscope
# ..                       ...                       ...
# 699  2019-12-10 12:25:49.549      VisualBehaviorTask1B
# 700  2019-12-11 08:57:44.877      VisualBehaviorTask1B
# 701  2019-12-12 09:29:20.785      VisualBehaviorTask1B
# 702  2019-12-16 09:27:10.443      VisualBehaviorTask1B
# 703  2019-12-17 09:39:25.881      VisualBehaviorTask1B
#
# [704 rows x 21 columns]

# %%
cells_table = pd.read_csv(base_path / 'ophys_cells_table.csv')
cells_table
# Out:
#         cell_roi_id  cell_specimen_id  ophys_experiment_id    x    y  height  \
# 0        1080884343        1086496928            775614751   63  380      19
# 1        1080884173        1086496914            775614751  272  463      15
# 2        1080883843        1086496838            775614751  210  361      17
# 3        1080886674        1086491756            775614751  136  230      17
# 4        1080885658        1086491699            775614751   45  435      20
# ...             ...               ...                  ...  ...  ...     ...
# 133130   1115385589        1120127229           1110928073  166  212      19
# 133131   1115385513        1120127083           1110928073  117   68      19
# 133132   1115301580        1120126794           1110928075  419  417      15
# 133133   1115301595        1120126500           1110928075  121  342      17
# 133134   1115301537        1120126373           1110928075  236  187      17
#
#         width
# 0          17
# 1          19
# 2          17
# 3          15
# 4          14
# ...       ...
# 133130     19
# 133131     17
# 133132     17
# 133133     15
# 133134     20
#
# [133135 rows x 7 columns]
