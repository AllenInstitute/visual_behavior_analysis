# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# import sys
# sys.path.append(r'C:\Users\justink\Code\dro')

from dro import utilities as dro
from dro import plotting_functions as dro_plots
# Out:
# /home/justink/.conda/envs/braintv_behav/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# failed to import CV2 in core.utilities
# failed to import mask in core.jcamdata.py
# failed to import get_mask_dict_gui in core.epoch.py
# failed to import aibs.Analysis.Core.smooth
# failed to import mask relalated functions in __init__.py

# %%
from braintv_pilot.cohorts import cohort_assignment
cohort_assignment
# Out:
#       mouse                   experiment  cohort   day_zero
# 0   M272464  visual_behavior_development       4 2016-10-31
# 1   M271733  visual_behavior_development       4 2016-10-31
# 2   M271728  visual_behavior_development       4 2016-10-31
# 3   M276951  visual_behavior_development       4 2016-10-31
# 4   M276950  visual_behavior_development       4 2016-10-31
# 5   M276600  visual_behavior_development       4 2016-10-31
# 6   M272465  visual_behavior_development       3 2016-10-10
# 7   M265158  visual_behavior_development       3 2016-10-10
# 8   M271966  visual_behavior_development       3 2016-10-10
# 9   M265154  visual_behavior_development       3 2016-10-10
# 10  M258194  visual_behavior_development       3 2016-10-10
# 11  M265166  visual_behavior_development       3 2016-10-10
# 12  M258173  visual_behavior_development       2 2016-09-19
# 13  M258089  visual_behavior_development       2 2016-09-19
# 14  M258276  visual_behavior_development       2 2016-09-19
# 15  M261584  visual_behavior_development       2 2016-09-19
# 16  M258274  visual_behavior_development       2 2016-09-19
# 17  M258275  visual_behavior_development       2 2016-09-19
# 18  M246782  visual_behavior_development       1 2016-08-22
# 19  M249123  visual_behavior_development       1 2016-08-22
# 20  M258174  visual_behavior_development       1 2016-08-22
# 21  M250783  visual_behavior_development       1 2016-08-22
# 22  M250786  visual_behavior_development       1 2016-08-22
# 23  M258196  visual_behavior_development       1 2016-08-22
# 24  M273577  visual_behavior_development       5 2016-11-28
# 25  M273578  visual_behavior_development       5 2016-11-28
# 26  M278229  visual_behavior_development       5 2016-11-28
# 27  M276444  visual_behavior_development       5 2016-11-28
# 28  M275962  visual_behavior_development       5 2016-11-28
# 29  M276445  visual_behavior_development       5 2016-11-28
# 30  M275965  visual_behavior_development       6 2017-01-16
# 31  M275963  visual_behavior_development       6 2017-01-16
# 32  M277931  visual_behavior_development       6 2017-01-16
# 33  M278329  visual_behavior_development       6 2017-01-16
# 34  M278463  visual_behavior_development       6 2017-01-16
# 35  M278332  visual_behavior_development       6 2017-01-16

# %%
mice = cohort_assignment[cohort_assignment.cohort==6]['mouse']
print mice
# Out:
# 30    M275965
# 31    M275963
# 32    M277931
# 33    M278329
# 34    M278463
# 35    M278332
# Name: mouse, dtype: object

# %%
from braintv_pilot.latest import local_dir
trials = pd.concat([
    dro.load_from_folder(local_dir,filename_contains=mouse,load_existing_dataframe=False,save_dataframe=False)
    for mouse in mice
    ])
# Out:
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170119141121-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170127134855-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170124100046-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170203113406-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170126141745-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170123122707-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170125143736-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170116112904-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170201110949-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170117140749-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170118141604-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M275965.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170207145155-task=DetectionOfChange_General_stage=2_SolicitRewards_fixed_duration_mouse=M275965.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170208145203-task=DetectionOfChange_General_stage=2_SolicitRewards_fixed_duration_mouse=M275965.pkl
# /home/justink/Code/dro/dro/utilities.py:137: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is
# /home/justink/Code/dro/dro/utilities.py:137: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 60 but corresponding boolean dimension is 59
# /home/justink/Code/dro/dro/utilities.py:137: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 79 but corresponding boolean dimension is 78
# /home/justink/Code/dro/dro/utilities.py:137: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 88 but corresponding boolean dimension is 87
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170123122421-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278463.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170118135106-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278463.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170202160538-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278463.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170117141414-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278463.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170206152606-task=DetectionOfChange_General_stage=2_SolicitRewards_fixed_duration_mouse=M278463.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170125145544-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278463.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170203110139-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170127134852-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170126141742-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170118135706-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170130145709-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170123122319-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170206153337-task=DetectionOfChange_General_stage=2_SolicitRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170209150504-task=DetectionOfChange_General_stage=2_SolicitRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170119140712-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170116111935-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170117141411-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170207141735-task=DetectionOfChange_General_stage=2_SolicitRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170208141525-task=DetectionOfChange_General_stage=2_SolicitRewards_fixed_duration_mouse=M278332.pkl
# /home/justink/Code/dro/dro/utilities.py:137: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 14 but corresponding boolean dimension is 13
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170201110943-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170131134626-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170202154652-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170125143747-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170124100045-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl
# Loading /local1/Projects/braintv_behavior_piloting/braintv_pilot/../data/raw/170116120723-task=DetectionOfChange_General_stage=1_AutoRewards_fixed_duration_mouse=M278332.pkl

# %%
trials['trial_scheduled_change_time'] =  trials['scheduled_change_time'] - trials['starttime']# - trials['prechange_minimum']

# %%
trials['wait_time'] = trials['lick_times'].map(lambda x: x[0] if len(x)>0 else None) - trials['starttime']
trials['lick_time_from_change'] = trials['lick_times'].map(lambda x: x[0] if len(x)>0 else None) - trials['scheduled_change_time']

# %%
from braintv_pilot.cohorts import mouse_info
mouse_df = cohort_assignment['mouse'].apply(lambda mouse: pd.Series(mouse_info(mouse)))
cohort_assignment = cohort_assignment.merge(
    mouse_df,
    how='left',
    left_on='mouse',
    right_on='mouse_id'
)

# %%
trials = trials.merge(
    cohort_assignment,
    how='left',
    on='mouse_id',
)

# %%
day_zero = {r['mouse']:"{:%Y-%m-%d}".format(r['day_zero']) for _,r in cohort_assignment.iterrows()}

def get_training_day(df_in):
    '''adds a column to the dataframe with the number of unique training days up to that point
         '''
    coh = cohort_assignment.set_index('mouse')['cohort']
#     print coh

    training_day_lookup = {}
    for mouse, group in df_in.groupby('mouse_id'):
        dates = np.sort(group['date'].unique())
        try:
            dz = day_zero[mouse]
            offset = np.argwhere(dates==dz)[0][0]
        except KeyError:
            print 'day zero not found for {}'.format(mouse)
            offset = 0
        except IndexError:
            print 'day zero ({}) not found in dates'.format(dz)
            offset = 0
        print offset
        training_day_lookup[mouse] = {date:training_day-offset for training_day,date in enumerate(dates)}
        print mouse,dates
    return df_in.apply(lambda row: training_day_lookup[row['mouse_id']][row['date']],axis=1)

trials['training_day'] = get_training_day(trials)
# Out:
# 0
# M275963 ['2017-01-16' '2017-01-17' '2017-01-18' '2017-01-19' '2017-01-23'
#  '2017-01-24' '2017-01-25' '2017-01-26' '2017-01-27' '2017-01-30'
#  '2017-01-31' '2017-02-01' '2017-02-02' '2017-02-03' '2017-02-06'
#  '2017-02-07' '2017-02-08' '2017-02-09']
# 0
# M275965 ['2017-01-16' '2017-01-17' '2017-01-18' '2017-01-19' '2017-01-23'
#  '2017-01-24' '2017-01-25' '2017-01-26' '2017-01-27' '2017-01-30'
#  '2017-01-31' '2017-02-01' '2017-02-02' '2017-02-03' '2017-02-06'
#  '2017-02-07' '2017-02-08' '2017-02-09']
# 0
# M277931 ['2017-01-16' '2017-01-17' '2017-01-18' '2017-01-19' '2017-01-23'
#  '2017-01-24' '2017-01-25' '2017-01-26' '2017-01-27' '2017-01-30'
#  '2017-01-31' '2017-02-01' '2017-02-02' '2017-02-03' '2017-02-06'
#  '2017-02-07' '2017-02-08' '2017-02-09']
# 0
# M278329 ['2017-01-16' '2017-01-17' '2017-01-18' '2017-01-19' '2017-01-23'
#  '2017-01-24' '2017-01-25' '2017-01-26' '2017-01-27' '2017-01-30'
#  '2017-01-31' '2017-02-01' '2017-02-02' '2017-02-03' '2017-02-06'
#  '2017-02-07' '2017-02-08' '2017-02-09']
# 0
# M278332 ['2017-01-16' '2017-01-17' '2017-01-18' '2017-01-19' '2017-01-23'
#  '2017-01-24' '2017-01-25' '2017-01-26' '2017-01-27' '2017-01-30'
#  '2017-01-31' '2017-02-01' '2017-02-02' '2017-02-03' '2017-02-06'
#  '2017-02-07' '2017-02-08' '2017-02-09']
# 0
# M278463 ['2017-01-16' '2017-01-17' '2017-01-18' '2017-01-19' '2017-01-23'
#  '2017-01-24' '2017-01-25' '2017-01-26' '2017-01-27' '2017-01-30'
#  '2017-01-31' '2017-02-01' '2017-02-02' '2017-02-03' '2017-02-06'
#  '2017-02-07' '2017-02-08' '2017-02-09']

# %%
import itertools

for key1,group1 in trials.groupby('mouse_id'):
    plt.figure()
    plt.title(key1)
    
    for key,group in group1.groupby('date'):

        lick_times = []
        for _,row in group.iterrows():
            lick_times.append([t-row['starttime'] for t in row['lick_times']])
        lick_times = np.array(list(itertools.chain.from_iterable(lick_times)))
        print lick_times.max()
#         lick_times = lick_times[lick_times>9]
        plt.hist(lick_times,bins=np.arange(0,18,0.5),histtype='step',label=key,normed=True)
    plt.xlim(0,18)
    plt.axvline(17)
    plt.legend()
# Out:
# 18.0672175065
# 18.0010407194
# 18.0016744547
# 18.0168821514
# 18.0171605311
# 18.0014582947
# 18.0685706027
# 18.0512339994
# 18.003160648
# 18.2005389929
# 18.2003616393
# 18.0668284819
# 46.0353303477
# 18.0006231517
# 18.1836151555
# 75.7849095687
# 18.1503206939
# 18.1675864309
# 18.9021426141
# 18.0009951852
# 18.003874898
# 18.0021433495
# 17.9842364565
# 18.0007629842
# 18.0010923594
# 18.0016802326
# 18.0006340593
# 18.1337990016
# 18.0006170645
# 17.9834262207
# 46.1375089958
# 18.0003601685
# 17.616994299
# 47.4021196738
# 17.9839178845
# 18.1838901117
# 18.0018529892
# 18.0032073855
# 18.0016318336
# 18.0186080113
# 18.0037351102
# 18.0005836599
# 18.0025574528
# 18.003114298
# 18.0190552548
# 18.0004773885
# 18.1174587086
# 18.20090314
# 72.353392968
# 18.1674337909
# 18.0171314552
# 66.0031338902
# 18.0015659183
# 18.1506757811
# 18.0097078308
# 18.0033771656
# 18.0030195639
# 18.018433623
# 18.0041209124
# 18.0507649444
# 18.0169935971
# 18.0014945492
# 18.0338261947
# 18.0675387606
# 18.1513413787
# 18.151311554
# 67.4692943655
# 17.9841950834
# 15.4988593683
# 62.9692869186
# 18.0035583526
# 17.9675097987
# 18.0004863292
# 18.0007303208
# 18.0014699139
# 18.6349813007
# 18.0201993994
# 18.0010676831
# 18.001663927
# 18.0014354922
# 17.9173578694
# 17.9840139225
# 17.7674617916
# 13.9641543999
# 59.8365219049
# 18.001440458
# 16.7329702452
# 40.2207386326
# 17.9845518991
# 17.9340285882
# 18.0344322883
# 18.4855056964
# 18.0020529293
# 18.0018006563
# 18.0038900003
# 18.00251678
# 18.0509377979
# 18.0189324543
# 18.0022476241
# 18.1844274178
# 18.1676690802
# 18.2034942955
# 101.420118349
# 18.1675273925
# 16.9832433164
# 65.5699957227
# 18.1679031551
# 18.1519933417

# %%
def post_change_lick_rate(row):
#     print 'in function'
    a = (np.array(row['lick_times'])-row['change_time'])
    return np.logical_and(a>0,a<1).any()

def pre_change_lick_rate(row):
    a = (np.array(row['lick_times'])-row['change_time'])
    return np.logical_and(a>-1,a<0).any()

# %%
trials['post_change_lick_likelihood'] = trials.apply(post_change_lick_rate,axis=1)
trials['pre_change_lick_likelihood'] = trials.apply(pre_change_lick_rate,axis=1)

# %%
trials.sort_values('date',inplace=True)

# %%
mask = (
    trials['date'].isin(['2017-02-02','2017-02-03','2017-02-06','2017-02-07','2017-02-08','2017-02-09'])
    )

# %%
mask.sum()
# Out:
# 5061

# %%
trials['auto_rewarded'] = (trials['auto_rewarded']==True)

# %%
sns.factorplot('date','post_change_lick_likelihood',data=trials[mask],
               hue='mouse_id',
               aspect=2,
               row='auto_rewarded',
              )

# %%
sns.factorplot('date','pre_change_lick_likelihood',data=trials[mask],
               hue='mouse_id',
               row='auto_rewarded',
               aspect=2,
              )
sns.factorplot('date','pre_change_lick_likelihood',data=trials[mask],
#                hue='mouse_id',
               row='auto_rewarded',
               aspect=2,
              )

# %%
agg = (
    trials[mask & (~trials['auto_rewarded'])]
    .groupby(['mouse_id','date'])['pre_change_lick_likelihood','post_change_lick_likelihood']
    .mean()
    .reset_index()
    )
agg['relative_lick_likelihood'] = agg['pre_change_lick_likelihood'] / agg['post_change_lick_likelihood']

# %%
sns.factorplot('date','relative_lick_likelihood',data=agg,
               hue='mouse_id',
#                aspect=2,
              )

# %%
from braintv_pilot.cohorts import mouse_info
trials['group'] = trials['mouse_id'].apply(lambda mouse: mouse_info(mouse)['group'])

# %%
sns.factorplot('date','post_change_lick_likelihood',data=trials[mask],
               hue='mouse_id',
#                col='group',
               row='auto_rewarded',
#                aspect=2,
              )

# %%
sns.factorplot('date','pre_change_lick_likelihood',data=trials[mask],
               hue='mouse_id',
#                col='group',
               row='auto_rewarded',
#                aspect=2,
              )

# %%
mask = ( 
    trials['date'].isin(['2017-02-07','2017-02-08','2017-02-09'])
    )

tidy = pd.melt(
    trials[mask],
    id_vars=['group','mouse_id','date','auto_rewarded'],
    value_vars=['pre_change_lick_likelihood','post_change_lick_likelihood'],
    var_name='window',
    value_name='lick',
)

tidy['window'] = tidy['window'].map(lambda x: x.split('_')[0])

sns.factorplot('window','lick',data=tidy,
               hue='mouse_id',
               row='auto_rewarded',
               col='date',
#                aspect=2,
              )
