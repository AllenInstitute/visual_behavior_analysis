# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_context('notebook', font_scale=1.5, rc={'lines.markeredgewidth': 2})

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import visual_behavior.data_access.loading as loading
import visual_behavior.ophys.response_analysis.utilities as ut
from visual_behavior.ophys.response_analysis.response_analysis import ResponseAnalysis

# %%
experiments_table = loading.get_filtered_ophys_experiment_table()

# %%
experiments_table.head()
# Out:
#                      ophys_session_id  behavior_session_id  container_id  \
# ophys_experiment_id
# 953659745                   952430817            952554548    1018028339
# 953659749                   952430817            952554548    1018028354
# 953659752                   952430817            952554548    1018028357
# 953659743                   952430817            952554548    1018028345
# 958527474                   954954402            953982960    1018028339
#
#                                  project_code container_workflow_state  \
# ophys_experiment_id
# 953659745            VisualBehaviorMultiscope                completed
# 953659749            VisualBehaviorMultiscope                completed
# 953659752            VisualBehaviorMultiscope                completed
# 953659743            VisualBehaviorMultiscope                completed
# 958527474            VisualBehaviorMultiscope                completed
#
#                     experiment_workflow_state              session_name  \
# ophys_experiment_id
# 953659745                              passed  20190923_457841_2imagesA
# 953659749                              passed  20190923_457841_2imagesA
# 953659752                              passed  20190923_457841_2imagesA
# 953659743                              passed  20190923_457841_2imagesA
# 958527474                              passed  20190924_457841_3imagesA
#
#                                  session_type equipment_name  \
# ophys_experiment_id
# 953659745            OPHYS_2_images_A_passive         MESO.1
# 953659749            OPHYS_2_images_A_passive         MESO.1
# 953659752            OPHYS_2_images_A_passive         MESO.1
# 953659743            OPHYS_2_images_A_passive         MESO.1
# 958527474                    OPHYS_3_images_A         MESO.1
#
#                             date_of_acquisition  ...  imaging_depth  \
# ophys_experiment_id                              ...
# 953659745            2019-09-23 08:13:07.627573  ...             75
# 953659749            2019-09-23 08:13:07.627573  ...            150
# 953659752            2019-09-23 08:13:07.627573  ...            225
# 953659743            2019-09-23 08:13:07.627573  ...            225
# 958527474            2019-09-24 16:00:00.000000  ...             75
#
#                      targeted_structure published_at  super_container_id  \
# ophys_experiment_id
# 953659745                          VISp          NaN           850862430
# 953659749                          VISl          NaN           850862430
# 953659752                          VISl          NaN           850862430
# 953659743                          VISp          NaN           850862430
# 958527474                          VISp          NaN           850862430
#
#                          cre_line session_tags  \
# ophys_experiment_id
# 953659745            Sst-IRES-Cre          NaN
# 953659749            Sst-IRES-Cre          NaN
# 953659752            Sst-IRES-Cre          NaN
# 953659743            Sst-IRES-Cre          NaN
# 958527474            Sst-IRES-Cre          NaN
#
#                                                           failure_tags  \
# ophys_experiment_id
# 953659745            z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...
# 953659749            z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...
# 953659752            z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...
# 953659743            z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...
# 958527474                                                          NaN
#
#                      exposure_number model_outputs_available      location
# ophys_experiment_id
# 953659745                          0                   False   Sst_VISp_75
# 953659749                          0                   False  Sst_VISl_150
# 953659752                          0                   False  Sst_VISl_225
# 953659743                          0                   False  Sst_VISp_225
# 958527474                          0                    True   Sst_VISp_75
#
# [5 rows x 27 columns]

# %%
arbitrary_index = 650
experiments_table.iloc[arbitrary_index]
# Out:
# ophys_session_id                                                     882386411
# behavior_session_id                                                  882446265
# container_id                                                        1018027561
# project_code                                          VisualBehaviorMultiscope
# container_workflow_state                                             completed
# experiment_workflow_state                                               passed
# session_name                                        20190606_451787_3imagesA_2
# session_type                                                  OPHYS_3_images_A
# equipment_name                                                          MESO.1
# date_of_acquisition                                 2019-06-06 13:37:46.000000
# isi_experiment_id                                                    846136902
# specimen_id                                                          837581585
# sex                                                                          M
# age_in_days                                                                127
# full_genotype                Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# reporter_line                                           ['Ai93(TITL-GCaMP6f)']
# driver_line                                ['Camk2a-tTA', 'Slc17a7-IRES2-Cre']
# imaging_depth                                                              225
# targeted_structure                                                        VISl
# published_at                                                               NaN
# super_container_id                                                   837581585
# cre_line                                                     Slc17a7-IRES2-Cre
# session_tags                                                               NaN
# failure_tags                                                               NaN
# exposure_number                                                              0
# model_outputs_available                                                   True
# location                                                      Slc17a7_VISl_225
# Name: 882551962, dtype: object

# %% [markdown]
# ### get metrics for one experiment

# %%
ophys_experiment_id = experiments_table.index.values[arbitrary_index]

dataset = loading.get_ophys_dataset(ophys_experiment_id)

# %%
analysis = ResponseAnalysis(dataset)
# Out:
# C:\Users\marinag\Documents\Code\AllenSDK\allensdk\brain_observatory\sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# C:\Users\marinag\Documents\Code\AllenSDK\allensdk\brain_observatory\sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# WARNING:root:acquiring (valid line label(s) = ['2p_acquiring']
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times

# %%
sdf = analysis.get_response_df(df_name='stimulus_response_df')
tdf = analysis.get_response_df(df_name='trials_response_df')
# Out:
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# C:\Users\marinag\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# C:\Users\marinag\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
msdf = ut.get_mean_df(sdf, conditions=['cell_specimen_id', 'omitted', 'image_name'], flashes=True)
mtdf = ut.get_mean_df(tdf, conditions=['cell_specimen_id', 'go', 'change_image_name'])

# pooled images and image changes
msdf_p = ut.get_mean_df(sdf, conditions=['cell_specimen_id', 'omitted'], flashes=True)
mtdf_p = ut.get_mean_df(tdf, conditions=['cell_specimen_id', 'go'])

# %%
session_type = dataset.metadata['session_type']
# Out:
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times

# %%
df_list = []
for cell_specimen_id in msdf.cell_specimen_id.unique():
    
    cdf = msdf[msdf.cell_specimen_id==cell_specimen_id]
    for omitted in cdf.omitted.unique():
        if omitted: 
            condition = 'omitted_post'
            mean_response = cdf[cdf.omitted==True].mean_response.values[0]
            df_list.append([cell_specimen_id, condition, mean_response])
            
            condition = 'omitted_pre'
            mean_response = cdf[cdf.omitted==True].mean_baseline.values[0]
            df_list.append([cell_specimen_id, condition, mean_response])
        else: 
            for i, image_name in enumerate(cdf.image_name.unique()): 
                if 'images_B' in session_type: 
                    i = i+8
                condition = 'im'+str(i)+'_post'
                mean_response = cdf[cdf.image_name==image_name].mean_response.values[0]
                df_list.append([cell_specimen_id, condition, mean_response])
                condition = 'im'+str(i)+'_pre'
                mean_response = cdf[cdf.image_name==image_name].mean_baseline.values[0]
                df_list.append([cell_specimen_id, condition, mean_response])
                
                
    cdf = mtdf[mtdf.cell_specimen_id==cell_specimen_id]
    cdf = cdf[cdf.go]
    for i, change_image_name in enumerate(cdf.change_image_name.unique()): 
        if 'images_B' in session_type: 
            i = i+8
        condition = 'change_im'+str(i)+'_post'
        mean_response = cdf[cdf.change_image_name==change_image_name].mean_response.values[0]
        df_list.append([cell_specimen_id, condition, mean_response])
        
        condition = 'change_im'+str(i)+'_pre'
        mean_response = cdf[cdf.change_image_name==change_image_name].mean_baseline.values[0]
        df_list.append([cell_specimen_id, condition, mean_response])
        
        
    # pooled images        
    cdf = msdf_p[msdf_p.cell_specimen_id==cell_specimen_id]
    cdf = cdf[cdf.omitted]

    condition = 'im_pooled_post'
    mean_response = cdf.mean_response.values[0]
    df_list.append([cell_specimen_id, condition, mean_response])

    condition = 'im_pooled_pre'
    mean_response = cdf.mean_baseline.values[0]
    df_list.append([cell_specimen_id, condition, mean_response])
    
    # pooled image changes
    cdf = mtdf_p[mtdf_p.cell_specimen_id==cell_specimen_id]
    cdf = cdf[cdf.go]
    
    condition = 'change_im_pooled_post'
    mean_response = cdf.mean_response.values[0]
    df_list.append([cell_specimen_id, condition, mean_response])

    condition = 'change_im_pooled_pre'
    mean_response = cdf.mean_baseline.values[0]
    df_list.append([cell_specimen_id, condition, mean_response])

# %%
metrics_df = pd.DataFrame(data=df_list, columns=['cell_specimen_id','condition','mean_response'])

# %%
metrics_df = metrics_df.set_index(['cell_specimen_id', 'condition'])

# %%
metrics_df
# Out:
#                                         mean_response
# cell_specimen_id condition
# 1028768480       im0_post                    0.000419
#                  im0_pre                    -0.002450
#                  im1_post                   -0.000753
#                  im1_pre                    -0.000518
#                  im2_post                    0.001859
# ...                                               ...
# 1028772542       change_im7_pre              0.017372
#                  im_pooled_post             -0.004091
#                  im_pooled_pre              -0.006202
#                  change_im_pooled_post       0.024975
#                  change_im_pooled_pre        0.010802
#
# [2120 rows x 1 columns]

# %%
unstacked_metrics = metrics_df.unstack(level=-1)

# %%
unstacked_metrics.head()
# Out:
#                    mean_response                                 \
# condition        change_im0_post change_im0_pre change_im1_post
# cell_specimen_id
# 1028768480             -0.002508       0.010885        0.000733
# 1028768607              0.009732       0.017473        0.004840
# 1028768626              0.035414       0.013918        0.026619
# 1028768716              0.032951       0.000379        0.004358
# 1028768871              0.012340       0.007120        0.015825
# 1028768885              0.031640       0.007170        0.016409
# 1028768914              0.013463       0.016557       -0.000390
# 1028769197              0.046698       0.012541        0.014357
# 1028769390              0.052922       0.021034        0.052296
# 1028769548              0.020917       0.019568        0.017556
# 1028769575              0.037321       0.027519        0.003413
# 1028769661              0.010746      -0.001977        0.016074
# 1028769816              0.027281       0.007424        0.025221
# 1028769894              0.018208      -0.000242        0.008271
# 1028769924              0.010534       0.002761        0.015425
# 1028770076              0.013794       0.007161        0.003152
# 1028770385              0.048025       0.011796        0.110906
# 1028770430              0.021523       0.007164        0.006031
# 1028770437              0.026775       0.003890        0.018532
# 1028770446              0.012423       0.013855        0.012252
# 1028770859              0.006537       0.003412       -0.000856
# 1028770880              0.027992       0.016710        0.010723
# 1028770891              0.022851       0.009987        0.018642
# 1028770960              0.048006       0.007008        0.006088
# 1028771868              0.012862       0.001681        0.008964
# 1028771913              0.031953       0.012755        0.012605
# 1028771924              0.042370       0.032771        0.042437
# 1028771954              0.027874       0.021137        0.087983
# 1028771984              0.010352       0.030146        0.043463
# 1028771991              0.051417       0.009542        0.052843
# 1028772009              0.046730       0.007848        0.060632
# 1028772018              0.033807       0.008069        0.009885
# 1028772484           0.001889    0.000656
# 1028772504          -0.009988    0.002117
# 1028772534          -0.005406    0.000273
# 1028772542          -0.004091   -0.006202
#
# [53 rows x 40 columns]

# %%
metrics_array = unstacked_metrics.values
metrics_array.shape
# Out:
# (53, 40)

# %% [markdown]
# ### for a bunch of experiments

# %%
def get_metrics_df(mean_stim_df, mean_trials_df, mean_stim_pooled_df, mean_trials_pooled_df, session_type, experiment_id, session_id): 
    msdf = mean_stim_df.copy()
    mtdf = mean_trials_df.copy()
    msdf_p = mean_stim_pooled_df.copy()
    mtdf_p = mean_trials_pooled_df.copy()
    
    df_list = []
    for cell_specimen_id in msdf.cell_specimen_id.unique():
        cdf = msdf[msdf.cell_specimen_id==cell_specimen_id]
        for omitted in cdf.omitted.unique():
            if omitted: 
                condition = 'omitted_post'
                mean_response = cdf[cdf.omitted==True].mean_response.values[0]
                df_list.append([cell_specimen_id, condition, mean_response])
                
                condition = 'omitted_pre'
                mean_response = cdf[cdf.omitted==True].mean_baseline.values[0]
                df_list.append([cell_specimen_id, condition, mean_response])
            else: 
                for i, image_name in enumerate(cdf.image_name.unique()): 
                    if 'images_B' in session_type: 
                        i = i+8
                    condition = 'im'+str(i)+'_post'
                    mean_response = cdf[cdf.image_name==image_name].mean_response.values[0]
                    df_list.append([cell_specimen_id, condition, mean_response])
                    
                    condition = 'im'+str(i)+'_pre'
                    mean_response = cdf[cdf.image_name==image_name].mean_baseline.values[0]
                    df_list.append([cell_specimen_id, condition, mean_response])
                    
                    
        cdf = mtdf[mtdf.cell_specimen_id==cell_specimen_id]
        cdf = cdf[cdf.go]
        for i, change_image_name in enumerate(cdf.change_image_name.unique()): 
            if 'images_B' in session_type: 
                i = i+8
            condition = 'change_im'+str(i)+'_post'
            mean_response = cdf[cdf.change_image_name==change_image_name].mean_response.values[0]
            df_list.append([cell_specimen_id, condition, mean_response])
            
            condition = 'change_im'+str(i)+'_pre'
            mean_response = cdf[cdf.change_image_name==change_image_name].mean_baseline.values[0]
            df_list.append([cell_specimen_id, condition, mean_response])
            
            
        # pooled images        
        cdf = msdf_p[msdf_p.cell_specimen_id==cell_specimen_id]
        cdf = cdf[cdf.omitted]

        condition = 'im_pooled_post'
        mean_response = cdf.mean_response.values[0]
        df_list.append([cell_specimen_id, condition, mean_response])

        condition = 'im_pooled_pre'
        mean_response = cdf.mean_baseline.values[0]
        df_list.append([cell_specimen_id, condition, mean_response])


        # pooled image changes
        cdf = mtdf_p[mtdf_p.cell_specimen_id==cell_specimen_id]
        cdf = cdf[cdf.go]

        condition = 'change_im_pooled_post'
        mean_response = cdf.mean_response.values[0]
        df_list.append([cell_specimen_id, condition, mean_response])

        condition = 'change_im_pooled_pre'
        mean_response = cdf.mean_baseline.values[0]
        df_list.append([cell_specimen_id, condition, mean_response])


    metrics_df = pd.DataFrame(data=df_list, columns=['cell_specimen_id','condition','mean_response'])
    metrics_df['experiment_id'] = experiment_id
    metrics_df['session_id'] = session_id
    
    return metrics_df

# %%
ophys_experiment_ids = experiments_table[experiments_table.project_code=='VisualBehaviorMultiscope'].index.values
print(ophys_experiment_ids.shape)

multi_session_metrics_df = pd.DataFrame()

count = 0
for ophys_experiment_id in ophys_experiment_ids:
    count = count+1
    print(f'Experiment {count} / {len(ophys_experiment_ids)}')
    session_id = experiments_table[experiments_table.index.values==ophys_experiment_id].iloc[0]['ophys_session_id']
    
    dataset = loading.get_ophys_dataset(ophys_experiment_id)

    analysis = ResponseAnalysis(dataset)

    sdf = analysis.get_response_df(df_name='stimulus_response_df')
    tdf = analysis.get_response_df(df_name='trials_response_df')

    mean_stim_df = ut.get_mean_df(sdf, conditions=['cell_specimen_id', 'omitted', 'image_name'], flashes=True)
    mean_trials_df = ut.get_mean_df(tdf, conditions=['cell_specimen_id', 'go', 'change_image_name'])
    # pooled images and image changes
    mean_stim_pooled_df = ut.get_mean_df(sdf, conditions=['cell_specimen_id', 'omitted'], flashes=True)
    mean_trials_pooled_df = ut.get_mean_df(tdf, conditions=['cell_specimen_id', 'go'])

    session_type = dataset.metadata['session_type']
    experiment_id = dataset.ophys_experiment_id
    
    metrics_df = get_metrics_df(mean_stim_df, mean_trials_df, mean_stim_pooled_df, mean_trials_pooled_df, session_type, experiment_id, session_id)
    
    multi_session_metrics_df = pd.concat([multi_session_metrics_df, metrics_df])
# Out:
# (750,)
# Experiment 1 / 750
# C:\Users\marinag\Documents\Code\AllenSDK\allensdk\brain_observatory\sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# C:\Users\marinag\Documents\Code\AllenSDK\allensdk\brain_observatory\sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# WARNING:root:acquiring (valid line label(s) = ['2p_acquiring']
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# C:\Users\marinag\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# C:\Users\marinag\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# Experiment 2 / 750
# C:\Users\marinag\Documents\Code\AllenSDK\allensdk\brain_observatory\sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# C:\Users\marinag\Documents\Code\AllenSDK\allensdk\brain_observatory\sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# WARNING:root:acquiring (valid line label(s) = ['2p_acquiring']
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# C:\Users\marinag\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# C:\Users\marinag\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen driver line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.io.lims_database:cannot query specimen reporter line: can't adapt type 'numpy.int64'
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times

# %%
multi_session_metrics_df.head()
# Out:
#                                                      mean_response
# cell_specimen_id experiment_id session_id condition
# 1028819695       953659745     952430817  im0_post        0.014633
#                                           im0_pre         0.007758
#                                           im1_post        0.003397
#                                           im1_pre         0.003970
#                                           im2_post        0.006659

# %%
## unstack to make metrics columns, then be able to extract the metrics as an array
multi_session_metrics_df = multi_session_metrics_df.set_index(['cell_specimen_id', 'experiment_id', 'session_id', 'condition'])
unstacked_metrics = multi_session_metrics_df.unstack(level=-1)

# %%
unstacked_metrics.head()
# Out:
#                                             mean_response                 \
# condition                                 change_im0_post change_im0_pre
# cell_specimen_id experiment_id session_id
# 1028819695       953659745     952430817         0.006167       0.001132
# 1028819736       953659745     952430817         0.228675       0.833580
# 1028819780       953659745     952430817         0.569764       0.119790
# 1028819805       953659745     952430817         0.351769       0.432902
# 1028819826       953659745     952430817         0.009849      -0.006004
#
#                                                                           \
# condition                                 change_im1_post change_im1_pre
# cell_specimen_id experiment_id session_id
# 1028819695       953659745     952430817         0.008001       0.005618
# 1028819736       953659745     952430817         0.498823       0.236903
# 1028819780       953659745     952430817         0.464546       0.375370
# 1028819805       953659745     952430817         0.244559       0.326967
# 1028819826       953659745     952430817         0.011923       0.001426
#
#                                                                           \
# condition                                 change_im2_post change_im2_pre
# cell_specimen_id experiment_id session_id
# 1028819695       953659745     952430817         0.018985       0.000079
# 1028819736       953659745     952430817         0.669045       0.166200
# 1028819780       953659745     952430817         0.577959       0.232178
# 1028819805       953659745     952430817         0.560339       0.594638
# 1028819826       953659745     952430817         0.039588       0.014574
#
#                                                                           \
# condition                                 change_im3_post change_im3_pre
# cell_specimen_id experiment_id session_id
# 1028819695       953659745     952430817         0.006144      -0.008348
# 1028819736       953659745     952430817         0.903899       0.392250
# 1028819780       953659745     952430817         1.967256       0.458320
# 1028819805       953659745     952430817         0.507747       0.480689
# 1028819826       953659745     952430817         0.086531      -0.055747
#
#                                                                           ...  \
# condition                                 change_im4_post change_im4_pre  ...
# cell_specimen_id experiment_id session_id                                 ...
# 1028819695       953659745     952430817         0.007209      -0.001575  ...
# 1028819736       953659745     952430817         0.328961       0.673835  ...
# 1028819780       953659745     952430817         0.449400       0.611084  ...
# 1028819805       953659745     952430817         0.311482       0.418718  ...
# 1028819826       953659745     952430817         0.036070       0.009923  ...
#
#                                                                          \
# condition                                  im6_post   im6_pre  im7_post
# cell_specimen_id experiment_id session_id
# 1028819695       953659745     952430817   0.007404  0.002779  0.004941
# 1028819736       953659745     952430817   0.224942  0.151245  2.885198
# 1028819780       953659745     952430817   0.540034  0.470717  0.397525
# 1028819805       953659745     952430817   0.334945  0.341358  1.771561
# 1028819826       953659745     952430817   0.075619  0.032600  0.056486
#
#                                                                          \
# condition                                   im7_pre  im8_post   im8_pre
# cell_specimen_id experiment_id session_id
# 1028819695       953659745     952430817   0.004869  0.001434  0.005035
# 1028819736       953659745     952430817   2.210023  0.114837  0.891974
# 1028819780       953659745     952430817   0.433123  0.160932  1.261406
# 1028819805       953659745     952430817   1.756350  0.394068  0.346340
# 1028819826       953659745     952430817   0.033975 -0.047750  0.051382
#
#                                                                         \
# condition                                 im_pooled_post im_pooled_pre
# cell_specimen_id experiment_id session_id
# 1028819695       953659745     952430817        0.001434      0.005035
# 1028819736       953659745     952430817        0.114837      0.891974
# 1028819780       953659745     952430817        0.160932      1.261406
# 1028819805       953659745     952430817        0.394068      0.346340
# 1028819826       953659745     952430817       -0.047750      0.051382
#
#
# condition                                 omitted_post omitted_pre
# cell_specimen_id experiment_id session_id
# 1028819695       953659745     952430817      0.001434    0.005035
# 1028819736       953659745     952430817      0.114837    0.891974
# 1028819780       953659745     952430817      0.160932    1.261406
# 1028819805       953659745     952430817      0.394068    0.346340
# 1028819826       953659745     952430817     -0.047750    0.051382
#
# [5 rows x 40 columns]

# %%
# get rid of unecessary 'mean_response' column multi-index and set rows multi-index to columns with reset_index
unstacked_metrics = unstacked_metrics.droplevel(axis=1, level=0).reset_index()
unstacked_metrics.head()
# Out:
# condition  cell_specimen_id  experiment_id  session_id  change_im0_post  \
# 0                1028819695      953659745   952430817         0.006167
# 1                1028819736      953659745   952430817         0.228675
# 2                1028819780      953659745   952430817         0.569764
# 3                1028819805      953659745   952430817         0.351769
# 4                1028819826      953659745   952430817         0.009849
#
# condition  change_im0_pre  change_im1_post  change_im1_pre  change_im2_post  \
# 0                0.001132         0.008001        0.005618         0.018985
# 1                0.833580         0.498823        0.236903         0.669045
# 2                0.119790         0.464546        0.375370         0.577959
# 3                0.432902         0.244559        0.326967         0.560339
# 4               -0.006004         0.011923        0.001426         0.039588
#
# condition  change_im2_pre  change_im3_post  ...  im6_post   im6_pre  im7_post  \
# 0                0.000079         0.006144  ...  0.007404  0.002779  0.004941
# 1                0.166200         0.903899  ...  0.224942  0.151245  2.885198
# 2                0.232178         1.967256  ...  0.540034  0.470717  0.397525
# 3                0.594638         0.507747  ...  0.334945  0.341358  1.771561
# 4                0.014574         0.086531  ...  0.075619  0.032600  0.056486
#
# condition   im7_pre  im8_post   im8_pre  im_pooled_post  im_pooled_pre  \
# 0          0.004869  0.001434  0.005035        0.001434       0.005035
# 1          2.210023  0.114837  0.891974        0.114837       0.891974
# 2          0.433123  0.160932  1.261406        0.160932       1.261406
# 3          1.756350  0.394068  0.346340        0.394068       0.346340
# 4          0.033975 -0.047750  0.051382       -0.047750       0.051382
#
# condition  omitted_post  omitted_pre
# 0              0.001434     0.005035
# 1              0.114837     0.891974
# 2              0.160932     1.261406
# 3              0.394068     0.346340
# 4             -0.047750     0.051382
#
# [5 rows x 43 columns]

# %%
# merge unstacked_metrics with metadata from experiments_table
expts = experiments_table.reset_index().rename(columns={'ophys_experiment_id':'experiment_id'})
unstacked_metrics = unstacked_metrics.merge(expts, on='experiment_id')
unstacked_metrics.head()
# Out:
#    experiment_id  ophys_session_id  behavior_session_id  container_id  \
# 0      953659745         952430817            952554548    1018028339
# 1      953659749         952430817            952554548    1018028354
# 2      953659752         952430817            952554548    1018028357
# 3      953659743         952430817            952554548    1018028345
# 4      958527474         954954402            953982960    1018028339
#
#                project_code container_workflow_state  \
# 0  VisualBehaviorMultiscope                completed
# 1  VisualBehaviorMultiscope                completed
# 2  VisualBehaviorMultiscope                completed
# 3  VisualBehaviorMultiscope                completed
# 4  VisualBehaviorMultiscope                completed
#
#   experiment_workflow_state              session_name  \
# 0                    passed  20190923_457841_2imagesA
# 1                    passed  20190923_457841_2imagesA
# 2                    passed  20190923_457841_2imagesA
# 3                    passed  20190923_457841_2imagesA
# 4                    passed  20190924_457841_3imagesA
#
#                session_type equipment_name  ... imaging_depth  \
# 0  OPHYS_2_images_A_passive         MESO.1  ...            75
# 1  OPHYS_2_images_A_passive         MESO.1  ...           150
# 2  OPHYS_2_images_A_passive         MESO.1  ...           225
# 3  OPHYS_2_images_A_passive         MESO.1  ...           225
# 4          OPHYS_3_images_A         MESO.1  ...            75
#
#    targeted_structure  published_at super_container_id      cre_line  \
# 0                VISp           NaN          850862430  Sst-IRES-Cre
# 1                VISl           NaN          850862430  Sst-IRES-Cre
# 2                VISl           NaN          850862430  Sst-IRES-Cre
# 3                VISp           NaN          850862430  Sst-IRES-Cre
# 4                VISp           NaN          850862430  Sst-IRES-Cre
#
#   session_tags                                       failure_tags  \
# 0          NaN  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...
# 1          NaN  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...
# 2          NaN  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...
# 3          NaN  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...
# 4          NaN                                                NaN
#
#   exposure_number  model_outputs_available      location
# 0               0                    False   Sst_VISp_75
# 1               0                    False  Sst_VISl_150
# 2               0                    False  Sst_VISl_225
# 3               0                    False  Sst_VISp_225
# 4               0                     True   Sst_VISp_75
#
# [5 rows x 28 columns]

# %% [markdown]
# ### save data

# %%
# there is an easy function to get the default path for the 'visual_behavior_production_analysis' folder:
# loading.get_analysis_cache_dir()

multi_session_metrics_df.to_hdf(os.path.join(loading.get_analysis_cache_dir(), 'multi_session_summary_dfs', 'response_metrics_feature_matrix.h5'), key='df')

unstacked_metrics.to_hdf(os.path.join(loading.get_analysis_cache_dir(), 'multi_session_summary_dfs', 'response_metrics_feature_matrix_unstacked.h5'), key='df')

# %% [markdown]
# ### load previously saved data

# %%
# there is an easy function to get the default path for the 'visual_behavior_production_analysis' folder:
# loading.get_analysis_cache_dir()

multi_session_metrics_df = pd.read_hdf(os.path.join(loading.get_analysis_cache_dir(), 'multi_session_summary_dfs', 'response_metrics_feature_matrix.h5'), key='df')

unstacked_metrics = pd.read_hdf(os.path.join(loading.get_analysis_cache_dir(), 'multi_session_summary_dfs', 'response_metrics_feature_matrix_unstacked.h5'), key='df')

# %% [markdown]
# ### get the metrics array without all the metadata columns

# %% [markdown]
# #### i assume this array is what goes into PCA or UMAP

# %%
metrics_array = unstacked_metrics.drop(columns=experiments_table.columns)
metrics_array = metrics_array.set_index(['cell_specimen_id','experiment_id','session_id'])
metrics_array.values
# Out:
# array([[ 6.16709448e-03,  1.13154361e-03,  8.00131384e-03, ...,
#          5.03536511e-03,  1.43386968e-03,  5.03536511e-03],
#        [ 2.28674572e-01,  8.33579827e-01,  4.98823001e-01, ...,
#          8.91974029e-01,  1.14836748e-01,  8.91974029e-01],
#        [ 5.69763638e-01,  1.19789811e-01,  4.64545638e-01, ...,
#          1.26140628e+00,  1.60931699e-01,  1.26140628e+00],
#        ...,
#        [ 4.94495307e-01,  4.67167686e-01,  3.86146100e-01, ...,
#          4.39699717e-01,  9.21897017e-01,  4.39699717e-01],
#        [ 3.00837653e-02, -2.53623092e-02,  4.57420901e-03, ...,
#          1.70503135e-02, -1.95694893e-02,  1.70503135e-02],
#        [ 4.06492561e-02,  5.61440202e-02,  2.63837622e-02, ...,
#          3.79070388e-02,  3.28955590e-02,  3.79070388e-02]])

# %% [markdown]
# ### to get just the metadata columns (corresponding to the rows in metrics_array)

# %% [markdown]
# #### can then use this metadata to label points in umap or split by cre line, etc

# %%
expts = experiments_table.reset_index().rename(columns={'ophys_experiment_id':'experiment_id'})

# %%
metadata_df = metrics_array.reset_index()[['cell_specimen_id','experiment_id','session_id']]
metadata_df = metadata_df.merge(expts, on='experiment_id')

# %%
metadata_df
# Out:
#     cell_specimen_id  experiment_id  session_id  ophys_session_id  \
# 0         1028819695      953659745   952430817         952430817
# 1         1028819736      953659745   952430817         952430817
# 2         1028819780      953659745   952430817         952430817
# 3         1028819805      953659745   952430817         952430817
# 4         1028819826      953659745   952430817         952430817
# 5         1028819862      953659745   952430817         952430817
# 6         1028819872      953659745   952430817         952430817
# 7         1028819888      953659745   952430817         952430817
# 8         1028819953      953659745   952430817         952430817
# 9         1028820374      953659745   952430817         952430817
# 10        1028820384      953659745   952430817         952430817
# 11        1028822882      953659749   952430817         952430817
# 12        1028822956      953659749   952430817         952430817
# 13        1028823035      953659749   952430817         952430817
# 14        1028823078      953659749   952430817         952430817
# 15        1028823216      953659749   952430817         952430817
# 16        1028823222      953659749   952430817         952430817
# 17        1028823231      953659749   952430817         952430817
# 18        1028823237      953659749   952430817         952430817
# 19        1028823246      953659749   952430817         952430817
# 20        1028823252      953659749   952430817         952430817
# 21        1028823258      953659749   952430817         952430817
# 22        1028823267      953659749   952430817         952430817
# 23        1028823284      953659749   952430817         952430817
# 24        1028823293      953659749   952430817         952430817
# 25        1028823299      953659749   952430817         952430817
# 26        1028823305      953659749   952430817         952430817
# 27        1028823318      953659749   952430817         952430817
# 28        1028823324      953659749   952430817         952430817
# 29        1028823340      953659749   952430817         952430817
# 30        1028823366      953659749   952430817         952430817
# 31        1028823389      953659749   952430817         952430817
# 32        1028823405      953659749   952430817         952430817
# 33        1028823414      953659749   952430817         952430817
#
#     behavior_session_id  container_id              project_code  \
# 0             952554548    1018028339  VisualBehaviorMultiscope
# 1             952554548    1018028339  VisualBehaviorMultiscope
# 2             952554548    1018028339  VisualBehaviorMultiscope
# 3             952554548    1018028339  VisualBehaviorMultiscope
# 4             952554548    1018028339  VisualBehaviorMultiscope
# 5             952554548    1018028339  VisualBehaviorMultiscope
# 6             952554548    1018028339  VisualBehaviorMultiscope
# 7             952554548    1018028339  VisualBehaviorMultiscope
# 8             952554548    1018028339  VisualBehaviorMultiscope
# 9             952554548    1018028339  VisualBehaviorMultiscope
# 10            952554548    1018028339  VisualBehaviorMultiscope
# 11            952554548    1018028354  VisualBehaviorMultiscope
# 12            952554548    1018028354  VisualBehaviorMultiscope
# 13            952554548    1018028354  VisualBehaviorMultiscope
# 14            952554548    1018028354  VisualBehaviorMultiscope
# 15            952554548    1018028354  VisualBehaviorMultiscope
# 16            952554548    1018028354  VisualBehaviorMultiscope
# 17            952554548    1018028354  VisualBehaviorMultiscope
# 18            952554548    1018028354  VisualBehaviorMultiscope
# 19            952554548    1018028354  VisualBehaviorMultiscope
# 20            952554548    1018028354  VisualBehaviorMultiscope
# 21            952554548    1018028354  VisualBehaviorMultiscope
# 22            952554548    1018028354  VisualBehaviorMultiscope
# 23            952554548    1018028354  VisualBehaviorMultiscope
# 24            952554548    1018028354  VisualBehaviorMultiscope
# 25            952554548    1018028354  VisualBehaviorMultiscope
# 26            952554548    1018028354  VisualBehaviorMultiscope
# 27            952554548    1018028354  VisualBehaviorMultiscope
# 28            952554548    1018028354  VisualBehaviorMultiscope
# 29            952554548    1018028354  VisualBehaviorMultiscope
# 30            952554548    1018028354  VisualBehaviorMultiscope
# 31            952554548    1018028354  VisualBehaviorMultiscope
# 32            952554548    1018028354  VisualBehaviorMultiscope
# 33            952554548    1018028354  VisualBehaviorMultiscope
#
#    container_workflow_state experiment_workflow_state  \
# 0                 completed                    passed
# 1                 completed                    passed
# 2                 completed                    passed
# 3                 completed                    passed
# 4                 completed                    passed
# 5                 completed                    passed
# 6                 completed                    passed
# 7                 completed                    passed
# 8                 completed                    passed
# 9                 completed                    passed
# 10                completed                    passed
# 11                completed                    passed
# 12                completed                    passed
# 13                completed                    passed
# 14                completed                    passed
# 15                completed                    passed
# 16                completed                    passed
# 17                completed                    passed
# 18                completed                    passed
# 19                completed                    passed
# 20                completed                    passed
# 21                completed                    passed
# 22                completed                    passed
# 23                completed                    passed
# 24                completed                    passed
# 25                completed                    passed
# 26                completed                    passed
# 27                completed                    passed
# 28                completed                    passed
# 29                completed                    passed
# 30                completed                    passed
# 31                completed                    passed
# 32                completed                    passed
# 33                completed                    passed
#
#                 session_name  ... imaging_depth targeted_structure  \
# 0   20190923_457841_2imagesA  ...            75               VISp
# 1   20190923_457841_2imagesA  ...            75               VISp
# 2   20190923_457841_2imagesA  ...            75               VISp
# 3   20190923_457841_2imagesA  ...            75               VISp
# 4   20190923_457841_2imagesA  ...            75               VISp
# 5   20190923_457841_2imagesA  ...            75               VISp
# 6   20190923_457841_2imagesA  ...            75               VISp
# 7   20190923_457841_2imagesA  ...            75               VISp
# 8   20190923_457841_2imagesA  ...            75               VISp
# 9   20190923_457841_2imagesA  ...            75               VISp
# 10  20190923_457841_2imagesA  ...            75               VISp
# 11  20190923_457841_2imagesA  ...           150               VISl
# 12  20190923_457841_2imagesA  ...           150               VISl
# 13  20190923_457841_2imagesA  ...           150               VISl
# 14  20190923_457841_2imagesA  ...           150               VISl
# 15  20190923_457841_2imagesA  ...           150               VISl
# 16  20190923_457841_2imagesA  ...           150               VISl
# 17  20190923_457841_2imagesA  ...           150               VISl
# 18  20190923_457841_2imagesA  ...           150               VISl
# 19  20190923_457841_2imagesA  ...           150               VISl
# 20  20190923_457841_2imagesA  ...           150               VISl
# 21  20190923_457841_2imagesA  ...           150               VISl
# 22  20190923_457841_2imagesA  ...           150               VISl
# 23  20190923_457841_2imagesA  ...           150               VISl
# 24  20190923_457841_2imagesA  ...           150               VISl
# 25  20190923_457841_2imagesA  ...           150               VISl
# 26  20190923_457841_2imagesA  ...           150               VISl
# 27  20190923_457841_2imagesA  ...           150               VISl
# 28  20190923_457841_2imagesA  ...           150               VISl
# 29  20190923_457841_2imagesA  ...           150               VISl
# 30  20190923_457841_2imagesA  ...           150               VISl
# 31  20190923_457841_2imagesA  ...           150               VISl
# 32  20190923_457841_2imagesA  ...           150               VISl
# 33  20190923_457841_2imagesA  ...           150               VISl
#
#    published_at  super_container_id      cre_line session_tags  \
# 0           NaN           850862430  Sst-IRES-Cre          NaN
# 1           NaN           850862430  Sst-IRES-Cre          NaN
# 2           NaN           850862430  Sst-IRES-Cre          NaN
# 3           NaN           850862430  Sst-IRES-Cre          NaN
# 4           NaN           850862430  Sst-IRES-Cre          NaN
# 5           NaN           850862430  Sst-IRES-Cre          NaN
# 6           NaN           850862430  Sst-IRES-Cre          NaN
# 7           NaN           850862430  Sst-IRES-Cre          NaN
# 8           NaN           850862430  Sst-IRES-Cre          NaN
# 9           NaN           850862430  Sst-IRES-Cre          NaN
# 10          NaN           850862430  Sst-IRES-Cre          NaN
# 11          NaN           850862430  Sst-IRES-Cre          NaN
# 12          NaN           850862430  Sst-IRES-Cre          NaN
# 13          NaN           850862430  Sst-IRES-Cre          NaN
# 14          NaN           850862430  Sst-IRES-Cre          NaN
# 15          NaN           850862430  Sst-IRES-Cre          NaN
# 16          NaN           850862430  Sst-IRES-Cre          NaN
# 17          NaN           850862430  Sst-IRES-Cre          NaN
# 18          NaN           850862430  Sst-IRES-Cre          NaN
# 19          NaN           850862430  Sst-IRES-Cre          NaN
# 20          NaN           850862430  Sst-IRES-Cre          NaN
# 21          NaN           850862430  Sst-IRES-Cre          NaN
# 22          NaN           850862430  Sst-IRES-Cre          NaN
# 23          NaN           850862430  Sst-IRES-Cre          NaN
# 24          NaN           850862430  Sst-IRES-Cre          NaN
# 25          NaN           850862430  Sst-IRES-Cre          NaN
# 26          NaN           850862430  Sst-IRES-Cre          NaN
# 27          NaN           850862430  Sst-IRES-Cre          NaN
# 28          NaN           850862430  Sst-IRES-Cre          NaN
# 29          NaN           850862430  Sst-IRES-Cre          NaN
# 30          NaN           850862430  Sst-IRES-Cre          NaN
# 31          NaN           850862430  Sst-IRES-Cre          NaN
# 32          NaN           850862430  Sst-IRES-Cre          NaN
# 33          NaN           850862430  Sst-IRES-Cre          NaN
#
#                                          failure_tags exposure_number  \
# 0   z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 1   z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 2   z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 3   z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 4   z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 5   z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 6   z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 7   z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 8   z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 9   z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 10  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 11  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 12  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 13  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 14  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 15  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 16  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 17  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 18  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 19  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 20  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 21  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 22  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 23  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 24  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 25  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 26  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 27  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 28  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 29  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 30  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 31  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 32  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
# 33  z_drift_corr_um_diff,z_drift_corr_um_diff,z_dr...               0
#
#    model_outputs_available      location
# 0                    False   Sst_VISp_75
# 1                    False   Sst_VISp_75
# 2                    False   Sst_VISp_75
# 3                    False   Sst_VISp_75
# 4                    False   Sst_VISp_75
# 5                    False   Sst_VISp_75
# 6                    False   Sst_VISp_75
# 7                    False   Sst_VISp_75
# 8                    False   Sst_VISp_75
# 9                    False   Sst_VISp_75
# 10                   False   Sst_VISp_75
# 11                   False  Sst_VISl_150
# 12                   False  Sst_VISl_150
# 13                   False  Sst_VISl_150
# 14                   False  Sst_VISl_150
# 15                   False  Sst_VISl_150
# 16                   False  Sst_VISl_150
# 17                   False  Sst_VISl_150
# 18                   False  Sst_VISl_150
# 19                   False  Sst_VISl_150
# 20                   False  Sst_VISl_150
# 21                   False  Sst_VISl_150
# 22                   False  Sst_VISl_150
# 23                   False  Sst_VISl_150
# 24                   False  Sst_VISl_150
# 25                   False  Sst_VISl_150
# 26                   False  Sst_VISl_150
# 27                   False  Sst_VISl_150
# 28                   False  Sst_VISl_150
# 29                   False  Sst_VISl_150
# 30                   False  Sst_VISl_150
# 31                   False  Sst_VISl_150
# 32                   False  Sst_VISl_150
# 33                   False  Sst_VISl_150
#
# [34 rows x 30 columns]
