# %%
from allensdk.brain_observatory.behavior.behavior_project_cache import VisualBehaviorOphysProjectCache
from visual_behavior.utilities import annotate_stimuli
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
data_storage_directory = "/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/production_cache/" 
cache = VisualBehaviorOphysProjectCache.from_s3_cache(cache_dir=data_storage_directory)
# Out:
# /home/dougo/anaconda3/envs/vba/lib/python3.8/site-packages/allensdk/api/cloud_cache/cloud_cache.py:272: OutdatedManifestWarning: You are loading visual-behavior-ophys_project_manifest_v0.3.0.json. A more up to date version of the dataset -- visual-behavior-ophys_project_manifest_v1.0.1.json -- exists online. To see the changes between the two versions of the dataset, run
# VisualBehaviorOphysProjectCache.compare_manifests('visual-behavior-ophys_project_manifest_v0.3.0.json', 'visual-behavior-ophys_project_manifest_v1.0.1.json')
# To load another version of the dataset, run
# VisualBehaviorOphysProjectCache.load_manifest('visual-behavior-ophys_project_manifest_v1.0.1.json')
#   warnings.warn(msg, OutdatedManifestWarning)

# %%
ophys_experiment_id = 982343736
experiment = cache.get_behavior_ophys_experiment(ophys_experiment_id)
experiment.stimulus_presentations
# Out:
#                            duration  end_frame  image_index image_name  \
# stimulus_presentations_id
# 0                           0.25020    18001.0            0      im000
# 1                           0.25021    18046.0            0      im000
# 2                           0.25021    18091.0            0      im000
# 3                           0.26691    18137.0            0      im000
# 4                           0.25026    18182.0            0      im000
# ...                             ...        ...          ...        ...
# 4793                        0.25000        NaN            8    omitted
# 4794                        0.25021   233765.0            3      im073
# 4795                        0.25020   233810.0            3      im073
# 4796                        0.25020   233855.0            3      im073
# 4797                        0.25016   233900.0            3      im073
#
#                                                                    image_set  \
# ...

# %%
# %%time
annotated_stimuli = annotate_stimuli(experiment)
# Out:
# CPU times: user 5.51 s, sys: 0 ns, total: 5.51 s
# Wall time: 5.51 s

# %%
annotated_stimuli
# Out:
#                            trials_id  duration  end_frame  image_index  \
# stimulus_presentations_id
# 0                                  0   0.25020    18001.0            0
# 1                                  0   0.25021    18046.0            0
# 2                                  1   0.25021    18091.0            0
# 3                                  1   0.26691    18137.0            0
# 4                                  1   0.25026    18182.0            0
# ...                              ...       ...        ...          ...
# 4793                             800   0.25000        NaN            8
# 4794                             800   0.25021   233765.0            3
# 4795                             800   0.25020   233810.0            3
# 4796                             800   0.25020   233855.0            3
# 4797                             800   0.25016   233900.0            3
#
#                           image_name  \
# stimulus_presentations_id
# ...

# %%
annotated_stimuli.loc[4790:4795]
# Out:
#                            trials_id  duration  end_frame  image_index  \
# stimulus_presentations_id
# 4790                             800   0.25020   233585.0            7
# 4791                             800   0.25022   233630.0            7
# 4792                             800   0.25021   233675.0            3
# 4793                             800   0.25000        NaN            8
# 4794                             800   0.25021   233765.0            3
# 4795                             800   0.25020   233810.0            3
#
#                           image_name  \
# stimulus_presentations_id
# 4790                           im035
# 4791                           im035
# 4792                           im073
# 4793                         omitted
# 4794                           im073
# 4795                           im073
#
#                                                                    image_set  \
# stimulus_presentations_id
# ...

# %%
annotated_stimuli.loc[4790:4795][['image_name','start_time','next_start_time','previous_image_name']]
# Out:
#                           image_name  start_time  next_start_time  \
# stimulus_presentations_id
# 4790                           im035  3904.50918       3905.25979
# 4791                           im035  3905.25979       3906.01040
# 4792                           im073  3906.01040       3906.74432
# 4793                         omitted  3906.74432       3907.51163
# 4794                           im073  3907.51163       3908.26225
# 4795                           im073  3908.26225       3909.01283
#
#                           previous_image_name
# stimulus_presentations_id
# 4790                                    im035
# 4791                                    im035
# 4792                                    im035
# 4793                                    im073
# 4794                                  omitted
# 4795                                    im073
