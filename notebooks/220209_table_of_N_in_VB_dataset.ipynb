# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_context('notebook', font_scale=1.5, rc={'lines.markeredgewidth': 2})

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import visual_behavior.data_access.utilities as utilities
from visual_behavior.data_access import loading as loading

# %%
from allensdk.brain_observatory.behavior.behavior_project_cache import VisualBehaviorOphysProjectCache

# %% [markdown]
# ### get numbers table from AWS cache

# %%
cache_dir = loading.get_platform_analysis_cache_dir()
cache = VisualBehaviorOphysProjectCache.from_s3_cache(cache_dir=cache_dir)
experiment_table = cache.get_ophys_experiment_table()
len(experiment_table)
# Out:
# 1941

# %%
cells_table = loading.get_cell_table(platform_paper_only=False)
len(cells_table.ophys_experiment_id.unique())
# Out:
# 1941

# %%
len(cells_table)
# Out:
# 133135

# %%
cells_table = utilities.add_cell_type_column(cells_table)

# %% [markdown]
# ### N by cell type and experience level

# %%
conditions_to_group=['cell_type', 'experience_level']

utilities.count_mice_expts_containers_cells(cells_table, conditions_to_group)
# Out:
#                                  n_mouse_id  n_ophys_session_id  \
# cell_type      experience_level
# Excitatory     Familiar                  55                 181
#                Novel 1                   44                  44
#                Novel >1                  55                 136
# Sst Inhibitory Familiar                  24                  80
#                Novel 1                   19                  19
#                Novel >1                  24                  59
# Vip Inhibitory Familiar                  28                  94
#                Novel 1                   21                  21
#                Novel >1                  28                  70
#
#                                  n_ophys_experiment_id  n_ophys_container_id  \
# cell_type      experience_level
# Excitatory     Familiar                            445                   141
#                Novel 1                             102                   102
#                Novel >1                            324                   141
# Sst Inhibitory Familiar                            209                    72
#                Novel 1                              58                    58
#                Novel >1                            135                    69
# Vip Inhibitory Familiar                            341                   113
#                Novel 1                              75                    75
#                Novel >1                            252                   109
#
#                                  n_cell_specimen_id
# cell_type      experience_level
# Excitatory     Familiar                       33299
#                Novel 1                        13904
#                Novel >1                       28555
# Sst Inhibitory Familiar                        1051
#                Novel 1                          583
#                Novel >1                         856
# Vip Inhibitory Familiar                        2610
#                Novel 1                         1153
#                Novel >1                        2256

# %% [markdown]
# ### N by genotype & experience level

# %%
conditions_to_group=['full_genotype', 'experience_level']

utilities.count_mice_expts_containers_cells(cells_table, conditions_to_group)
# Out:
#                                                                      n_mouse_id  \
# full_genotype                                      experience_level
# Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC... Familiar                  47
#                                                    Novel 1                   40
#                                                    Novel >1                  47
# Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC... Familiar                   8
#                                                    Novel 1                    4
#                                                    Novel >1                   8
# Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt      Familiar                  24
#                                                    Novel 1                   19
#                                                    Novel >1                  24
# Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt      Familiar                  28
#                                                    Novel 1                   21
#                                                    Novel >1                  28
#
#                                                                      n_ophys_session_id  \
# full_genotype                                      experience_level
# Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC... Familiar                         152
#                                                    Novel 1                           40
#                                                    Novel >1                         113
# Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC... Familiar                          29
#                                                    Novel 1                            4
#                                                    Novel >1                          23
# Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt      Familiar                          80
#                                                    Novel 1                           19
#                                                    Novel >1                          59
# Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt      Familiar                          94
#                                                    Novel 1                           21
#                                                    Novel >1                          70
#
#                                                                      n_ophys_experiment_id  \
# full_genotype                                      experience_level
# Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC... Familiar                            416
#                                                    Novel 1                              98
#                                                    Novel >1                            301
# Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC... Familiar                             29
#                                                    Novel 1                               4
#                                                    Novel >1                             23
# Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt      Familiar                            209
#                                                    Novel 1                              58
#                                                    Novel >1                            135
# Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt      Familiar                            341
#                                                    Novel 1                              75
#                                                    Novel >1                            252
#
#                                                                      n_ophys_container_id  \
# full_genotype                                      experience_level
# Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC... Familiar                           133
#                                                    Novel 1                             98
#                                                    Novel >1                           133
# Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC... Familiar                             8
#                                                    Novel 1                              4
#                                                    Novel >1                             8
# Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt      Familiar                            72
#                                                    Novel 1                             58
#                                                    Novel >1                            69
# Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt      Familiar                           113
#                                                    Novel 1                             75
#                                                    Novel >1                           109
#
#                                                                      n_cell_specimen_id
# full_genotype                                      experience_level
# Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC... Familiar                       25914
#                                                    Novel 1                        11771
#                                                    Novel >1                       22419
# Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC... Familiar                        7385
#                                                    Novel 1                         2133
#                                                    Novel >1                        6136
# Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt      Familiar                        1051
#                                                    Novel 1                          583
#                                                    Novel >1                         856
# Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt      Familiar                        2610
#                                                    Novel 1                         1153
#                                                    Novel >1                        2256

# %% [markdown]
# ### N by project code & full genotype

# %%
conditions_to_group=['project_code', 'full_genotype']

utilities.count_mice_expts_containers_cells(cells_table, conditions_to_group)
# Out:
#                                                                                       n_mouse_id  \
# project_code                      full_genotype
# VisualBehavior                    Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...          17
#                                   Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC...           7
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                6
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                7
# VisualBehaviorMultiscope          Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...           9
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                6
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                9
# VisualBehaviorMultiscope4areasx2d Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...           6
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                5
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                6
# VisualBehaviorTask1B              Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...          15
#                                   Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC...           1
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                7
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                6
#
#                                                                                       n_ophys_session_id  \
# project_code                      full_genotype
# VisualBehavior                    Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                 103
#                                   Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC...                  50
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                       40
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                       46
# VisualBehaviorMultiscope          Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                  63
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                       41
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                       59
# VisualBehaviorMultiscope4areasx2d Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                  38
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                       27
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                       38
# VisualBehaviorTask1B              Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                 101
#                                   Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC...                   6
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                       50
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                       42
#
#                                                                                       n_ophys_experiment_id  \
# project_code                      full_genotype
# VisualBehavior                    Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                    103
#                                   Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC...                     50
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                          40
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                          46
# VisualBehaviorMultiscope          Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                    343
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                         198
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                         326
# VisualBehaviorMultiscope4areasx2d Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                    268
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                         114
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                         254
# VisualBehaviorTask1B              Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                    101
#                                   Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC...                      6
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                          50
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                          42
#
#                                                                                       n_ophys_container_id  \
# project_code                      full_genotype
# VisualBehavior                    Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                    17
#                                   Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC...                     7
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                          6
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                          7
# VisualBehaviorMultiscope          Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                    56
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                         33
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                         56
# VisualBehaviorMultiscope4areasx2d Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                    45
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                         26
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                         44
# VisualBehaviorTask1B              Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                    15
#                                   Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC...                     1
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                          7
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                          6
#
#                                                                                       n_cell_specimen_id
# project_code                      full_genotype
# VisualBehavior                    Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                5921
#                                   Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC...                9742
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                      139
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                      379
# VisualBehaviorMultiscope          Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...               14673
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                      682
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                     1827
# VisualBehaviorMultiscope4areasx2d Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                9910
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                      369
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                      975
# VisualBehaviorTask1B              Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GC...                4881
#                                   Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-GC...                 653
#                                   Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                      142
#                                   Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt                      189

# %% [markdown]
# ### N cells by project code and abbreviated genotype

# %%
cells_table['genotype'] = [full_genotype.split(';')[0].split('/')[0].split('-')[0]+';'+full_genotype.split(';')[-1].split('/')[0].split('(')[0] for full_genotype in cells_table.full_genotype.values]

# %%
conditions_to_group=['project_code', 'genotype']

utilities.count_mice_expts_containers_cells(cells_table, conditions_to_group)
# Out:
#                                                 n_mouse_id  \
# project_code                      genotype
# VisualBehavior                    Slc17a7;Ai93          17
#                                   Slc17a7;Ai94           7
#                                   Sst;Ai148              6
#                                   Vip;Ai148              7
# VisualBehaviorMultiscope          Slc17a7;Ai93           9
#                                   Sst;Ai148              6
#                                   Vip;Ai148              9
# VisualBehaviorMultiscope4areasx2d Slc17a7;Ai93           6
#                                   Sst;Ai148              5
#                                   Vip;Ai148              6
# VisualBehaviorTask1B              Slc17a7;Ai93          15
#                                   Slc17a7;Ai94           1
#                                   Sst;Ai148              7
#                                   Vip;Ai148              6
#
#                                                 n_ophys_session_id  \
# project_code                      genotype
# VisualBehavior                    Slc17a7;Ai93                 103
#                                   Slc17a7;Ai94                  50
#                                   Sst;Ai148                     40
#                                   Vip;Ai148                     46
# VisualBehaviorMultiscope          Slc17a7;Ai93                  63
#                                   Sst;Ai148                     41
#                                   Vip;Ai148                     59
# VisualBehaviorMultiscope4areasx2d Slc17a7;Ai93                  38
#                                   Sst;Ai148                     27
#                                   Vip;Ai148                     38
# VisualBehaviorTask1B              Slc17a7;Ai93                 101
#                                   Slc17a7;Ai94                   6
#                                   Sst;Ai148                     50
#                                   Vip;Ai148                     42
#
#                                                 n_ophys_experiment_id  \
# project_code                      genotype
# VisualBehavior                    Slc17a7;Ai93                    103
#                                   Slc17a7;Ai94                     50
#                                   Sst;Ai148                        40
#                                   Vip;Ai148                        46
# VisualBehaviorMultiscope          Slc17a7;Ai93                    343
#                                   Sst;Ai148                       198
#                                   Vip;Ai148                       326
# VisualBehaviorMultiscope4areasx2d Slc17a7;Ai93                    268
#                                   Sst;Ai148                       114
#                                   Vip;Ai148                       254
# VisualBehaviorTask1B              Slc17a7;Ai93                    101
#                                   Slc17a7;Ai94                      6
#                                   Sst;Ai148                        50
#                                   Vip;Ai148                        42
#
#                                                 n_ophys_container_id  \
# project_code                      genotype
# VisualBehavior                    Slc17a7;Ai93                    17
#                                   Slc17a7;Ai94                     7
#                                   Sst;Ai148                        6
#                                   Vip;Ai148                        7
# VisualBehaviorMultiscope          Slc17a7;Ai93                    56
#                                   Sst;Ai148                       33
#                                   Vip;Ai148                       56
# VisualBehaviorMultiscope4areasx2d Slc17a7;Ai93                    45
#                                   Sst;Ai148                       26
#                                   Vip;Ai148                       44
# VisualBehaviorTask1B              Slc17a7;Ai93                    15
#                                   Slc17a7;Ai94                     1
#                                   Sst;Ai148                        7
#                                   Vip;Ai148                        6
#
#                                                 n_cell_specimen_id
# project_code                      genotype
# VisualBehavior                    Slc17a7;Ai93                5921
#                                   Slc17a7;Ai94                9742
#                                   Sst;Ai148                    139
#                                   Vip;Ai148                    379
# VisualBehaviorMultiscope          Slc17a7;Ai93               14673
#                                   Sst;Ai148                    682
#                                   Vip;Ai148                   1827
# VisualBehaviorMultiscope4areasx2d Slc17a7;Ai93                9910
#                                   Sst;Ai148                    369
#                                   Vip;Ai148                    975
# VisualBehaviorTask1B              Slc17a7;Ai93                4881
#                                   Slc17a7;Ai94                 653
#                                   Sst;Ai148                    142
#                                   Vip;Ai148                    189
