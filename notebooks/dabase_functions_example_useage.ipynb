# %% [markdown]
# ## example useage of database functions

# %%
import visual_behavior.database as db

# %% [markdown]
# ## connect to visual behavior database server

# %%
vb = db.Database('visual_behavior_data')

# %% [markdown]
# ## view available tables in the 'behavior_data' database

# %%
vb.behavior_data.list_collection_names()
# Out:
# ['running',
#  'metadata',
#  'summary',
#  'log',
#  'time',
#  'rewards',
#  'licks',
#  'trials',
#  'visual_stimuli',
#  'omitted_stimuli',
#  'error_log']

# %% [markdown]
# ## open the summary table

# %%
summary = pd.DataFrame(vb.behavior_data.summary.find({}))
summary.sample(5)
# Out:
#                            _id                 behavior_session_uuid  \
# 4209  5d5eb68fb0ea7738fb67530f  315b6638-e8d7-4511-8976-1ba53630058f
# 4112  5d5eb4d16cc540d7d7673cf4  56adbd76-a3c9-4ede-9cab-f1a126b96b7d
# 3810  5d5eb030837b442906e9a4ac  5e40df9c-d75d-4ad0-9a9d-18a31b578e0f
# 983   5d5e3953b4acad04cff5d217  dcba34d2-e489-4747-bf68-c0915d1d74c6
# 8420  5d63f60bf3330568e075ac42  ff206a5e-3755-46a3-84ec-4a4d8a5799bb
#
#       blank_duration change_time_distribution  d_prime_peak  day_of_week  \
# 4209             0.5                geometric      1.588525          3.0
# 4112             0.5                geometric      1.809165          4.0
# 3810             0.5                geometric      3.307474          4.0
# 983              0.5                geometric      0.819815          1.0
# 8420             0.5                geometric      1.828231          4.0
#
#          discrim_p  earned_water  error_on_load  false_alarm_rate  \
# 4209  6.092270e-04         0.469            NaN          0.454545
# 4112  1.203408e-06         0.854            NaN          0.333333
# 3810  3.155199e-08         0.959            NaN          0.142857
# 983   4.153060e-01         0.590            NaN          0.151515
# 8420  8.238932e-03         0.896            NaN          0.242424
#
#       false_alarm_rate_peak  fraction_time_aborted  \
# 4209               0.600000               0.801580
# 4112               0.545455               0.586419
# 3810               0.272727               0.454657
# 983                0.333333               0.355389
# 8420               0.545455               0.314920
#
#       fraction_time_auto_rewarded  fraction_time_correct_reject  \
# 4209                     0.010880                      0.012975
# 4112                     0.013157                      0.034041
# 3810                     0.004988                      0.057767
# 983                      0.036029                      0.063570
# 8420                     0.000000                      0.058404
#
#       fraction_time_false_alarm  fraction_time_hit  fraction_time_miss  \
# 4209                   0.011292           0.147785            0.015487
# 4112                   0.018586           0.287444            0.060353
# 3810                   0.009150           0.335731            0.137706
# 983                    0.010620           0.121271            0.413120
# 8420                   0.017467           0.300362            0.308846
#
#       hit_rate  hit_rate_peak  lick_latency_median    lims_id mouse_id  \
# 4209  0.905405       0.909091             0.416941  919895625   467660
# 4112  0.835616       0.887640             0.600501  892387252   442147
# 3810  0.703125       0.836735             0.483755  882883364   427937
# 983   0.231760       0.445783             0.833932  740099601   377588
# 8420  0.504032       0.934426             0.550486  843178908   423749
#
#       num_contingent_trials  number_of_correct_reject_trials  \
# 4209                   85.0                              6.0
# 4112                  167.0                             14.0
# 3810                  220.0                             24.0
# 983                   266.0                             28.0
# 8420                  281.0                             25.0
#
#       number_of_false_alarm_trials  number_of_hit_trials  number_of_licks  \
# 4209                           5.0                  67.0           3762.0
# 4112                           7.0                 122.0           3204.0
# 3810                           4.0                 135.0           2411.0
# 983                            5.0                  54.0           1997.0
# 8420                           8.0                 125.0           2619.0
#
#       number_of_miss_trials  \
# 4209                    7.0
# 4112                   24.0
# 3810                   57.0
# 983                   179.0
# 8420                  123.0
#
#                                                pkl_path  response_bias  \
# 4209  /allen/programs/braintv/production/visualbehav...       0.847059
# 4112  /allen/programs/braintv/production/visualbehav...       0.772455
# 3810  /allen/programs/braintv/production/visualbehav...       0.631818
# 983   /allen/programs/braintv/production/visualbehav...       0.221805
# 8420  /allen/programs/braintv/production/visualbehav...       0.473310
#
#             rig_id  session_duration                              stage  \
# 4209            G2       3597.747142  TRAINING_5_images_A_handoff_ready
# 4112  CAM2P.4-Stim       3594.283192                   OPHYS_4_images_B
# 3810           NP3       3614.932982                   EPHYS_1_images_B
# 983             F4       3605.713728             3_images_a_10uL_reward
# 8420            B3       3620.914272  TRAINING_4_images_A_handoff_ready
#
#                startdatetime stimulus  total_water   user_id
# 4209 2019-08-08 19:46:29.618   images        0.494  nicoleha
# 4112 2019-06-21 16:02:51.854   images        0.879  shiellac
# 3810 2019-06-07 23:10:47.883   images        0.969      samg
# 983  2018-08-21 16:32:11.742   images        0.675  chelsean
# 8420 2019-03-29 15:58:48.508   images        0.896   sophiel

# %% [markdown]
# ## use some convenience functions to get data

# %% [markdown]
# #### get the summary table

# %%
summary = db.get_behavior_session_summary()
summary.sample(5)
# Out:
#                             _id                 behavior_session_uuid  \
# 2718   5d5e4264e9cc3568aaf70c63  ae014721-0985-4051-8006-394ff3f803a5
# 10124  5d641ecb2cc319586f173a28  12bbfaf1-c1c0-4a98-8ea7-b742bbe1234e
# 307    5d5e3641b4acad04cff55348  a2912cff-6732-4961-8147-04a3aee9aee6
# 9945   5d63fd7aef7008c7b576cc2b  eb0cea80-c32c-4158-85a4-67b1dd1aee6d
# 7688   5d63f2a64998a69bfd74cc38  4168ae7d-b125-4cd5-a9b2-ff5b745c39cb
#
#        blank_duration change_time_distribution  d_prime_peak  day_of_week  \
# 2718              0.5              exponential      1.037730          2.0
# 10124             0.5              exponential           NaN          4.0
# 307               0.5              exponential           NaN          4.0
# 9945              0.5                geometric      0.549934          2.0
# 7688              0.5                geometric      1.856268          4.0
#
#        discrim_p  earned_water  error_on_load  false_alarm_rate  \
# 2718    0.916309         0.100            NaN          0.021277
# 10124   1.000000         0.000            NaN               NaN
# 307     1.000000         0.000            NaN               NaN
# 9945    0.986095         0.406            NaN          0.280000
# 7688    0.157040         0.336            NaN          0.090909
#
#        false_alarm_rate_peak  fraction_time_aborted  \
# 2718                0.166667               0.046670
# 10124                    NaN               0.000000
# 307                      NaN               0.000000
# 9945                0.714286               0.481325
# 7688                0.250000               0.318046
#
#        fraction_time_auto_rewarded  fraction_time_correct_reject  \
# 2718                      0.076748                      0.109361
# 10124                     1.000000                      0.000000
# 307                       1.000000                      0.000000
# 9945                      0.024832                      0.044588
# 7688                      0.047185                      0.079288
#
#        fraction_time_false_alarm  fraction_time_hit  fraction_time_miss  \
# 2718                    0.002614           0.022692            0.741915
# 10124                   0.000000           0.000000            0.000000
# 307                     0.000000           0.000000            0.000000
# 9945                    0.015432           0.124311            0.309511
# 7688                    0.006641           0.115846            0.432994
#
#        hit_rate  hit_rate_peak  lick_latency_median    lims_id mouse_id  \
# 2718   0.030675       0.157895             1.250878  799116735   417099
# 10124       NaN            NaN                  NaN  788951929   422856
# 307         NaN            NaN                  NaN  738910080   382375
# 9945   0.301136       0.775000             0.758917  802408383   420734
# 7688   0.213333       0.422535             0.700579  854563861   421530
#
#        num_contingent_trials  number_of_correct_reject_trials  \
# 2718                   373.0                             46.0
# 10124                    0.0                              0.0
# 307                      0.0                              0.0
# 9945                   201.0                             18.0
# 7688                   258.0                             30.0
#
#        number_of_false_alarm_trials  number_of_hit_trials  number_of_licks  \
# 2718                            1.0                  10.0            463.0
# 10124                           0.0                   0.0           1382.0
# 307                             0.0                   0.0           1440.0
# 9945                            7.0                  53.0           2091.0
# 7688                            3.0                  48.0           1633.0
#
#        number_of_miss_trials  \
# 2718                   316.0
# 10124                    0.0
# 307                      0.0
# 9945                   123.0
# 7688                   177.0
#
#                                                 pkl_path  response_bias  \
# 2718   /allen/programs/braintv/production/visualbehav...       0.029491
# 10124  /allen/programs/braintv/production/visualbehav...            NaN
# 307    /allen/programs/braintv/production/visualbehav...            NaN
# 9945   /allen/programs/braintv/production/visualbehav...       0.298507
# 7688   /allen/programs/braintv/production/neuralcodin...       0.197674
#
#       rig_id  session_duration                               stage  \
# 2718      G4       3617.648764                 TRAINING_1_gratings
# 10124     F6        905.184221        0_gratings_autorewards_15min
# 307       D5        906.738499        0_gratings_autorewards_15min
# 9945      G2       3603.341446  TRAINING_4_images_A_handoff_lapsed
# 7688      B6       3619.258455  TRAINING_4_images_A_handoff_lapsed
#
#                 startdatetime stimulus  total_water          user_id
# 2718  2018-12-19 22:16:14.809  grating        0.270  jonathan.gentry
# 10124 2018-11-30 18:47:05.445  grating        0.605         chelsean
# 307   2018-08-17 22:54:53.643  grating        0.545         nicoleha
# 9945  2019-01-02 18:21:19.891   images        0.456  jonathan.gentry
# 7688  2019-04-19 20:00:44.763   images        0.431            andyc

# %% [markdown]
# #### get running data for some session

# %%
uuid = summary.sample()['behavior_session_uuid'].item()
running_data = db.get_behavior_data('running',uuid)
running_data.head()
# Out:
#       speed      v_in     v_sig      time
# 0 -1.843444  4.882884  1.771758  0.000000
# 1 -2.017021  4.882884  1.767889  0.014865
# 2 -1.916648  4.884173  1.762729  0.031539
# 3 -0.821349  4.884173  1.762729  0.048221
# 4  0.000000  4.884173  1.757570  0.064877

# %% [markdown]
# #### get all data for some session

# %%
data = db.get_behavior_data('all',uuid)
data.keys()
# Out:
# dict_keys(['trials', 'time', 'running', 'licks', 'rewards', 'visual_stimuli', 'omitted_stimuli'])

# %%
data['licks'].head()
# Out:
#    frame      time
# 0     72  1.200394
# 1    153  2.551275
# 2    220  3.668722
# 3    336  5.603307
# 4    438  7.304437

# %% [markdown]
# ### get QC results from mouseseeks:

# %%
sample = summary.sample()
uuid = sample['behavior_session_uuid'].item()
lims_id = sample['lims_id'].item()

db.get_mouseseeks_qc_results(uuid)
# Out:
# {'_id': ObjectId('5c9e5b8f09ed448525359598'),
#  'lims_id': 843224163,
#  'lims_behavior_session': {'created_at': datetime.datetime(2019, 3, 29, 17, 30, 52, 479000),
#   'id': 843224163,
#   'storage_directory': '\\\\allen\\programs\\braintv\\production\\visualbehavior\\prod0\\specimen_791837237\\behavior_session_843224163\\',
#   'foraging_id': '6a28628a-44ea-4cb4-8199-34728309911c',
#   'ophys_session_id': None,
#   'external_donor_name': '429084'},
#  'change_detection': {'validate_autoreward_volume': True,
#   'validate_number_of_warmup_trials': True,
#   'validate_reward_delivery_on_warmup_trials': True,
#   'validate_autorewards_after_N_consecutive_misses': True,
#   'validate_change_on_all_go_trials': True,
#   'validate_no_change_on_all_catch_trials': True,
#   'validate_intial_and_final_in_non_aborted': True,
#   'validate_min_change_time': True,
#   'validate_max_change_time': True,
#   'validate_reward_when_lick_in_window': True,
#   'validate_licks_near_every_reward': True,
#   'validate_never_more_than_one_reward': True,
#   'validate_lick_after_scheduled_on_go_catch_trials': True,
#   'validate_initial_matches_final': True,
#   'validate_first_lick_after_change_on_nonaborted': True,
#   'validate_trial_ends_without_licks': True,
#   'validate_session_within_expected_duration': True,
#   'validate_session_ends_at_max_cumulative_volume': True,
#   'validate_duration_and_volume_limit': True,
#   'validate_catch_frequency': True,
#   'validate_stage_present': True,
#   'validate_task_id_present': True,
#   'validate_number_aborted_trial_repeats': True,
#   'validate_params_change_after_aborted_trial_repeats': True,
#   'validate_ignore_false_alarms': True,
#   'validate_trial_times_never_overlap': True,
#   'validate_stimulus_distribution_key': True,
#   'validate_change_time_mean': True,
#   'validate_no_abort_on_lick_before_response_window': True,
#   'validate_licks_on_go_trials_earn_reward': True,
#   'validate_licks_on_catch_trials_do_not_earn_reward': True,
#   'validate_even_sampling': True,
#   'validate_two_stimuli_per_go_trial': True,
#   'validate_one_stimulus_per_catch_trial': True,
#   'validate_one_stimulus_per_aborted_trial': True,
#   'validate_change_frame_at_flash_onset': True,
#   'validate_initial_blank': True,
#   'validate_new_params_on_nonaborted_trials': True,
#   'validate_flash_blank_durations': True,
#   'validate_lick_before_scheduled_on_aborted_trials': True,
#   'validate_running_data': True,
#   'validate_licks': True,
#   'validate_minimal_dropped_frames': True,
#   'validate_no_read_errors': True,
#   'validate_omitted_flashes_are_omitted': True,
#   'visual_behavior_global_software_test': True,
#   'nb_wheel_artifacts': 0,
#   'total_reward_number': 137,
#   'total_reward_volume': 0.959,
#   'autorewards_without_lick': 0,
#   'aborted_trial_perc': 44.87632508833922,
#   'total_trial_number': 566,
#   'nb_dropped_visual_stim_events': 0,
#   'visual_stim_duration_min': 60.694361050279504,
#   'mean_visual_stim_period_s': 0.016678857117416734,
#   'nb_very_long_visual_stim_events': 0,
#   'rig_id': 'F3',
#   'operator': 'chelsean',
#   'external_specimen_name': '429084',
#   'task': 'DoC',
#   'stage': 'TRAINING_4_images_A_handoff_ready',
#   'behavior_stats': [{'mouse_id': '429084',
#     'behavior_session_uuid': UUID('6a28628a-44ea-4cb4-8199-34728309911c'),
#     'startdatetime': datetime.datetime(2019, 3, 29, 16, 27, 52, 842000),
#     'session_duration': 3616.4605942491353,
#     'd_prime_peak': 2.4660581729227027,
#     'd_prime': 1.6187748475737915,
#     'discrim_p': 4.542476639133927e-07,
#     'response_bias': 0.4391025641025641,
#     'earned_water': 0.9590000000000001,
#     'total_water': 0.959,
#     'num_contingent_trials': 312,
#     'lick_latency_median': 0.5003457288257778,
#     'fraction_time_aborted': 0.23775974145186662,
#     'fraction_time_hit': 0.32786068033990445,
#     'fraction_time_miss': 0.3407070107085683,
#     'fraction_time_correct_reject': 0.08930509377706557,
#     'fraction_time_false_alarm': 0.004367473722595153,
#     'fraction_time_auto_rewarded': 0.0,
#     'number_of_hit_trials': 135,
#     'number_of_miss_trials': 138,
#     'number_of_false_alarm_trials': 2,
#     'number_of_correct_reject_trials': 37,
#     'hit_rate': 0.4945054945054945,
#     'false_alarm_rate': 0.05128205128205128,
#     'hit_rate_peak': 0.6744186046511628,
#     'false_alarm_rate_peak': 0.14285714285714285,
#     'number_of_licks': 1472,
#     'blank_duration': 0.5,
#     'day_of_week': 4,
#     'change_time_distribution': 'geometric',
#     'user_id': 'chelsean',
#     'rig_id': 'F3',
#     'stimulus': 'images',
#     'stage': 'TRAINING_4_images_A_handoff_ready'}]}}
