# %%
# Import the BehaviorProjectCache, to see what sessions are available for analysis.
from allensdk.brain_observatory.behavior.behavior_project_cache import BehaviorProjectCache as bpc
manifest_path = "/home/alex.piet/codebase/behavior/manifest/manifest.json" # pick a path
cache = bpc.from_lims(manifest=manifest_path)
ophys_sessions = cache.get_session_table() # This returns a dataframe you can filter

# %%
# Currently this cache just scrapes everything off LIMS. Several QC filters are needed, but havent been implemented yet. 
ophys_sessions
# Out:
#                   behavior_session_id  \
# ophys_session_id
# 952430817                   952554548
# 954954402                   953982960
# 955775716                   956010809
# 957020350                   957032492
# 958105827                   958234742
# ...                               ...
# 794286862                   794324246
# 795009671                   795025333
# 795866393                   795903435
# 797611742                   797806962
# 799021448                   799131344
#
#                                                 ophys_experiment_id  \
# ophys_session_id
# 952430817         [953659741, 953659743, 953659745, 953659747, 9...
# 954954402         [958527464, 958527471, 958527474, 958527477, 9...
# 955775716         [956941841, 956941844, 956941846, 956941848, 9...
# 957020350         [957759562, 957759564, 957759566, 957759568, 9...
# 958105827         [958741219, 958741222, 958741224, 958741226, 9...
# ...

# %%
# To get the SDK session object, you need to use the ophys_experiment_id. You can get an ophys_experiment_id
# in two ways. Each sessions has a unique behavior_session_id. Each OPHYS session has a unique ophys_session_id. 
# Each scientifica session has a single ophys_experiment_id. Mesoscope sessions will have multiple ophys_experiment_ids 
# for each ophys_session_id. To conver between these, we wrote some useful functions:
from visual_behavior.translator.allensdk_sessions import sdk_utils
bsid = 855866701
# From behavior_session_id
oeid = sdk_utils.get_oeid_from_bsid(bsid,cache)
# From ophys_session_id
osid = sdk_utils.get_osid_from_bsid(bsid,cache)
oeid = sdk_utils.get_oeid_from_osid(osid,cache)

# %%
# Once you have the ophys_experiment_id, you can load the SDK session object by:
session =cache.get_session_data(oeid)

# %%
# you can see dataframes like session.stimulus_presentations, just as before.
session.stimulus_presentations
# Out:
#                            duration  end_frame  image_index image_name  \
# stimulus_presentations_id
# 0                           0.25015    18001.0            0      im000
# 1                           0.25023    18046.0            0      im000
# 2                           0.25019    18091.0            0      im000
# 3                           0.25022    18136.0            0      im000
# 4                           0.25019    18181.0            0      im000
# ...                             ...        ...          ...        ...
# 4792                        0.25054   233641.0            1      im106
# 4793                        0.25029   233686.0            1      im106
# 4794                        0.25021   233731.0            1      im106
# 4795                        0.25020   233776.0            1      im106
# 4796                        0.25019   233821.0            1      im106
#
#                                                                    image_set  \
# ...

# %%
# Right now, the SDK does not support many of the analysis tools that existed in the SWDB version of the SDK that many 
# of have been using. Nick and Alex have put many of those analysis tools in VBA. This function adds many basic things.
sdk_utils.add_stimulus_presentations_analysis(session)
session.stimulus_presentations
# Out:
#                            duration  end_frame  image_index image_name  \
# stimulus_presentations_id
# 0                           0.25015    18001.0            0      im000
# 1                           0.25023    18046.0            0      im000
# 2                           0.25019    18091.0            0      im000
# 3                           0.25022    18136.0            0      im000
# 4                           0.25019    18181.0            0      im000
# ...                             ...        ...          ...        ...
# 4792                        0.25054   233641.0            1      im106
# 4793                        0.25029   233686.0            1      im106
# 4794                        0.25021   233731.0            1      im106
# 4795                        0.25020   233776.0            1      im106
# 4796                        0.25019   233821.0            1      im106
#
#                                                                    image_set  \
# ...
