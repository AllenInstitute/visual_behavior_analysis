# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/movie_mean_oeid=1103720970.csv')

fig, ax= plt.subplots(1, 1, figsize = (10,5), sharex=True)
ax.plot(df['time'], df['movie_mean'])
ax.set_xlabel('time in session')
ax.set_ylabel('mean F across full frame')
# Out:
# <img src="data:image/png;base64,..." width="998.8889153504084">
# Text(0, 0.5, 'mean F across full frame')

# %%
df = pd.read_csv('/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/movie_mean_oeid=1103720970.csv')

# %%
# Out:
# <img src="data:image/png;base64,..." width="1498.8889285958853">
# Text(0, 0.5, 'mean F across full frame')

# %%
# Out:
# /home/dougo/anaconda3/envs/keras/lib/python3.6/site-packages/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam2_exposure', 'cam1_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# WARNING:root:acquiring (valid line label(s) = ['2p_acquiring']
# /home/dougo/anaconda3/envs/keras/lib/python3.6/site-packages/allensdk/brain_observatory/behavior/session_apis/data_transforms/behavior_ophys_data_transforms.py:189: UserWarning: Monitory delay calculation failed with ValueError
#     "Can't find valid start event"
# looking monitor delay up from table for rig: MESO.1
# delay: 0.03613 seconds
#   warnings.warn(warning_msg)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
from allensdk.brain_observatory.behavior.behavior_ophys_experiment import BehaviorOphysExperiment

dataset = BehaviorOphysExperiment.from_lims(int(oeid))

# %%
dataset.running_speed
# Out:
# /home/dougo/anaconda3/envs/keras/lib/python3.6/site-packages/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam2_exposure', 'cam1_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# WARNING:root:acquiring (valid line label(s) = ['2p_acquiring']
# /home/dougo/anaconda3/envs/keras/lib/python3.6/site-packages/allensdk/brain_observatory/behavior/session_apis/data_transforms/behavior_ophys_data_transforms.py:189: UserWarning: Monitory delay calculation failed with ValueError
#     "Can't find valid start event"
# looking monitor delay up from table for rig: MESO.1
# delay: 0.03613 seconds
#   warnings.warn(warning_msg)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...
