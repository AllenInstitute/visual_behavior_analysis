# %% [markdown]
# NWB file sanity check

# %%
import os
import numpy as np
import pandas as pd

# %%
import allensdk

# %%
from allensdk.brain_observatory.behavior.behavior_session import BehaviorSession
from allensdk.brain_observatory.behavior.behavior_ophys_session import BehaviorOphysSession

# %%
allensdk.__version__
# Out:
# '2.13.4'

# %%
import pynwb
pynwb.__version__
# Out:
# '1.4.0'

# %%
BehaviorOphysSession.from_nwb(behav_files[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21908\2188849252.py in <module>
# ----> 1 BehaviorOphysSession.from_nwb(behav_files[0])
#
# ~\AppData\Roaming\Python\Python37\site-packages\allensdk\brain_observatory\behavior\behavior_ophys_experiment.py in from_nwb(cls, nwbfile, eye_tracking_z_threshold, eye_tracking_dilation_frames, events_filter_scale_seconds, events_filter_n_time_steps, exclude_invalid_rois)
#     269                 imaging_plane_group_meta=imaging_plane_group_meta)
#     270
# --> 271         behavior_session = BehaviorSession.from_nwb(nwbfile=nwbfile)
#     272         projections = Projections.from_nwb(nwbfile=nwbfile)
#     273         cell_specimens = CellSpecimens.from_nwb(
#
# ~\AppData\Roaming\Python\Python37\site-packages\allensdk\brain_observatory\behavior\behavior_session.py in from_nwb(cls, nwbfile, **kwargs)
# ...

# %%
BehaviorSession.from_nwb

# %%
BehaviorOphysSession.from_nwb(filename)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21908\2073778823.py in <module>
# ----> 1 BehaviorOphysSession.from_nwb(filename)
#
# ~\AppData\Roaming\Python\Python37\site-packages\allensdk\brain_observatory\behavior\behavior_ophys_experiment.py in from_nwb(cls, nwbfile, eye_tracking_z_threshold, eye_tracking_dilation_frames, events_filter_scale_seconds, events_filter_n_time_steps, exclude_invalid_rois)
#     269                 imaging_plane_group_meta=imaging_plane_group_meta)
#     270
# --> 271         behavior_session = BehaviorSession.from_nwb(nwbfile=nwbfile)
#     272         projections = Projections.from_nwb(nwbfile=nwbfile)
#     273         cell_specimens = CellSpecimens.from_nwb(
#
# ~\AppData\Roaming\Python\Python37\site-packages\allensdk\brain_observatory\behavior\behavior_session.py in from_nwb(cls, nwbfile, **kwargs)
# ...

# %%
ophys_files = os.listdir(os.path.join(folder_path, 'ophys_experiments'))
behav_files = os.listdir(os.path.join(folder_path, 'behavior_sessions'))

# %%
folder_path = '//allen/aibs/informatics/chris.morrison/vbo_nbw_test'
filename = '775614751.nwb'
file = os.path.join(folder_path, 'ophys_experiments', filename)

# %%
from pynwb import NWBFile, TimeSeries, NWBHDF5IO

# %%
with NWBHDF5IO(file, "r") as io:
    read_nwbfile = io.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21908\885835595.py in <module>
#       1 with NWBHDF5IO(file, "r") as io:
# ----> 2     read_nwbfile = io.read()
#
# ~\Anaconda3\envs\vba\lib\site-packages\hdmf\backends\hdf5\h5tools.py in read(self, **kwargs)
#     493                                        % (self.source, self.__mode))
#     494         try:
# --> 495             return call_docval_func(super().read, kwargs)
#     496         except UnsupportedOperation as e:
#     497             if str(e) == 'Cannot build data. There are no values.':  # pragma: no cover
#
# ~\Anaconda3\envs\vba\lib\site-packages\hdmf\utils.py in call_docval_func(func, kwargs)
#     421 def call_docval_func(func, kwargs):
#     422     fargs, fkwargs = fmt_docval_args(func, kwargs)
# --> 423     return func(*fargs, **fkwargs)
#     424
#     425
#
# ...

# %%
io = NWBHDF5IO(file, mode="r")
nwbfile = io.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21908\3615209869.py in <module>
#       1 io = NWBHDF5IO(file, mode="r")
# ----> 2 nwbfile = io.read()
#
# ~\Anaconda3\envs\vba\lib\site-packages\hdmf\backends\hdf5\h5tools.py in read(self, **kwargs)
#     493                                        % (self.source, self.__mode))
#     494         try:
# --> 495             return call_docval_func(super().read, kwargs)
#     496         except UnsupportedOperation as e:
#     497             if str(e) == 'Cannot build data. There are no values.':  # pragma: no cover
#
# ~\Anaconda3\envs\vba\lib\site-packages\hdmf\utils.py in call_docval_func(func, kwargs)
#     421 def call_docval_func(func, kwargs):
#     422     fargs, fkwargs = fmt_docval_args(func, kwargs)
# --> 423     return func(*fargs, **fkwargs)
#     424
#     425
#
# ...
