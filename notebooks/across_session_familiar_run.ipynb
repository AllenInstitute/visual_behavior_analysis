# %%
import warnings
warnings.filterwarnings('ignore')
import visual_behavior_glm.GLM_across_session as gas
import visual_behavior_glm.GLM_fit_tools as gft
from visual_behavior.dimensionality_reduction.clustering import processing

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
cells_table = processing.get_cells_matched_in_3_familiar_active_sessions()
# Out:
# 1244 experiments
# 452 familiar active experiments
# ['Familiar']
# ['OPHYS_1_images_A' 'OPHYS_3_images_A' 'OPHYS_1_images_B'
#  'OPHYS_3_images_B']
# 451 experiments in filtered cells table
# 17990 familiar active cell_specimen_ids
# 17990 familiar active cell_specimen_ids
# 5 familiar active session numbers
# checking session counts: [3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3]
# 1450 cell_specimen_ids in at least 3 sessions
# ['Familiar']
# ['OPHYS_3_images_A' 'OPHYS_1_images_A' 'OPHYS_1_images_B'
#  'OPHYS_3_images_B']
# 1450 familiar active cell_specimen_ids in the first 3 sessions
# 3 familiar active session numbers
# 1450 familiar active cell_specimen_ids
# 1450 familiar active cell_specimen_ids
# 3 familiar active session numbers
# experience_levels:  ['Familiar 1' 'Familiar 2' 'Familiar 3']

# %%
cell_specimen_ids = cells_table.cell_specimen_id.unique()
len(cell_specimen_ids)
# Out:
# 1450

# %%
import visual_behavior_glm.GLM_params as glm_params

# %%
glm_version = '24_events_all_L2_optimize_by_session'

# %%
run_params = glm_params.load_run_json(glm_version)

# %%
import hdmf
hdmf.__version__
# Out:
# '2.2.0'

# %%
import allensdk
allensdk.__version__
# Out:
# '2.15.2'

# %%
import pynwb
pynwb.__version__
# Out:
# '1.4.0'

# %%
import h5py

h5py.__version__
# Out:
# '2.9.0'

# %%
import visual_behavior.data_access.loading as loading
dataset = loading.get_ophys_dataset(993344852, include_invalid_rois=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3812\1140834474.py in <module>
#       1 import visual_behavior.data_access.loading as loading
# ----> 2 dataset = loading.get_ophys_dataset(993344852, include_invalid_rois=False)
#
# c:\users\iryna.yavorska\documents\github\visual_behavior_analysis\visual_behavior\data_access\loading.py in get_ophys_dataset(ophys_experiment_id, include_invalid_rois, load_from_lims, load_from_nwb, get_extended_stimulus_presentations, get_behavior_movie_timestamps)
#     942         cache_dir = get_platform_analysis_cache_dir()
#     943         cache = bpc.from_s3_cache(cache_dir=cache_dir)
# --> 944         dataset = cache.get_behavior_ophys_experiment(ophys_experiment_id)
#     945     else:
#     946         raise Exception('Set load_from_lims or load_from_nwb to True')
#
# ...

# %%
experiment = gft.load_fit_experiment(993344852, run_params)
# Out:
# loading fit
# loading sdk object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3812\3050450687.py in <module>
# ----> 1 experiment = gft.load_fit_experiment(993344852, run_params)
#
# c:\users\iryna.yavorska\documents\github\visual_behavior_glm\visual_behavior_glm\GLM_fit_tools.py in load_fit_experiment(ophys_experiment_id, run_params)
#      43     fit = gat.load_fit_pkl(run_params, ophys_experiment_id)
#      44     print('loading sdk object')
# ---> 45     session = load_data(ophys_experiment_id, run_params)
#      46
#      47     # num_weights gets populated during stimulus interpolation
#
# c:\users\iryna.yavorska\documents\github\visual_behavior_glm\visual_behavior_glm\GLM_fit_tools.py in load_data(oeid, run_params)
#     946         include_invalid_rois = False
#     947
# ...

# %%
# data_across_df = gas.across_session_normalization(cell_specimen_ids[0],glm_version,do_folds=False, familiar_only=True)
