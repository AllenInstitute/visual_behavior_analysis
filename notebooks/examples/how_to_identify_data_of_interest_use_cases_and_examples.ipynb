# %% [markdown]
# ## Notebook demonstrating how to identify experiments, sessions, containers, or mice of interest using LIMS BehaviorProjectCache and associated VBA filtering functions

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_context('notebook', font_scale=1.5, rc={'lines.markeredgewidth': 2})

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %% [markdown]
# # Table of Contents
#
# 1. [Experiments table](#expts_table)<br>
#     1.1 [Get list of experiments from BehaviorProjectCache](#bpc)<br>
#     1.2 [Get experiments that are in the data release](#release_expts)<br>
# 2. Container level view

# %% [markdown]
# ## 1. Experiments table
# <a id='expts_table'></a>

# %% [markdown]
# ### 1.1 Get list of experiments from BehaviorProjectCache
# <a id='bpc'></a>

# %% [markdown]
# <code>BehaviorProjectCache.get_experiment_table()</code> currently returns a list of ophys data from lims, for a variety of project codes, regardless of QC state. This is the maximally inclusive all encompasing list, including failed data and very recently collected data.

# %%
from allensdk.brain_observatory.behavior.behavior_project_cache import BehaviorProjectCache

# %%
cache = BehaviorProjectCache.from_lims()
all_experiments = cache.get_experiment_table()

print(len(all_experiments))
# Out:
# Getting all ophys sessions. This might take a while.
# 4449

# %%
all_experiments.project_code.unique()
# Out:
# array(['VisualBehaviorMultiscope', 'VisualBehavior',
#        'VisBIntTestDatacube', 'VisualBehaviorTask1B',
#        'MultiscopeSignalNoise', 'VisualBehaviorMultiscope4areasx2d',
#        'VisualBehaviorIntegrationTest'], dtype=object)

# %%
all_experiments.experiment_workflow_state.unique()
# Out:
# array(['passed', 'failed', 'qc', 'created'], dtype=object)

# %%
all_experiments.keys()
# Out:
# Index(['ophys_session_id', 'behavior_session_id', 'container_id',
#        'project_code', 'container_workflow_state', 'experiment_workflow_state',
#        'session_name', 'session_type', 'equipment_name', 'date_of_acquisition',
#        'isi_experiment_id', 'specimen_id', 'donor_id', 'sex', 'age_in_days',
#        'full_genotype', 'mouse_id', 'reporter_line', 'driver_line',
#        'imaging_depth', 'targeted_structure', 'published_at'],
#       dtype='object')

# %% [markdown]
# ## 2. Get experiments that are in the data release using VBA <code>get_filtered_ophys_dataset()</code>
# <a id='release_expts'></a>

# %% [markdown]
# To limit to release experiments only, use VBA function to restrict to experiments that have passed QC from relevant project codes. This function loads from a previously cached file, so that the dataset used for analysis is stable and consistent across users.

# %% [markdown]
# https://github.com/AllenInstitute/visual_behavior_analysis/blob/master/visual_behavior/data_access/loading.py#L130

# %%
import visual_behavior.data_access.loading as loading

# %%
experiments = loading.get_filtered_ophys_experiment_table(release_data_only=True)
print('there are', len(experiments), 'experiments in the release')
# Out:
# there are 1109 experiments in the release

# %%
experiments.head()
# Out:
#                      ophys_session_id  behavior_session_id  container_id  \
# ophys_experiment_id
# 951980471                   951410079            951520319    1018028342
# 951980475                   951410079            951520319    1018028339
# 951980486                   951410079            951520319    1018028360
# 951980479                   951410079            951520319    1018028354
# 951980481                   951410079            951520319    1018028357
#
#                                  project_code container_workflow_state  \
# ophys_experiment_id
# 951980471            VisualBehaviorMultiscope                published
# 951980475            VisualBehaviorMultiscope                published
# 951980486            VisualBehaviorMultiscope                published
# 951980479            VisualBehaviorMultiscope                published
# 951980481            VisualBehaviorMultiscope                published
#
#                     experiment_workflow_state                session_name  \
# ophys_experiment_id
# 951980471                              passed  20190920_457841_1imagesA_2
# 951980475                              passed  20190920_457841_1imagesA_2
# 951980486                              passed  20190920_457841_1imagesA_2
# 951980479                              passed  20190920_457841_1imagesA_2
# 951980481                              passed  20190920_457841_1imagesA_2
#
#                          session_type equipment_name  \
# ophys_experiment_id
# 951980471            OPHYS_1_images_A         MESO.1
# 951980475            OPHYS_1_images_A         MESO.1
# 951980486            OPHYS_1_images_A         MESO.1
# 951980479            OPHYS_1_images_A         MESO.1
# 951980481            OPHYS_1_images_A         MESO.1
#
#                             date_of_acquisition  ...  super_container_id  \
# ophys_experiment_id                              ...
# 951980471            2019-09-20 09:45:29.897856  ...           850862430
# 951980475            2019-09-20 09:45:29.897856  ...           850862430
# 951980486            2019-09-20 09:45:29.897856  ...           850862430
# 951980479            2019-09-20 09:45:29.897856  ...           850862430
# 951980481            2019-09-20 09:45:29.897856  ...           850862430
#
#                          cre_line  session_tags failure_tags  \
# ophys_experiment_id
# 951980471            Sst-IRES-Cre           NaN          NaN
# 951980475            Sst-IRES-Cre           NaN          NaN
# 951980486            Sst-IRES-Cre           NaN          NaN
# 951980479            Sst-IRES-Cre           NaN          NaN
# 951980481            Sst-IRES-Cre           NaN          NaN
#
#                      prior_exposures_to_session_type  \
# ophys_experiment_id
# 951980471                                          0
# 951980475                                          0
# 951980486                                          0
# 951980479                                          0
# 951980481                                          0
#
#                     prior_exposures_to_image_set  \
# ophys_experiment_id
# 951980471                                   65.0
# 951980475                                   65.0
# 951980486                                   65.0
# 951980479                                   65.0
# 951980481                                   65.0
#
#                      prior_exposures_to_omissions model_outputs_available  \
# ophys_experiment_id
# 951980471                                     0.0                   False
# 951980475                                     0.0                   False
# 951980486                                     0.0                   False
# 951980479                                     0.0                   False
# 951980481                                     0.0                   False
#
#                          location  session_number
# ophys_experiment_id
# 951980471            Sst_VISp_150               1
# 951980475             Sst_VISp_75               1
# 951980486            Sst_VISl_300               1
# 951980479            Sst_VISl_150               1
# 951980481            Sst_VISl_225               1
#
# [5 rows x 32 columns]

# %%
experiments.project_code.unique()
# Out:
# array(['VisualBehaviorMultiscope', 'VisualBehaviorTask1B',
#        'VisualBehavior'], dtype=object)

# %%
experiments.experiment_workflow_state.unique()
# Out:
# array(['passed'], dtype=object)

# %%
# this table also includes a few extra useful columns
experiments.keys()
# Out:
# Index(['ophys_session_id', 'behavior_session_id', 'container_id',
#        'project_code', 'container_workflow_state', 'experiment_workflow_state',
#        'session_name', 'session_type', 'equipment_name', 'date_of_acquisition',
#        'isi_experiment_id', 'specimen_id', 'donor_id', 'sex', 'age_in_days',
#        'full_genotype', 'mouse_id', 'reporter_line', 'driver_line',
#        'imaging_depth', 'targeted_structure', 'published_at',
#        'super_container_id', 'cre_line', 'session_tags', 'failure_tags',
#        'prior_exposures_to_session_type', 'prior_exposures_to_image_set',
#        'prior_exposures_to_omissions', 'model_outputs_available', 'location',
#        'session_number'],
#       dtype='object')

# %% [markdown]
# ### Describe the dataset - how many mice, containers, sessions, and experiments are there for each project?

# %%
n_mice = experiments.groupby(['project_code', 'cre_line', 'mouse_id']).count().reset_index().groupby(['project_code','cre_line']).count()[['mouse_id']].rename(columns={'mouse_id':'# mice'})
n_containers = experiments.groupby(['project_code', 'cre_line', 'container_id']).count().reset_index().groupby(['project_code','cre_line']).count()[['container_id']].rename(columns={'container_id':'# containers'})
n_sessions = experiments.groupby(['project_code', 'cre_line', 'ophys_session_id']).count().reset_index().groupby(['project_code','cre_line']).count()[['ophys_session_id']].rename(columns={'ophys_session_id':'# sessions'})
n_experiments = experiments.groupby(['project_code', 'cre_line', 'ophys_experiment_id']).count().reset_index().groupby(['project_code','cre_line']).count()[['ophys_experiment_id']].rename(columns={'ophys_experiment_id':'# experiments'})

dataset = n_mice.merge(n_containers, on=['project_code', 'cre_line'])
dataset = dataset.merge(n_sessions, on=['project_code', 'cre_line'])
dataset = dataset.merge(n_experiments, on=['project_code', 'cre_line'])
for i, column in enumerate(dataset.columns):
    dataset.at[('Total', ''),column] = int(dataset.sum()[i])
dataset = dataset.apply(pd.to_numeric, downcast='integer')
dataset
# Out:
#                                             # mice  # containers  # sessions  \
# project_code             cre_line
# VisualBehavior           Slc17a7-IRES2-Cre      17            17         103
#                          Sst-IRES-Cre            4             4          26
#                          Vip-IRES-Cre            7             7          46
# VisualBehaviorMultiscope Slc17a7-IRES2-Cre       6            42          43
#                          Sst-IRES-Cre            4            23          30
#                          Vip-IRES-Cre            9            56          60
# VisualBehaviorTask1B     Slc17a7-IRES2-Cre      14            14          95
#                          Sst-IRES-Cre            7             7          50
#                          Vip-IRES-Cre            6             6          42
# Total                                           74           176         495
#
#                                             # experiments
# project_code             cre_line
# VisualBehavior           Slc17a7-IRES2-Cre            103
#                          Sst-IRES-Cre                  26
#                          Vip-IRES-Cre                  46
# VisualBehaviorMultiscope Slc17a7-IRES2-Cre            265
#                          Sst-IRES-Cre                 149
#                          Vip-IRES-Cre                 333
# VisualBehaviorTask1B     Slc17a7-IRES2-Cre             95
#                          Sst-IRES-Cre                  50
#                          Vip-IRES-Cre                  42
# Total                                                1109

# %% [markdown]
# ### Get all Vip experiments

# %%
vip_experiments = experiments[(experiments.cre_line=='Vip-IRES-Cre')]
print(len(vip_experiments))
# Out:
# 421

# %%
vip_experiments.head()
# Out:
#                      ophys_session_id  behavior_session_id  container_id  \
# ophys_experiment_id
# 792815735                   792619807            792680306     791352433
# 795073741                   794918442            794968300     791352433
# 795953296                   795625712            795742990     791352433
# 796108483                   796044280            796052844     791352433
# 796308505                   796236521            796251270     791352433
#
#                        project_code container_workflow_state  \
# ophys_experiment_id
# 792815735            VisualBehavior                published
# 795073741            VisualBehavior                published
# 795953296            VisualBehavior                published
# 796108483            VisualBehavior                published
# 796308505            VisualBehavior                published
#
#                     experiment_workflow_state              session_name  \
# ophys_experiment_id
# 792815735                              passed  20181210_412036_1imagesA
# 795073741                              passed  20181213_412036_3imagesA
# 795953296                              passed  20181214_412036_4imagesB
# 796108483                              passed  20181215_412036_5imagesB
# 796308505                              passed  20181216_412036_6imagesB
#
#                                  session_type equipment_name  \
# ophys_experiment_id
# 792815735                    OPHYS_1_images_A        CAM2P.4
# 795073741                    OPHYS_3_images_A        CAM2P.4
# 795953296                    OPHYS_4_images_B        CAM2P.4
# 796108483            OPHYS_5_images_B_passive        CAM2P.4
# 796308505                    OPHYS_6_images_B        CAM2P.4
#
#                             date_of_acquisition  ...  super_container_id  \
# ophys_experiment_id                              ...
# 792815735            2018-12-10 21:19:50.000000  ...           744911458
# 795073741            2018-12-13 21:11:17.000000  ...           744911458
# 795953296            2018-12-14 20:17:05.000000  ...           744911458
# 796108483            2018-12-15 20:56:37.000000  ...           744911458
# 796308505            2018-12-16 20:44:48.000000  ...           744911458
#
#                          cre_line  session_tags failure_tags  \
# ophys_experiment_id
# 792815735            Vip-IRES-Cre           NaN          NaN
# 795073741            Vip-IRES-Cre           NaN          NaN
# 795953296            Vip-IRES-Cre           NaN          NaN
# 796108483            Vip-IRES-Cre           NaN          NaN
# 796308505            Vip-IRES-Cre           NaN          NaN
#
#                      prior_exposures_to_session_type  \
# ophys_experiment_id
# 792815735                                          0
# 795073741                                          0
# 795953296                                          0
# 796108483                                          0
# 796308505                                          0
#
#                     prior_exposures_to_image_set  \
# ophys_experiment_id
# 792815735                                   19.0
# 795073741                                   21.0
# 795953296                                    0.0
# 796108483                                    1.0
# 796308505                                    2.0
#
#                      prior_exposures_to_omissions model_outputs_available  \
# ophys_experiment_id
# 792815735                                     1.0                    True
# 795073741                                     3.0                    True
# 795953296                                     4.0                    True
# 796108483                                     5.0                   False
# 796308505                                     6.0                    True
#
#                          location  session_number
# ophys_experiment_id
# 792815735            Vip_VISp_175               1
# 795073741            Vip_VISp_175               3
# 795953296            Vip_VISp_175               4
# 796108483            Vip_VISp_175               5
# 796308505            Vip_VISp_175               6
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Get Vip containers that have a session that is the first exposure to a novel image set

# %%
vip_containers_with_novelty = vip_experiments[vip_experiments.prior_exposures_to_image_set==0]
vip_container_ids_with_novelty = vip_containers_with_novelty.container_id.unique()

print('there are', len(vip_container_ids_with_novelty), 'containers with a novel image set exposure')
print('\n')
print('container_ids: ',vip_container_ids_with_novelty)
# Out:
# there are 47 containers with a novel image set exposure
#
#
# container_ids:  [ 791352433  825183217  957570596 1046576791 1046576787 1046576772
#  1046576775 1046576784 1046576794  969421516  929913236 1026722876
#  1026722873 1026722861 1026722854 1026722858 1064333322 1064333290
#  1051327176  991913246 1018027853 1018027847 1018027865 1018027859
#  1018027868 1018027862 1022731547 1022731524 1022731527 1022731531
#  1022731544 1022731540 1000740410 1000740620 1018027593 1018027602
#  1018027611 1018027608 1018027615 1018027605 1018027599 1018028172
#  1018028169 1018028166 1018028185 1018028182 1018028188]

# %% [markdown]
# ### In what order were the sessions for these containers collected?

# %% [markdown]
# #### Let's look at the data from a container view

# %% [markdown]
# VBA function <code>build_container_df()</code> rearranges the experiment table to organize data by container_id

# %% [markdown]
# https://github.com/AllenInstitute/visual_behavior_analysis/blob/master/visual_behavior/data_access/loading.py#L2009

# %%
containers = loading.build_container_df(experiments)

# %%
containers.head()
# Out:
#                           project_code  mouse_id sex  age_in_days  \
# container_id
# 1064333322              VisualBehavior    544261   F        126.0
# 1064333290              VisualBehavior    538219   F        165.0
# 1058209392        VisualBehaviorTask1B    539518   F        128.0
# 1054675423        VisualBehaviorTask1B    539517   M        113.0
# 1052096570    VisualBehaviorMultiscope    528097   F        167.0
#
#                                                   full_genotype  \
# container_id
# 1064333322        Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 1064333290        Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 1058209392    Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 1054675423    Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 1052096570        Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
#
#                        cre_line targeted_structure  imaging_depth  \
# container_id
# 1064333322         Vip-IRES-Cre               VISp            175
# 1064333290         Vip-IRES-Cre               VISp            175
# 1058209392    Slc17a7-IRES2-Cre               VISp            375
# 1054675423    Slc17a7-IRES2-Cre               VISp            175
# 1052096570         Vip-IRES-Cre               VISl            225
#
#              first_acquisition_date equipment_name  ...  \
# container_id                                        ...
# 1064333322               2020-11-23      [CAM2P.4]  ...
# 1064333290               2020-11-23      [CAM2P.3]  ...
# 1058209392               2020-10-27      [CAM2P.4]  ...
# 1054675423               2020-10-12      [CAM2P.3]  ...
# 1052096570               2020-09-22       [MESO.1]  ...
#
#                                                       session_1  \
# container_id
# 1064333322            OPHYS_3_images_A experiment_id:1067133175
# 1064333290            OPHYS_1_images_A experiment_id:1065966776
# 1058209392    OPHYS_2_images_B_passive experiment_id:1059768347
# 1054675423            OPHYS_3_images_B experiment_id:1056561863
# 1052096570    OPHYS_2_images_A_passive experiment_id:1052412568
#
#                                                       session_2  \
# container_id
# 1064333322            OPHYS_4_images_B experiment_id:1067647876
# 1064333290    OPHYS_2_images_A_passive experiment_id:1066177684
# 1058209392            OPHYS_3_images_B experiment_id:1059963010
# 1054675423    OPHYS_2_images_B_passive experiment_id:1057070365
# 1052096570            OPHYS_3_images_A experiment_id:1052637596
#
#                                                       session_3  \
# container_id
# 1064333322    OPHYS_5_images_B_passive experiment_id:1069286458
# 1064333290            OPHYS_3_images_A experiment_id:1067133170
# 1058209392            OPHYS_3_images_B experiment_id:1060184782
# 1054675423            OPHYS_4_images_A experiment_id:1057706462
# 1052096570            OPHYS_6_images_B experiment_id:1057725806
#
#                                                       session_4  \
# container_id
# 1064333322            OPHYS_6_images_B experiment_id:1071070929
# 1064333290            OPHYS_4_images_B experiment_id:1067648397
# 1058209392            OPHYS_4_images_A experiment_id:1060759278
# 1054675423    OPHYS_5_images_A_passive experiment_id:1057956396
# 1052096570                                                  NaN
#
#                                                       session_5  \
# container_id
# 1064333322            OPHYS_6_images_B experiment_id:1071440875
# 1064333290    OPHYS_5_images_B_passive experiment_id:1068173247
# 1058209392    OPHYS_5_images_A_passive experiment_id:1061327688
# 1054675423            OPHYS_4_images_A experiment_id:1058275574
# 1052096570                                                  NaN
#
#                                               session_6  \
# container_id
# 1064333322                                          NaN
# 1064333290    OPHYS_6_images_B experiment_id:1069286452
# 1058209392    OPHYS_6_images_A experiment_id:1061787719
# 1054675423    OPHYS_4_images_A experiment_id:1058813457
# 1052096570                                          NaN
#
#                                               session_7 session_8 session_9  \
# container_id
# 1064333322                                          NaN       NaN       NaN
# 1064333290                                          NaN       NaN       NaN
# 1058209392                                          NaN       NaN       NaN
# 1054675423    OPHYS_6_images_A experiment_id:1059340828       NaN       NaN
# 1052096570                                          NaN       NaN       NaN
#
#              session_10
# container_id
# 1064333322          NaN
# 1064333290          NaN
# 1058209392          NaN
# 1054675423          NaN
# 1052096570          NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# #### look at containers with a novel image session that was not a retake

# %%
# scroll to the right to see session order 
# reminder this is only passing experiments
novel_vip_containers = containers.loc[vip_container_ids_with_novelty]
novel_vip_containers.head()
# Out:
#                           project_code  mouse_id sex  age_in_days  \
# container_id
# 791352433               VisualBehavior    412036   F        148.0
# 825183217               VisualBehavior    429952   M        131.0
# 957570596         VisualBehaviorTask1B    467953   M        177.0
# 1046576791    VisualBehaviorMultiscope    523922   M        172.0
# 1046576787    VisualBehaviorMultiscope    523922   M        172.0
#
#                                               full_genotype      cre_line  \
# container_id
# 791352433     Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 825183217     Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 957570596     Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 1046576791    Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 1046576787    Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
#
#              targeted_structure  imaging_depth first_acquisition_date  \
# container_id
# 791352433                  VISp            175             2018-12-10
# 825183217                  VISp            175             2019-02-20
# 957570596                  VISp            175             2019-10-10
# 1046576791                 VISl            225             2020-09-04
# 1046576787                 VISl            150             2020-09-04
#
#              equipment_name  ...  \
# container_id                 ...
# 791352433         [CAM2P.4]  ...
# 825183217         [CAM2P.4]  ...
# 957570596         [CAM2P.4]  ...
# 1046576791         [MESO.1]  ...
# 1046576787         [MESO.1]  ...
#
#                                                       session_1  \
# container_id
# 791352433              OPHYS_3_images_A experiment_id:795073741
# 825183217              OPHYS_4_images_B experiment_id:830093338
# 957570596      OPHYS_2_images_B_passive experiment_id:967008454
# 1046576791    OPHYS_2_images_A_passive experiment_id:1049610125
# 1046576787    OPHYS_2_images_A_passive experiment_id:1049610123
#
#                                                      session_2  \
# container_id
# 791352433             OPHYS_4_images_B experiment_id:795953296
# 825183217     OPHYS_5_images_B_passive experiment_id:830700800
# 957570596             OPHYS_3_images_B experiment_id:967876201
# 1046576791           OPHYS_3_images_A experiment_id:1050485654
# 1046576787           OPHYS_3_images_A experiment_id:1050485652
#
#                                                      session_3  \
# container_id
# 791352433     OPHYS_5_images_B_passive experiment_id:796108483
# 825183217             OPHYS_6_images_B experiment_id:832115263
# 957570596             OPHYS_4_images_A experiment_id:968651977
# 1046576791           OPHYS_4_images_B experiment_id:1050762974
# 1046576787           OPHYS_4_images_B experiment_id:1050762972
#
#                                                      session_4  \
# container_id
# 791352433             OPHYS_6_images_B experiment_id:796308505
# 825183217             OPHYS_6_images_B experiment_id:833631914
# 957570596     OPHYS_5_images_A_passive experiment_id:969809655
# 1046576791           OPHYS_6_images_B experiment_id:1051249031
# 1046576787           OPHYS_6_images_B experiment_id:1051249029
#
#                                                      session_5  \
# container_id
# 791352433     OPHYS_2_images_A_passive experiment_id:798404219
# 825183217             OPHYS_3_images_A experiment_id:836258957
# 957570596             OPHYS_6_images_A experiment_id:971280274
# 1046576791           OPHYS_4_images_B experiment_id:1051460018
# 1046576787           OPHYS_4_images_B experiment_id:1051460016
#
#                                                      session_6 session_7  \
# container_id
# 791352433                                                  NaN       NaN
# 825183217     OPHYS_2_images_A_passive experiment_id:836911939       NaN
# 957570596             OPHYS_6_images_A experiment_id:972200901       NaN
# 1046576791                                                 NaN       NaN
# 1046576787                                                 NaN       NaN
#
#              session_8 session_9 session_10
# container_id
# 791352433          NaN       NaN        NaN
# 825183217          NaN       NaN        NaN
# 957570596          NaN       NaN        NaN
# 1046576791         NaN       NaN        NaN
# 1046576787         NaN       NaN        NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Pick a container from the VisualBehavior project where you like the order of sessions and get the mouse_id for that container

# %%
visual_behavior_containers = novel_vip_containers[novel_vip_containers.project_code=='VisualBehavior']
visual_behavior_containers
# Out:
#                 project_code  mouse_id sex  age_in_days  \
# container_id
# 791352433     VisualBehavior    412036   F        148.0
# 825183217     VisualBehavior    429952   M        131.0
# 929913236     VisualBehavior    468866   F        139.0
# 1064333322    VisualBehavior    544261   F        126.0
# 1064333290    VisualBehavior    538219   F        165.0
# 1051327176    VisualBehavior    523927   F        192.0
#
#                                               full_genotype      cre_line  \
# container_id
# 791352433     Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 825183217     Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 929913236     Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 1064333322    Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 1064333290    Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 1051327176    Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
#
#              targeted_structure  imaging_depth first_acquisition_date  \
# container_id
# 791352433                  VISp            175             2018-12-10
# 825183217                  VISp            175             2019-02-20
# 929913236                  VISp            175             2019-09-03
# 1064333322                 VISp            175             2020-11-23
# 1064333290                 VISp            175             2020-11-23
# 1051327176                 VISp            175             2020-09-24
#
#              equipment_name  ...                                  session_1  \
# container_id                 ...
# 791352433         [CAM2P.4]  ...   OPHYS_3_images_A experiment_id:795073741
# 825183217         [CAM2P.4]  ...   OPHYS_4_images_B experiment_id:830093338
# 929913236         [CAM2P.4]  ...   OPHYS_1_images_A experiment_id:940352989
# 1064333322        [CAM2P.4]  ...  OPHYS_3_images_A experiment_id:1067133175
# 1064333290        [CAM2P.3]  ...  OPHYS_1_images_A experiment_id:1065966776
# 1051327176        [CAM2P.4]  ...  OPHYS_3_images_A experiment_id:1053605418
#
#                                                       session_2  \
# container_id
# 791352433              OPHYS_4_images_B experiment_id:795953296
# 825183217      OPHYS_5_images_B_passive experiment_id:830700800
# 929913236      OPHYS_2_images_A_passive experiment_id:943134119
# 1064333322            OPHYS_4_images_B experiment_id:1067647876
# 1064333290    OPHYS_2_images_A_passive experiment_id:1066177684
# 1051327176    OPHYS_2_images_A_passive experiment_id:1053774037
#
#                                                       session_3  \
# container_id
# 791352433      OPHYS_5_images_B_passive experiment_id:796108483
# 825183217              OPHYS_6_images_B experiment_id:832115263
# 929913236              OPHYS_3_images_A experiment_id:945473009
# 1064333322    OPHYS_5_images_B_passive experiment_id:1069286458
# 1064333290            OPHYS_3_images_A experiment_id:1067133170
# 1051327176            OPHYS_4_images_B experiment_id:1053997501
#
#                                                       session_4  \
# container_id
# 791352433              OPHYS_6_images_B experiment_id:796308505
# 825183217              OPHYS_6_images_B experiment_id:833631914
# 929913236              OPHYS_3_images_A experiment_id:947716576
# 1064333322            OPHYS_6_images_B experiment_id:1071070929
# 1064333290            OPHYS_4_images_B experiment_id:1067648397
# 1051327176    OPHYS_5_images_B_passive experiment_id:1054266228
#
#                                                       session_5  \
# container_id
# 791352433      OPHYS_2_images_A_passive experiment_id:798404219
# 825183217              OPHYS_3_images_A experiment_id:836258957
# 929913236              OPHYS_3_images_A experiment_id:948507789
# 1064333322            OPHYS_6_images_B experiment_id:1071440875
# 1064333290    OPHYS_5_images_B_passive experiment_id:1068173247
# 1051327176            OPHYS_6_images_B experiment_id:1054813047
#
#                                                      session_6  \
# container_id
# 791352433                                                  NaN
# 825183217     OPHYS_2_images_A_passive experiment_id:836911939
# 929913236             OPHYS_4_images_B experiment_id:950833329
# 1064333322                                                 NaN
# 1064333290           OPHYS_6_images_B experiment_id:1069286452
# 1051327176                                                 NaN
#
#                                              session_7  \
# container_id
# 791352433                                          NaN
# 825183217                                          NaN
# 929913236     OPHYS_6_images_B experiment_id:953443028
# 1064333322                                         NaN
# 1064333290                                         NaN
# 1051327176                                         NaN
#
#                                                      session_8 session_9  \
# container_id
# 791352433                                                  NaN       NaN
# 825183217                                                  NaN       NaN
# 929913236     OPHYS_5_images_B_passive experiment_id:958435448       NaN
# 1064333322                                                 NaN       NaN
# 1064333290                                                 NaN       NaN
# 1051327176                                                 NaN       NaN
#
#              session_10
# container_id
# 791352433           NaN
# 825183217           NaN
# 929913236           NaN
# 1064333322          NaN
# 1064333290          NaN
# 1051327176          NaN
#
# [6 rows x 21 columns]

# %%
container_id = 1064333290
mouse_id = visual_behavior_containers.loc[container_id].mouse_id
print('mouse_id for container', container_id, 'is', mouse_id)
# Out:
# mouse_id for container 1064333290 is 538219

# %% [markdown]
# ### How many containers are there for this mouse?

# %%
novel_vip_containers[novel_vip_containers.mouse_id==mouse_id]
# Out:
#                 project_code  mouse_id sex  age_in_days  \
# container_id
# 1064333290    VisualBehavior    538219   F        165.0
#
#                                               full_genotype      cre_line  \
# container_id
# 1064333290    Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
#
#              targeted_structure  imaging_depth first_acquisition_date  \
# container_id
# 1064333290                 VISp            175             2020-11-23
#
#              equipment_name  ...                                  session_1  \
# container_id                 ...
# 1064333290        [CAM2P.3]  ...  OPHYS_1_images_A experiment_id:1065966776
#
#                                                       session_2  \
# container_id
# 1064333290    OPHYS_2_images_A_passive experiment_id:1066177684
#
#                                               session_3  \
# container_id
# 1064333290    OPHYS_3_images_A experiment_id:1067133170
#
#                                               session_4  \
# container_id
# 1064333290    OPHYS_4_images_B experiment_id:1067648397
#
#                                                       session_5  \
# container_id
# 1064333290    OPHYS_5_images_B_passive experiment_id:1068173247
#
#                                               session_6 session_7 session_8  \
# container_id
# 1064333290    OPHYS_6_images_B experiment_id:1069286452       NaN       NaN
#
#              session_9 session_10
# container_id
# 1064333290         NaN        NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# ### Compare to a mouse from the VisualBehaviorMultiscope project - how many containers are there? do they all have the same set of sessions?

# %%
multiscope_mice = novel_vip_containers[novel_vip_containers.project_code=='VisualBehaviorMultiscope'].mouse_id.unique()
mouse_id = multiscope_mice[0]

# %%
novel_vip_containers[novel_vip_containers.mouse_id==mouse_id]
# Out:
#                           project_code  mouse_id sex  age_in_days  \
# container_id
# 1046576791    VisualBehaviorMultiscope    523922   M        172.0
# 1046576787    VisualBehaviorMultiscope    523922   M        172.0
# 1046576772    VisualBehaviorMultiscope    523922   M        172.0
# 1046576775    VisualBehaviorMultiscope    523922   M        172.0
# 1046576784    VisualBehaviorMultiscope    523922   M        172.0
# 1046576794    VisualBehaviorMultiscope    523922   M        172.0
#
#                                               full_genotype      cre_line  \
# container_id
# 1046576791    Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 1046576787    Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 1046576772    Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 1046576775    Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 1046576784    Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
# 1046576794    Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  Vip-IRES-Cre
#
#              targeted_structure  imaging_depth first_acquisition_date  \
# container_id
# 1046576791                 VISl            225             2020-09-04
# 1046576787                 VISl            150             2020-09-04
# 1046576772                 VISp             75             2020-09-04
# 1046576775                 VISp            150             2020-09-04
# 1046576784                 VISl             75             2020-09-04
# 1046576794                 VISl            274             2020-09-04
#
#              equipment_name  ...  \
# container_id                 ...
# 1046576791         [MESO.1]  ...
# 1046576787         [MESO.1]  ...
# 1046576772         [MESO.1]  ...
# 1046576775         [MESO.1]  ...
# 1046576784         [MESO.1]  ...
# 1046576794         [MESO.1]  ...
#
#                                                       session_1  \
# container_id
# 1046576791    OPHYS_2_images_A_passive experiment_id:1049610125
# 1046576787    OPHYS_2_images_A_passive experiment_id:1049610123
# 1046576772    OPHYS_2_images_A_passive experiment_id:1049610120
# 1046576775    OPHYS_2_images_A_passive experiment_id:1049610116
# 1046576784    OPHYS_2_images_A_passive experiment_id:1049610126
# 1046576794    OPHYS_2_images_A_passive experiment_id:1049610129
#
#                                               session_2  \
# container_id
# 1046576791    OPHYS_3_images_A experiment_id:1050485654
# 1046576787    OPHYS_3_images_A experiment_id:1050485652
# 1046576772    OPHYS_3_images_A experiment_id:1050485649
# 1046576775    OPHYS_3_images_A experiment_id:1050485645
# 1046576784    OPHYS_3_images_A experiment_id:1050485655
# 1046576794    OPHYS_3_images_A experiment_id:1050485657
#
#                                               session_3  \
# container_id
# 1046576791    OPHYS_4_images_B experiment_id:1050762974
# 1046576787    OPHYS_4_images_B experiment_id:1050762972
# 1046576772    OPHYS_4_images_B experiment_id:1050762969
# 1046576775    OPHYS_4_images_B experiment_id:1050762966
# 1046576784    OPHYS_4_images_B experiment_id:1050762975
# 1046576794    OPHYS_4_images_B experiment_id:1050762977
#
#                                               session_4  \
# container_id
# 1046576791    OPHYS_6_images_B experiment_id:1051249031
# 1046576787    OPHYS_6_images_B experiment_id:1051249029
# 1046576772    OPHYS_6_images_B experiment_id:1051249026
# 1046576775                                          NaN
# 1046576784                                          NaN
# 1046576794                                          NaN
#
#                                               session_5 session_6 session_7  \
# container_id
# 1046576791    OPHYS_4_images_B experiment_id:1051460018       NaN       NaN
# 1046576787    OPHYS_4_images_B experiment_id:1051460016       NaN       NaN
# 1046576772                                          NaN       NaN       NaN
# 1046576775                                          NaN       NaN       NaN
# 1046576784                                          NaN       NaN       NaN
# 1046576794                                          NaN       NaN       NaN
#
#              session_8 session_9 session_10
# container_id
# 1046576791         NaN       NaN        NaN
# 1046576787         NaN       NaN        NaN
# 1046576772         NaN       NaN        NaN
# 1046576775         NaN       NaN        NaN
# 1046576784         NaN       NaN        NaN
# 1046576794         NaN       NaN        NaN
#
# [6 rows x 21 columns]

# %% [markdown]
# ## Behavior Sessions table

# %% [markdown]
# You can get a list of all behavior sessions in lims using the SDK <code>BehaviorProjectCache</code>

# %%
cache = BehaviorProjectCache.from_lims()
behavior_sessions = cache.get_behavior_session_table()
print('there are',len(behavior_sessions),'behavior sessions in lims')
# Out:
# Getting behavior-only session data. This might take a while...
# there are 26713 behavior sessions in lims

# %% [markdown]
# VBA function <code>get_filtered_behavior_session_table()</code> returns the behavior sessions table from <code>BehaviorProjectCache</code> by default (with a few modifications like adding a column for project_code). <br><br> Setting the <code>release_data_only</code> flag to True limits the returned behavior sessions to the set that will go out in the release. This includes all behavior sessions for mice that have ophys data in the release, after filtering out sessions with an invalid session_type (such as OPHYS_7_receptive_field_mapping).

# %%
behavior_sessions = loading.get_filtered_behavior_session_table(release_data_only=True)
print('there are', len(behavior_sessions), 'behavior training sessions in the release')
# Out:
# Getting behavior-only session data. This might take a while...
# Getting all ophys sessions. This might take a while.
# there are 3213 behavior training sessions in the release

# %%
np.sort(behavior_sessions.project_code.unique())
# Out:
# array(['VisualBehavior', 'VisualBehaviorMultiscope',
#        'VisualBehaviorTask1B'], dtype=object)

# %%
np.sort(behavior_sessions.session_type.unique())
# Out:
# array(['0_gratings_autorewards_15min', '1_gratings', '2_gratings_flashed',
#        '3_images_a_10uL_reward', '4_images_a_handoff_lapsed',
#        '4_images_a_handoff_ready', '4_images_a_training',
#        'OPHYS_0_images_A_habituation', 'OPHYS_0_images_B_habituation',
#        'OPHYS_1_images_A', 'OPHYS_1_images_B', 'OPHYS_2_images_A_passive',
#        'OPHYS_2_images_B_passive', 'OPHYS_3_images_A', 'OPHYS_3_images_B',
#        'OPHYS_4_images_A', 'OPHYS_4_images_B', 'OPHYS_5_images_A_passive',
#        'OPHYS_5_images_B_passive', 'OPHYS_6_images_A', 'OPHYS_6_images_B',
#        'TRAINING_0_gratings_autorewards_15min', 'TRAINING_1_gratings',
#        'TRAINING_2_gratings_flashed', 'TRAINING_3_images_A_10uL_reward',
#        'TRAINING_3_images_B_10uL_reward',
#        'TRAINING_4_images_A_handoff_lapsed',
#        'TRAINING_4_images_A_handoff_ready',
#        'TRAINING_4_images_A_training', 'TRAINING_4_images_B_training',
#        'TRAINING_5_images_A_epilogue',
#        'TRAINING_5_images_A_handoff_lapsed',
#        'TRAINING_5_images_A_handoff_ready',
#        'TRAINING_5_images_B_epilogue',
#        'TRAINING_5_images_B_handoff_lapsed',
#        'TRAINING_5_images_B_handoff_ready'], dtype=object)

# %%
behavior_sessions.keys()
# Out:
# Index(['ophys_session_id', 'equipment_name', 'date_of_acquisition', 'donor_id',
#        'full_genotype', 'mouse_id', 'reporter_line', 'driver_line', 'sex',
#        'age_in_days', 'foraging_id', 'session_type', 'project_code',
#        'has_passing_ophys_data'],
#       dtype='object')

# %% [markdown]
# ### Let's look at the entire training history for one mouse

# %%
sessions_for_this_mouse = behavior_sessions[behavior_sessions.mouse_id==mouse_id].sort_values(by='date_of_acquisition')
sessions_for_this_mouse.head()
# Out:
#                      ophys_session_id equipment_name     date_of_acquisition  \
# behavior_session_id
# 1028197734                        NaN     BEH.B-Box5 2020-06-05 10:53:41.306
# 1028678561                        NaN     BEH.F-Box5 2020-06-08 09:13:13.220
# 1029018134                        NaN     BEH.B-Box5 2020-06-09 09:01:09.200
# 1029204296                        NaN     BEH.B-Box5 2020-06-10 08:26:52.157
# 1029409311                        NaN     BEH.B-Box5 2020-06-11 08:51:17.603
#
#                        donor_id  \
# behavior_session_id
# 1028197734           1022744249
# 1028678561           1022744249
# 1029018134           1022744249
# 1029204296           1022744249
# 1029409311           1022744249
#
#                                                      full_genotype  mouse_id  \
# behavior_session_id
# 1028197734           Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    523922
# 1028678561           Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    523922
# 1029018134           Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    523922
# 1029204296           Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    523922
# 1029409311           Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    523922
#
#                                     reporter_line     driver_line sex  \
# behavior_session_id
# 1028197734           [Ai148(TIT2L-GC6f-ICL-tTA2)]  [Vip-IRES-Cre]   M
# 1028678561           [Ai148(TIT2L-GC6f-ICL-tTA2)]  [Vip-IRES-Cre]   M
# 1029018134           [Ai148(TIT2L-GC6f-ICL-tTA2)]  [Vip-IRES-Cre]   M
# 1029204296           [Ai148(TIT2L-GC6f-ICL-tTA2)]  [Vip-IRES-Cre]   M
# 1029409311           [Ai148(TIT2L-GC6f-ICL-tTA2)]  [Vip-IRES-Cre]   M
#
#                      age_in_days                           foraging_id  \
# behavior_session_id
# 1028197734                  81.0  c1d6b5c3-91a9-40b3-aa6b-bcb0130293f7
# 1028678561                  84.0  24b972cd-8090-4089-a596-49cac409bad7
# 1029018134                  85.0  d5054c11-48c7-4764-b734-1ba4df544fb0
# 1029204296                  86.0  4a60fba8-10c6-412d-8181-21f9d38c1cb8
# 1029409311                  87.0  a542e989-ee03-43a7-9b74-20e19f40ed74
#
#                                               session_type  \
# behavior_session_id
# 1028197734           TRAINING_0_gratings_autorewards_15min
# 1028678561                             TRAINING_1_gratings
# 1029018134                             TRAINING_1_gratings
# 1029204296                             TRAINING_1_gratings
# 1029409311                             TRAINING_1_gratings
#
#                                  project_code  has_passing_ophys_data
# behavior_session_id
# 1028197734           VisualBehaviorMultiscope                   False
# 1028678561           VisualBehaviorMultiscope                   False
# 1029018134           VisualBehaviorMultiscope                   False
# 1029204296           VisualBehaviorMultiscope                   False
# 1029409311           VisualBehaviorMultiscope                   False

# %% [markdown]
# ### Which of the ophys sessions for this mouse have passing ophys data?

# %% [markdown]
# Use the <code>has_passing_ophys_data</code> to identify sessions with passing ophys data

# %%
# behavior sessions where ophys_session_id is not NaN were ophys experiments
ophys_sessions = sessions_for_this_mouse[sessions_for_this_mouse.ophys_session_id.isnull()==False]
# but not all ophys sessions passed, use has_passing_ophys_data column to determine which ones do
ophys_sessions[['session_type', 'has_passing_ophys_data']]
# Out:
#                                  session_type  has_passing_ophys_data
# behavior_session_id
# 1047956553                   OPHYS_1_images_A                   False
# 1048153246                   OPHYS_1_images_A                   False
# 1048388846                   OPHYS_1_images_A                    True
# 1049260803           OPHYS_2_images_A_passive                    True
# 1049767272           OPHYS_2_images_A_passive                   False
# 1050253885                   OPHYS_3_images_A                    True
# 1050620316                   OPHYS_4_images_B                    True
# 1050949898           OPHYS_5_images_B_passive                   False
# 1051129953                   OPHYS_6_images_B                    True

# %% [markdown]
# ## BehaviorSessions

# %% [markdown]
# ### plot behavior performance for this mouse across all training stages

# %%
from allensdk.brain_observatory.behavior.behavior_session import BehaviorSession

# %% [markdown]
# #### get behavior performance metrics for a behavior session

# %%
behavior_session_ids = sessions_for_this_mouse.index.values

# %%
behavior_session_id = behavior_session_ids[0]
behavior_session = BehaviorSession.from_lims(behavior_session_id)

# %%
behavior_session.get_performance_metrics()
# Out:
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\scipy\stats\_distn_infrastructure.py:2017: RuntimeWarning: invalid value encountered in greater
#   cond1 = (0 < q) & (q < 1)
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\scipy\stats\_distn_infrastructure.py:2017: RuntimeWarning: invalid value encountered in less
#   cond1 = (0 < q) & (q < 1)
# {'trial_count': 120,
#  'go_trial_count': 0,
#  'catch_trial_count': 0,
#  'hit_trial_count': 0,
#  'miss_trial_count': 0,
#  'false_alarm_trial_count': 0,
#  'correct_reject_trial_count': 0,
#  'auto_rewarded_trial_count': 120,
#  'rewarded_trial_count': 120,
#  'total_reward_count': 120,
#  'total_reward_volume': 0.6,
#  'maximum_reward_rate': 5.269230467148899,
#  'engaged_trial_count': 88,
#  'mean_hit_rate': nan,
#  'mean_hit_rate_uncorrected': nan,
#  'mean_hit_rate_engaged': nan,
#  'mean_false_alarm_rate': nan,
#  'mean_false_alarm_rate_uncorrected': nan,
#  'mean_false_alarm_rate_engaged': nan,
#  'mean_dprime': nan,
#  'mean_dprime_engaged': nan,
#  'max_dprime': nan,
#  'max_dprime_engaged': nan}

# %% [markdown]
# #### aggregate performance data across all behavior sessions for this mouse

# %% [markdown]
# #### WARNING: this takes a while

# %%
behavior_metrics_df = pd.DataFrame()
problem_sessions = []
for behavior_session_id in behavior_session_ids:
    print(np.where(behavior_session_ids==behavior_session)[0][0], 'out of', len(behavior_session_ids))
    try:
        behavior_session = BehaviorSession.from_lims(behavior_session_id)
        metrics = behavior_session.get_performance_metrics()
        metrics_df = pd.DataFrame(metrics, index=[behavior_session_id])
        behavior_metrics_df = pd.concat([behavior_metrics_df, metrics_df])
    except Exception as e:
        problem_sessions.append(behaior_session_id)
        print(behavior_session_id)
        print(e)
behavior_metrics_df.index.name = 'behavior_session_id'

# %%
bmdf = behavior_metrics_df.copy()

# %%
# add metadata
behavior_metrics_df = behavior_metrics_df.merge(behavior_sessions, on='behavior_session_id')

# %%
behavior_metrics_df.keys()
# Out:
# Index(['trial_count', 'go_trial_count', 'catch_trial_count', 'hit_trial_count',
#        'miss_trial_count', 'false_alarm_trial_count',
#        'correct_reject_trial_count', 'auto_rewarded_trial_count',
#        'rewarded_trial_count', 'total_reward_count', 'total_reward_volume',
#        'maximum_reward_rate', 'engaged_trial_count', 'mean_hit_rate',
#        'mean_hit_rate_uncorrected', 'mean_hit_rate_engaged',
#        'mean_false_alarm_rate', 'mean_false_alarm_rate_uncorrected',
#        'mean_false_alarm_rate_engaged', 'mean_dprime', 'mean_dprime_engaged',
#        'max_dprime', 'max_dprime_engaged', 'ophys_session_id',
#        'equipment_name', 'date_of_acquisition', 'donor_id', 'full_genotype',
#        'mouse_id', 'reporter_line', 'driver_line', 'sex', 'age_in_days',
#        'foraging_id', 'session_type', 'project_code',
#        'has_passing_ophys_data'],
#       dtype='object')

# %%
behavior_metrics_df['date'] = [str(date)[:10] for date in behavior_metrics_df.date_of_acquisition.values]

# %%
behavior_metrics_df = behavior_metrics_df[behavior_metrics_df.session_type.isnull()==False]

# %%
behavior_metrics_df.session_type.unique()
# Out:
# array(['TRAINING_0_gratings_autorewards_15min', 'TRAINING_1_gratings',
#        'TRAINING_2_gratings_flashed', 'TRAINING_3_images_A_10uL_reward',
#        'TRAINING_4_images_A_training', 'TRAINING_5_images_A_epilogue',
#        'TRAINING_5_images_A_handoff_ready',
#        'OPHYS_0_images_A_habituation', 'OPHYS_1_images_A',
#        'OPHYS_2_images_A_passive', 'OPHYS_3_images_A', 'OPHYS_4_images_B',
#        'OPHYS_5_images_B_passive', 'OPHYS_6_images_B',
#        'OPHYS_7_receptive_field_mapping'], dtype=object)

# %%
behavior_metrics_df.mean_dprime.values
# Out:
# array([        nan,  0.22885689, -0.12640532, -0.17288155,  0.3258951 ,
#         0.3512268 ,  0.82322992,  1.50197184,  0.60057463,  0.83145332,
#         0.13372015,  0.15726   ,  0.19991926,  0.83517707,  0.9133579 ,
#         0.69640308,  0.60177405,  0.51345368,  0.01166651,  1.19355827,
#         1.30414574,  0.86689864,  1.05699325,  0.57097944,  0.74852465,
#         0.55156315,  1.52572428,  1.13543836,  1.44504607,  0.57805425,
#         0.75330942,  1.01973077,  0.79153872,  0.60697267,  0.80657985,
#         0.77833283,  0.79230808,  1.0988575 ,  0.84806691,  0.42301715,
#         1.0271978 ,  0.64626809,  1.11866008,  0.66935207,  0.67098324,
#         0.51669655,  0.71025084,  0.8535635 ,  0.54815726,  0.42643845,
#         0.29097548,  0.31079835,  0.86740794,  0.27402685,  0.53432906,
#         0.76035917, -0.28264853,  1.33039482,  1.3449421 ,  0.76750234,
#         1.08828729,  1.32794448, -0.61146284,  0.88367196, -0.69859694,
#         1.22147906,  0.79363695, -0.63252041,  1.29704646,  0.32384191])

# %%
df = behavior_metrics_df[1:]

fig, ax = plt.subplots(figsize=(15,5))
sns.pointplot(data=df, x='date', y='mean_dprime', hue='session_type', 
              join=False, palette='magma', ax=ax)
ax.legend(bbox_to_anchor=(1.1,1), fontsize='x-small')
ax.set_xticklabels(labels=df.date.values, rotation=90);
ax.set_ylim(-1,3)
# Out:
# (-1, 3)
